# %% [markdown]
# # MSSW on weather evaluation

# %% [markdown]
# ## Accept and preprocess the weather dataset

# %%
import csv

import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv("../Datasets_concept_drift/real_world_data/weather_dataset.csv")

X = df.drop(columns=['Unnamed: 0', 'Label_Rain'])
y = df["Label_Rain"]

X_ref = X[:6053]
X_test = X[6053:]
y_ref = y[:6053]
y_test = y[6053:]

X_ref = X_ref.to_numpy()
X_test = X_test.to_numpy()
y_ref = y_ref.to_numpy()
y_test = y_test.to_numpy()

print('\nreference data')
print(X_ref.shape)
print(X_ref)
print('\nreference labels')
print(y_ref.shape)
print('\ntesting data')
print(X_test.shape)
print(X_test)
print('\ntesting labels')
print(y_test.shape)
# Out:
# reference data
# (6053, 8)
# [[  24.7   21.3 1013.8 ...   12.    30.9   19.9]
#  [  26.6   20.1 1015.7 ...   18.1   30.    19. ]
#  [  24.    16.5 1018.6 ...   14.    28.9   19. ]
#  ...
#  [  76.    70.6 1017.4 ...    9.9   87.1   72. ]
#  [  74.4   64.5 1019.  ...    8.    82.    66.9]
#  [  73.9   65.3 1017.4 ...    7.    81.    66.9]]
#
# reference labels
# (6053,)
#
# testing data
# (12106, 8)
# [[  73.    60.4 1018.  ...    9.9   82.9   61. ]
#  [  74.5   62.3 1017.2 ...    8.9   91.    61. ]
#  [  81.4   64.3 1012.7 ...   10.9   93.9   69.1]
#  ...
#  [  13.9    3.2 1009.6 ...   17.9   25.2    5.2]
#  [   7.3   -7.5 1014.1 ...   24.9   23.2   -2.7]
#  [  -2.1  -15.5 1025.4 ...   11.8   11.1  -10.8]]
#
# testing labels
# (12106,)

# %% [markdown]
# ## Split the dataset to batches

# %% [markdown]
# ### Yearly batches (size=365)

# %%
from eval_helpers import helpers

X_test_batches_year, y_test_batches_year = helpers.split_to_fixed_size_batches(X_test, y_test, batch_size=365)
X_ref_batches_year, y_ref_batches_year = helpers.split_to_fixed_size_batches(X_ref, y_ref, batch_size=365)

print('# yearly test batches:')
print(len(X_test_batches_year))
print(len(y_test_batches_year))
print('# yearly ref batches:')
print(len(X_ref_batches_year))
print(len(y_ref_batches_year))
# Out:
# chunk size 365
# number of chunks 34
# number of data 12106
# number of resulting batches 34
# [[  73.    60.4 1018.  ...    9.9   82.9   61. ]
#  [  74.5   62.3 1017.2 ...    8.9   91.    61. ]
#  [  81.4   64.3 1012.7 ...   10.9   93.9   69.1]
#  ...
#  [  88.    71.7 1009.7 ...    8.9   96.8   78.8]
#  [  83.5   74.1 1012.9 ...    9.9   95.    75.2]
#  [  73.8   71.2 1013.7 ...    8.9   78.8   69.8]]
# (357, 8)
# chunk size 365
# number of chunks 17
# number of data 6053
# number of resulting batches 17
# [[  24.7   21.3 1013.8 ...   12.    30.9   19.9]
#  [  26.6   20.1 1015.7 ...   18.1   30.    19. ]
#  [  24.    16.5 1018.6 ...   14.    28.9   19. ]
#  ...
#  [  31.8   28.3 1006.9 ...   15.    41.    21. ]
#  [  11.2    1.6 1030.4 ...   25.1   19.9    3.9]
#  [  16.2    5.3 1035.3 ...   17.1   37.9    6.1]]
# (357, 8)
# # yearly test batches:
# 34
# 34
# # yearly ref batches:
# 17
# 17

# %% [markdown]
# ### Montly batches (size=30)

# %%
X_test_batches_month, y_test_batches_month = helpers.split_to_fixed_size_batches(X_test, y_test, batch_size=30)
X_ref_batches_month, y_ref_batches_month = helpers.split_to_fixed_size_batches(X_ref, y_ref, batch_size=30)

print('# monthly test batches:')
print(len(X_test_batches_month))
print(len(y_test_batches_month))
print('# monthly ref batches:')
print(len(X_ref_batches_month))
print(len(y_ref_batches_month))
# Out:
# chunk size 30
# number of chunks 404
# number of data 12106
# number of resulting batches 404
# [[  73.    60.4 1018.    15.     3.9    9.9   82.9   61. ]
#  [  74.5   62.3 1017.2   15.4    3.1    8.9   91.    61. ]
#  [  81.4   64.3 1012.7   14.9    4.4   10.9   93.9   69.1]
#  [  82.4   69.3 1010.1   14.7    5.7   12.8   96.1   70. ]
#  [  86.6   71.5 1008.1   14.9    6.9   11.8  100.    75. ]
#  [  85.5   71.9 1009.3   14.9    6.     9.9   96.1   77. ]
#  [  77.6   73.6 1015.3   15.6    4.2   14.    90.    71.1]
#  [  76.9   73.3 1018.4   12.     4.5    7.    82.    71.1]
#  [  76.7   72.  1018.2    5.5    3.3    5.8   84.    72. ]
#  [  76.7   65.7 1017.5   11.6    3.8   12.8   84.    68. ]
#  [  66.2   59.3 1018.9   16.1    2.2    8.9   81.    60.1]
#  [  58.5   55.  1021.8   11.5    4.     8.    66.9   55. ]
#  [  62.6   54.8 1022.6   17.2    3.2    9.9   72.    53.1]
#  [  63.7   59.5 1018.6   13.6    6.7   14.    71.1   60.1]
#  [  68.5   66.8 1014.8    8.3    5.1   21.    77.    64. ]
#  [  69.3   67.5 1014.5    6.9    5.1   14.    75.    66.9]
#  [  70.7   69.7 1013.1    5.5    3.3    7.    75.    68.7]
#  [  73.    69.9 1018.4    4.1    3.8    7.    81.    68. ]
#  [  73.7   71.1 1021.6    4.4    1.2    4.9   81.    64.9]
#  [  75.6   70.5 1019.4    3.1    2.9    8.9   82.9   66.9]
#  [  78.5   72.  1015.9    4.3    4.9    8.9   91.    70. ]
#  [  77.9   71.2 1019.4    8.5    3.5   10.9   88.    73. ]
#  [  71.    62.1 1023.2   15.8    1.7    5.8   81.    60.1]
#  [  75.6   67.  1013.5   17.9    5.    11.8   88.    68. ]
#  [  74.4   68.1 1013.    16.4    1.8    5.8   82.9   68. ]
#  [  72.4   66.4 1012.6   15.3    6.3   15.9   80.1   69.1]
#  [  68.6   58.2 1018.8   19.3    3.8    9.9   79.    57.9]
#  [  68.4   62.9 1013.    17.6    4.7    9.9   75.9   63. ]
#  [  67.9   60.6 1015.3   15.2    5.8   10.9   73.    62.1]
#  [  63.5   56.4 1021.7   13.6    4.2    8.    75.    57. ]]
# (30, 8)
# chunk size 30
# number of chunks 202
# number of data 6053
#    4.4100e+01  2.1900e+01]
#  [ 3.2800e+01  2.7300e+01  1.0130e+03  5.5000e+00  1.5800e+01  2.0000e+01
#    4.1000e+01  2.5000e+01]
#  [ 2.5400e+01  2.0500e+01  1.0167e+03  5.4000e+00  1.2300e+01  2.0000e+01
#    2.8000e+01  2.4100e+01]
#  [ 2.5000e+01  1.9400e+01  1.0179e+03  1.2100e+01  1.0100e+01  1.8100e+01
#    3.3100e+01  1.9900e+01]
#  [ 2.4100e+01  1.8800e+01  1.0181e+03  8.2000e+00  7.5000e+00  1.5000e+01
#    3.5100e+01  1.6000e+01]
#  [ 3.3800e+01  2.5400e+01  1.0123e+03  7.4000e+00  9.3000e+00  1.7100e+01
#    4.3000e+01  2.6100e+01]
#  [ 3.2400e+01  2.6100e+01  1.0178e+03  1.0500e+01  8.8000e+00  2.0000e+01
#    3.9000e+01  2.8000e+01]
#  [ 2.8000e+01  2.0900e+01  1.0200e+03  9.3000e+00  7.2000e+00  1.2000e+01
#    3.9900e+01  1.9900e+01]
#  [ 3.3800e+01  2.6600e+01  1.0154e+03  1.0800e+01  8.1000e+00  2.2000e+01
#    4.2100e+01  2.8900e+01]
#  [ 3.9200e+01  3.3000e+01  1.0108e+03  8.6000e+00  3.1000e+00  1.0100e+01
#    5.2000e+01  3.3100e+01]]
# (30, 8)
# # monthly test batches:
# 404
# 404
# # monthly ref batches:
# 202
# 202

# %% [markdown]
# ## Find suitable KMeans clustering parameters

# %%
from core import mssw_preprocessing
from eval_helpers import kmeans_verbose_helpers

weighted_joined_reference_data, _, _ = mssw_preprocessing.mssw_preprocess(X_ref_batches_year, X_test_batches_year)

filename = 'weather_yearly_output.txt'
print(kmeans_verbose_helpers)
kmeans_verbose_helpers.write_verbose_kmeans_to_file(filename, weighted_joined_reference_data,
                                                    n_clusters=2, n_init=100, max_iter=500, tol=0, random_state=1053)
output_dicts = kmeans_verbose_helpers.convert_kmeans_output_file_to_dicts(filename, n_init=100)
kmeans_verbose_helpers.print_stats_from_kmeans_output_dicts(output_dicts)
# Out:
# <module 'eval_helpers.kmeans_verbose_helpers' from 'C:\\Users\\jpohl\\PycharmProjects\\clustering-drift-detection\\mssw\\eval_helpers\\kmeans_verbose_helpers.py'>
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 9.183929972903627
# maximum initial inertia: 22.607234056268144
# number of unique final inertia values: 1
# minimum final inertia: 6.770271431806887
# maximum final inertia: 6.770271431806887
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0

# %% [markdown]
# ## Yearly predictions - drift detection evaluation

# %% [markdown]
# ### Read the defined yearly drift locations

# %%
import csv

true_drift_bool_year = []
with open('../Datasets_concept_drift/real_world_data_drifts/weather/weather_yearly_drifts.csv') as f:
    rdr = csv.reader(f, delimiter=',')
    for row in rdr:
        true_drift_bool_year.append(row)
    true_drift_bool_year = true_drift_bool_year[0] # only one row of important data
    true_drift_bool_year = [b == 'True' for b in true_drift_bool_year]
print(true_drift_bool_year)
# Out:
# [False, True, True, False, False, True, False, False, False, False, False, False, True, False, True, True, True, True, True, False, True, False, True, True, False, False, False, True, False, False, False, False, True, True]

# %% [markdown]
# ### Use them for the evaluation

# %%
import mssw_eval_real_world

_, fpr_mean, _, det_acc_mean, _ = mssw_eval_real_world.all_drifting_batches_randomness_robust(
    reference_data_batches=X_ref_batches_year,
    testing_data_batches=X_test_batches_year,
    true_drift_bool=true_drift_bool_year,
    n_clusters=2, n_init=100, max_iter=90, tol=0,
    coeff=2.66, first_random_state=0,
    min_runs=5, std_err_threshold=0.05
)

print('yearly mean FPR:', fpr_mean)
print('yearly mean detection accuracy:', det_acc_mean)
# Out:
# min_runs 5
# centroid distance sums [[21.32772419 24.53787619]]
# num points in clusters [[180. 177.]]
# centroid distance sums [[26.20214066 29.62468571]]
# num points in clusters [[191. 165.]]
# centroid distance sums [[22.45533077 35.83701522]]
# num points in clusters [[167. 189.]]
# centroid distance sums [[103.50855398  29.08624347]]
# num points in clusters [[200. 156.]]
# centroid distance sums [[63.31212691 33.78521921]]
# num points in clusters [[186. 170.]]
# centroid distance sums [[18.53750067 28.9833492 ]]
# num points in clusters [[169. 187.]]
# centroid distance sums [[32.25303297 36.18016059]]
# num points in clusters [[184. 172.]]
# centroid distance sums [[25.3526229  32.42792877]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[24.77513497 26.92833754]]
# num points in clusters [[188. 168.]]
# centroid distance sums [[23.88460046 33.11560917]]
# num points in clusters [[175. 181.]]
# centroid distance sums [[24.13745451 29.70620744]]
# num points in clusters [[179. 177.]]
# centroid distance sums [[26.00597572 30.18356596]]
# num points in clusters [[181. 175.]]
# centroid distance sums [[20.40190938 31.82786673]]
# num points in clusters [[168. 188.]]
# centroid distance sums [[24.85957963 38.25758752]]
# num points in clusters [[162. 194.]]
# centroid distance sums [[25.39392804 29.02305237]]
# num points in clusters [[186. 170.]]
# centroid distance sums [[19.57336694 33.01546501]]
# num points in clusters [[162. 194.]]
# centroid distance sums [[27.05270313 36.52119263]]
# num points in clusters [[170. 186.]]
# centroid distance sums [[140.12713993  43.58319422]]
# num points in clusters [[172. 185.]]
# centroid distance sums [[20.90363955 30.26418863]]
# num points in clusters [[164. 193.]]
# centroid distance sums [[25.83757782 31.46230101]]
# num points in clusters [[169. 187.]]
# centroid distance sums [[61.7702883 31.6141496]]
# num points in clusters [[186. 170.]]
# centroid distance sums [[20.4983971  29.27734991]]
# num points in clusters [[169. 187.]]
# centroid distance sums [[20.50996037 27.38050474]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[97.1684974  26.47420094]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[25.24333892 32.95927919]]
# num points in clusters [[181. 175.]]
# centroid distance sums [[26.09576519 35.26280988]]
# num points in clusters [[177. 179.]]
# centroid distance sums [[26.7341067  40.75910991]]
# num points in clusters [[183. 173.]]
# centroid distance sums [[61.28220035 28.08988493]]
# num points in clusters [[184. 172.]]
# centroid distance sums [[102.11632113  37.66247716]]
# num points in clusters [[172. 184.]]
# centroid distance sums [[23.58398735 35.12252956]]
# num points in clusters [[161. 195.]]
# centroid distance sums [[136.31982378  38.55378162]]
# num points in clusters [[169. 187.]]
# centroid distance sums [[64.42880122 28.77796954]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[62.85323221 30.42064563]]
# num points in clusters [[165. 191.]]
# centroid distance sums [[25.60819502 34.05882002]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[68.16656449 32.55343814]]
# num points in clusters [[184. 172.]]
# centroid distance sums [[19.14678873 32.6539778 ]]
# num points in clusters [[163. 193.]]
# centroid distance sums [[59.61726939 32.66452626]]
# num points in clusters [[176. 180.]]
# centroid distance sums [[33.04408673 30.77024573]]
# num points in clusters [[181. 175.]]
# centroid distance sums [[20.18076316 25.89145163]]
# num points in clusters [[168. 188.]]
# centroid distance sums [[133.44347868  30.18434549]]
# num points in clusters [[177. 179.]]
# centroid distance sums [[ 21.34458628 226.50849033]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[23.4019583  32.13917744]]
# num points in clusters [[188. 168.]]
# centroid distance sums [[38.08048367 29.78333889]]
# num points in clusters [[203. 153.]]
# centroid distance sums [[24.30719105 28.92498846]]
# num points in clusters [[197. 159.]]
# centroid distance sums [[73.94239795 31.9808414 ]]
# num points in clusters [[197. 159.]]
# centroid distance sums [[19.80895493 35.38665713]]
# num points in clusters [[167. 189.]]
# centroid distance sums [[38.69526665 32.92393442]]
# num points in clusters [[214. 142.]]
# centroid distance sums [[22.27337733 26.26367342]]
# num points in clusters [[199. 157.]]
# centroid distance sums [[25.73547627 32.305837  ]]
# num points in clusters [[183. 173.]]
# centroid distance sums [[20.65085881 30.85099497]]
# num points in clusters [[184. 172.]]
# centroid distance sums [
False, False, False, False, False, True, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, True, True, False, False, False, True, False, False, False, False, False, False]
# [False, True, True, False, False, True, False, False, False, False, False, False, True, False, True, True, True, True, True, False, True, False, True, True, False, False, False, True, False, False, False, False, True, True]
# centroid distance sums [[24.53787619 21.32772419]]
# num points in clusters [[177. 180.]]
# centroid distance sums [[29.62468571 26.20214066]]
# num points in clusters [[165. 191.]]
# centroid distance sums [[35.83701522 22.45533077]]
# num points in clusters [[189. 167.]]
# centroid distance sums [[ 29.08624347 103.50855398]]
# num points in clusters [[156. 200.]]
# centroid distance sums [[33.78521921 63.31212691]]
# num points in clusters [[170. 186.]]
# centroid distance sums [[28.9833492  18.53750067]]
# num points in clusters [[187. 169.]]
# centroid distance sums [[36.18016059 32.25303297]]
# num points in clusters [[172. 184.]]
# centroid distance sums [[32.42792877 25.3526229 ]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[26.92833754 24.77513497]]
# num points in clusters [[168. 188.]]
# centroid distance sums [[33.11560917 23.88460046]]
# num points in clusters [[181. 175.]]
# centroid distance sums [[29.70620744 24.13745451]]
# num points in clusters [[177. 179.]]
# centroid distance sums [[30.18356596 26.00597572]]
# num points in clusters [[175. 181.]]
# centroid distance sums [[31.82786673 20.40190938]]
# num points in clusters [[188. 168.]]
# centroid distance sums [[38.25758752 24.85957963]]
# num points in clusters [[194. 162.]]
# centroid distance sums [[29.02305237 25.39392804]]
# num points in clusters [[170. 186.]]
# centroid distance sums [[33.01546501 19.57336694]]
# num points in clusters [[194. 162.]]
# centroid distance sums [[36.52119263 27.05270313]]
# num points in clusters [[186. 170.]]
# centroid distance sums [[ 43.58319422 140.12713993]]
# num points in clusters [[185. 172.]]
# centroid distance sums [[30.26418863 20.90363955]]
# num points in clusters [[193. 164.]]
# centroid distance sums [[31.46230101 25.83757782]]
# num points in clusters [[187. 169.]]
# centroid distance sums [[31.6141496 61.7702883]]
# num points in clusters [[170. 186.]]
# centroid distance sums [[29.27734991 20.4983971 ]]
# num points in clusters [[187. 169.]]
# centroid distance sums [[27.38050474 20.50996037]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[26.47420094 97.1684974 ]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[32.95927919 25.24333892]]
# num points in clusters [[175. 181.]]
# centroid distance sums [[35.26280988 26.09576519]]
# num points in clusters [[179. 177.]]
# centroid distance sums [[40.75910991 26.7341067 ]]
# num points in clusters [[173. 183.]]
# centroid distance sums [[28.08988493 61.28220035]]
# num points in clusters [[172. 184.]]
# centroid distance sums [[ 37.66247716 102.11632113]]
# num points in clusters [[184. 172.]]
# centroid distance sums [[35.12252956 23.58398735]]
# num points in clusters [[195. 161.]]
# centroid distance sums [[ 38.55378162 136.31982378]]
# num points in clusters [[187. 169.]]
# centroid distance sums [[28.77796954 64.42880122]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[30.42064563 62.85323221]]
# num points in clusters [[191. 165.]]
# centroid distance sums [[34.05882002 25.60819502]]
# num points in clusters [[185. 171.]]
# centroid distance sums [[32.55343814 68.16656449]]
# num points in clusters [[172. 184.]]
# centroid distance sums [[32.6539778  19.14678873]]
# num points in clusters [[193. 163.]]
# centroid distance sums [[32.66452626 59.61726939]]
# num points in clusters [[180. 176.]]
# centroid distance sums [[30.77024573 33.04408673]]
# num points in clusters [[175. 181.]]
# centroid distance sums [[25.89145163 20.18076316]]
# num points in clusters [[188. 168.]]
# centroid distance sums [[ 30.18434549 133.44347868]]
# num points in clusters [[179. 177.]]
# centroid distance sums [[226.50849033  21.34458628]]
# num points in clusters [[171. 185.]]
# centroid distance sums [[32.13917744 23.4019583 ]]
# num points in clusters [[168. 188.]]
# centroid distance sums [[29.78333889 38.08048367]]
# num points in clusters [[153. 203.]]
# centroid distance sums [[28.92498846 24.30719105]]
# num points in clusters [[159. 197.]]
# centroid distance sums [[31.9808414  73.94239795]]
# num points in clusters [[159. 197.]]
# centroid distance sums [[35.38665713 19.80895493]]
# num points in clusters [[189. 167.]]
# centroid distance sums [[32.92393442 38.69526665]]
# num points in clusters [[142. 214.]]
# centroid distance sums [[26.26367342 22.27337733]]
# num points in clusters [[157. 199.]]
# centroid distance sums [[32.305837   25.73547627]]
# num points in clusters [[173. 183.]]
# centroid distance sums [[30.85099497 20.65085881]]
# num points in clusters [[172. 184.]]
# centroid distance sums [[37.70517691 33.71571488]]
# num points in clusters [[166. 190.]]
# [True, False, False, False, False, False, True, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, True, True, False, False, False, True, False, False, False, False, False, False]
# [False, True, True, False, False, True, False, False, False, False, False, False, True, False, True, True, True, True, True, False, True, False, True, True, False, False, False, True, False, False, False, False, True, True]
# yearly mean FPR: 0.21052631578947367
# yearly mean detection accuracy: 0.2

# %% [markdown]
# ## Monthly predictions - drift detection evaluation

# %% [markdown]
# ### Read the defined monthly drift locations

# %%
import csv

true_drift_bool_month = []
with open('../Datasets_concept_drift/real_world_data_drifts/weather/weather_monthly_drifts.csv') as f:
    rdr = csv.reader(f, delimiter=',')
    for row in rdr:
        true_drift_bool_month.append(row)
    true_drift_bool_month = true_drift_bool_month[0] # only one row of important data
    true_drift_bool_month = [b == 'True' for b in true_drift_bool_month]
print(true_drift_bool_month)
# Out:
# [False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, True, True, True, True, True, True, False, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, False, False, False, True, True, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, True, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False]

# %% [markdown]
# ### Use them for the evaluation

# %%
import mssw_eval_real_world

_, fpr_mean, _, det_acc_mean, _ = mssw_eval_real_world.all_drifting_batches_randomness_robust(
    reference_data_batches=X_ref_batches_month,
    testing_data_batches=X_test_batches_month,
    true_drift_bool=true_drift_bool_month,
    n_clusters=2, n_init=100, max_iter=90, tol=0,
    coeff=2.66, first_random_state=0,
    min_runs=5, std_err_threshold=0.05
)

print('yearly mean FPR:', fpr_mean)
print('yearly mean detection accuracy:', det_acc_mean)
# Out:
# min_runs 5
# centroid distance sums [[4.18704012 1.13600062]]
# num points in clusters [[25.  5.]]
# centroid distance sums [[6.10203189 0.8271545 ]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[9.80187249 0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[12.5669593  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[17.93137689  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.94819316  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[25.08486799  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.02899442  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[21.08014001  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[17.72597664  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[10.96473204  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[6.85898796 1.49419068]]
# num points in clusters [[25.  5.]]
# centroid distance sums [[8.51082578 0.69456798]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[9.47168343 0.31619437]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[12.55881616  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[13.52442489  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[16.74840051  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[22.74727035  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[26.0427833  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.79612665  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.57185458  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[16.24362653  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[13.35625491  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[8.55811347 0.60579769]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[3.54241741 7.8226283 ]]
# num points in clusters [[12. 18.]]
# centroid distance sums [[8.07630946 1.62475355]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[7.38977038 0.16222447]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[10.97080562  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.9110862  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[21.2383331  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.45748846  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[25.21463473  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[22.74953087  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[17.57024964  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[12.04581583  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[92.07529295  0.38134124]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[91.49637032  1.27802335]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[3.57139873 5.93477071]]
# num points in clusters [[13. 17.]]
# centroid distance sums [[10.32566416  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[12.51167056  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.43919521  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[20.43404432  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.13390476  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.90569992  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.3768049  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.57579129  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[14.31706976  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[5.67939103 2.71746373]]
# num points in clusters [[22.  8.]]
# centroid distance sums [[3.96144823 6.86816563]]
# num points in clusters [[13. 17.]]
# centroid distance sums [[7.46457229 2.2466875 ]]
# num points in clusters [[24.  6.]]
# centroid distance sums [[9.36489152 0.68659919]]
# num points in clusters [[28.  2.]]
# centroid distance sums [
0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[22.14825737  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[21.37413985  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.38937304  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[8.84176861 1.16854294]]
# num points in clusters [[27.  3.]]
# centroid distance sums [[7.63787167 0.74032598]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[4.85046574 1.86304869]]
# num points in clusters [[22.  8.]]
# centroid distance sums [[4.33716245 3.84076047]]
# num points in clusters [[18. 12.]]
# centroid distance sums [[6.43743774 1.85575577]]
# num points in clusters [[22.  8.]]
# centroid distance sums [[10.33469095  0.52306181]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[18.79878897  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[20.24695722  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.33947892  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.0877606  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[20.13639038  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.35829314  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[8.23719772 1.01014651]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[5.32162109 2.91527363]]
# num points in clusters [[20. 10.]]
# centroid distance sums [[2.51483495 7.92121583]]
# num points in clusters [[10. 20.]]
# centroid distance sums [[1.88814905 7.77193136]]
# num points in clusters [[ 8. 22.]]
# centroid distance sums [[8.84465288 0.6045225 ]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[12.14968109  0.50043966]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[16.42376543  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[22.08109988  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.37604086  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.73774404  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[22.54386168  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[17.29098058  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[11.45882646  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[8.4423683  1.70806913]]
# num points in clusters [[25.  5.]]
# centroid distance sums [[6.57987444 0.23443149]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[3.7513053  3.14684671]]
# num points in clusters [[18. 12.]]
# centroid distance sums [[6.9357412  0.80960366]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[11.26129099  0.7512084 ]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[19.86681328  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.69204883  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[25.25584264  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[26.75392324  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.30027745  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.27804639  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[11.79828471  0.29807042]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[5.65761533 1.87506932]]
# num points in clusters [[22.  8.]]
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# centroid distance sums [[3.2442961  5.15787468]]
# num points in clusters [[13. 17.]]
# centroid distance sums [[4.06377728 2.54685262]]
# num points in clusters [[21.  9.]]
# centroid distance sums [[6.15850183 1.10278535]]
# num points in clusters [[25.  5.]]
# centroid distance sums [[9.78446173 0.28735295]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[14.61860061  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[18.73370042  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[21.97542354  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.69117518  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.18288106  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[18.81452835  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[10.29997958  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[7.90337812 0.17310312]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[6.09296497 1.39693286]]
# num points in clusters [[26.  4.]]
# centroid distance sums [[3.34578234 6.81251321]]
# num points in clusters [[12. 17.]]
# centroid distance sums [[8.64630516 1.86535327]]
# num points in clusters [[25.  4.]]
# centroid distance sums [[11.59395141  1.00445461]]
# num points in clusters [[27.  2.]]
# centroid distance sums [[14.17202999  0.        ]]
# num points in clusters [[29.  0.]]
# centroid distance sums [[19.29851009  0.        ]]
# num points in clusters [[29.  0.]]
# centroid distance sums [[21.17636127  0.        ]]
# num points in clusters [[29.  0.]]
# centroid distance sums [[25.90051449  0.        ]]
# num points in clusters [[29.  0.]]
# centroid distance sums [[24.3844266  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[21.49111619  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[18.03831877  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[13.31941352  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[10.19854837  1.01250658]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[88.36030284  3.31577987]]
# num points in clusters [[19. 11.]]
# centroid distance sums [[89.05558319  4.57578694]]
# num points in clusters [[18. 12.]]
# centroid distance sums [[6.70833121 2.40313445]]
# num points in clusters [[21.  9.]]
# centroid distance sums [[94.85751887  0.33259851]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[16.42709576  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.70077231 17.31028366]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[24.31560512  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.21413112  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[20.82879316  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.91867629  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[10.04593045  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[4.65729828 1.38966229]]
# num points in clusters [[24.  6.]]
# centroid distance sums [[3.06738342 5.18338434]]
# num points in clusters [[13. 17.]]
# centroid distance sums [[5.71587372 1.83794397]]
# num points in clusters [[23.  7.]]
# centroid distance sums [[7.75490642 0.5971964 ]]
# num points in clusters [[28.  2.]]
# centroid distance sums [[11.37483712  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[15.07332714  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.51382455  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[25.0871296  0.       ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[24.55277543  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[23.38018975  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.37347086  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[9.12520893 0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[6.66025803 0.20041115]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[7.04626534 0.42290762]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[8.00878091 0.18526076]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[10.99080347  0.36638613]]
# num points in clusters [[29.  1.]]
# centroid distance sums [[8.86444473 0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[16.06758881  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[19.81758509  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[25.15161424  0.        ]]
# num points in clusters [[30.  0.]]
# centroid distance sums [[27.99561405  0.        ]]
# num points in clusters [[30.  0.]]
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# ...
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# centroid distance sums [[ 0.         24.87029813]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         22.72651811]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         19.83532518]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         17.26093478]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[0.         9.41930442]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[6.98647512 3.53435764]]
# num points in clusters [[17. 13.]]
# centroid distance sums [[4.42869742 5.29093255]]
# num points in clusters [[11. 19.]]
# centroid distance sums [[3.55241041 6.54127611]]
# num points in clusters [[10. 20.]]
# centroid distance sums [[ 0.52696109 10.86398338]]
# num points in clusters [[ 2. 28.]]
# centroid distance sums [[ 0.         13.89779911]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         20.58975813]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         25.47287835]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         24.90741156]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         26.37435686]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         21.84169056]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         15.58116421]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         11.48794479]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[0.6198974  9.15847538]]
# num points in clusters [[ 2. 28.]]
# centroid distance sums [[5.85333138 3.82048435]]
# num points in clusters [[16. 14.]]
# centroid distance sums [[1.06075194 6.64956951]]
# num points in clusters [[ 3. 27.]]
# centroid distance sums [[3.00381097 5.52554112]]
# num points in clusters [[ 9. 21.]]
# centroid distance sums [[ 0.         12.32714989]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         20.58438579]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         21.23781073]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         25.03951853]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         22.93092552]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.         20.08095288]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[ 0.        17.2973341]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[0.         9.77565156]]
# num points in clusters [[ 0. 30.]]
# centroid distance sums [[1.02376314 7.92049319]]
# num points in clusters [[ 3. 26.]]
# centroid distance sums [[4.0081482  5.93501582]]
# num points in clusters [[10. 19.]]
# centroid distance sums [[2.16561803 8.24801912]]
# num points in clusters [[ 6. 23.]]
# centroid distance sums [[0.26699112 9.70798792]]
# num points in clusters [[ 1. 28.]]
# centroid distance sums [[ 0.         15.60981453]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         16.82059926]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         19.54602628]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         23.00219715]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         24.82884664]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         24.41822727]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         20.02068714]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 0.         12.78062022]]
# num points in clusters [[ 0. 29.]]
# centroid distance sums [[ 1.31903329 10.89792797]]
# num points in clusters [[ 3. 26.]]
# centroid distance sums [[3.2744681  7.76799453]]
# num points in clusters [[ 9. 20.]]
# [False, False, False, False, False, True, True, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False]
# [False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, True, True, True, True, True, True, False, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, False, False, False, True, True, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, True, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False]
# yearly mean FPR: 0.05654761904761905
# yearly mean detection accuracy: 0.04411764705882353
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\mssw\mssw.py:69: RuntimeWarning: invalid value encountered in divide
#   Av_c = np.divide(centroid_distance_sums, num_points_in_clusters)
