# %% [markdown]
# # Evaluation of UCDD on AGRAW2

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# ## AGRAW2 dataset locations

# %%
abrupt_agraw2_path = '../Datasets_concept_drift/synthetic_data/abrupt_drift/agraw2_1_abrupt_drift_0_noise_balanced.arff'
gradual_agraw2_paths = [
    '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_05.arff',
    '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_1.arff',
    '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_5.arff',
    '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_10.arff',
    '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_20.arff'
]

all_agraw2_data_paths = [abrupt_agraw2_path] + gradual_agraw2_paths

# %% [markdown]
# ## Accept and preprocess AGRAW2 datasets

# %%
from eval_helpers import accepting
from sklearn.preprocessing import MinMaxScaler
from category_encoders import TargetEncoder
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split


agraw2_exclude_reference_batches = {}
agraw2_exclude_testing_batches = {}
agraw2_onehot_reference_batches = {}
agraw2_onehot_testing_batches = {}
agraw2_target_reference_batches = {}
agraw2_target_testing_batches = {}

agraw2_reference_label_batches = {}
agraw2_testing_label_batches = {}

# agraw2 with categories excluded
for file_path in all_agraw2_data_paths:
    df_x, df_y = accepting.get_clean_df(file_path)
    df_y = pd.DataFrame(LabelEncoder().fit_transform(df_y))

    df_x_ref, df_x_test, df_y_ref, df_y_test = sklearn.model_selection.train_test_split(
        df_x, df_y, test_size=0.7, shuffle=False)

    reference_labels = df_y_ref.to_numpy()
    testing_labels = df_y_test.to_numpy()
    
    df_x_ref_num, df_x_ref_cat = accepting.divide_numeric_categorical(df_x_ref)
    df_x_test_num, df_x_test_cat = accepting.divide_numeric_categorical(df_x_test)
    
    reference_data = df_x_ref_num.to_numpy()
    testing_data = df_x_test_num.to_numpy()
    scaler = MinMaxScaler()
    scaler.fit(reference_data)
    reference_data = scaler.transform(reference_data)
    testing_data = scaler.transform(testing_data)
    
    num_ref_batches = 3
    num_test_batches = 7
    ref_batches = np.array_split(reference_data, num_ref_batches)
    ref_label_batches = np.array_split(reference_labels, num_ref_batches)
    test_batches = np.array_split(testing_data, num_test_batches)
    test_label_batches = np.array_split(testing_labels, num_test_batches)
    
    agraw2_exclude_reference_batches[file_path] = ref_batches
    agraw2_reference_label_batches[file_path] = ref_label_batches
    agraw2_exclude_testing_batches[file_path] = test_batches
    agraw2_testing_label_batches[file_path] = test_label_batches
    
print('agraw2 exclude')
print(agraw2_exclude_reference_batches)
print(agraw2_exclude_testing_batches)

# agraw2 with categories onehot encoded
for file_path in all_agraw2_data_paths:
    df_x, df_y = accepting.get_clean_df(file_path)
    df_y = pd.DataFrame(LabelEncoder().fit_transform(df_y))

    df_x_ref, df_x_test, df_y_ref, df_y_test = sklearn.model_selection.train_test_split(
        df_x, df_y, test_size=0.7, shuffle=False)
    
    df_x_ref_num, df_x_ref_cat = accepting.divide_numeric_categorical(df_x_ref)
    df_x_test_num, df_x_test_cat = accepting.divide_numeric_categorical(df_x_test)
    
    ref_index = df_x_ref_cat.index
    test_index = df_x_test_cat.index
    encoder = OneHotEncoder(sparse=False)
    encoder.fit(df_x_ref_cat)
    df_x_ref_cat_transformed = pd.DataFrame(encoder.transform(df_x_ref_cat))
    df_x_test_cat_transformed = pd.DataFrame(encoder.transform(df_x_test_cat))
    df_x_ref_cat_transformed.set_index(ref_index, inplace=True)
    df_x_test_cat_transformed.set_index(test_index, inplace=True)
    
    reference_data = df_x_ref_num.join(df_x_ref_cat_transformed, lsuffix='_num').to_numpy()
    testing_data = df_x_test_num.join(df_x_test_cat_transformed, lsuffix='_num').to_numpy()
    scaler = MinMaxScaler()
    scaler.fit(reference_data)
    reference_data = scaler.transform(reference_data)
    testing_data = scaler.transform(testing_data)
    
    num_ref_batches = 3
    num_test_batches = 7
    ref_batches = np.array_split(reference_data, num_ref_batches)
    test_batches = np.array_split(testing_data, num_test_batches)
    
    agraw2_onehot_reference_batches[file_path] = ref_batches
    agraw2_onehot_testing_batches[file_path] = test_batches
    
print('agraw2 onehot')
print(agraw2_onehot_reference_batches)
print(agraw2_onehot_testing_batches)

# agraw2 with categories target encoded
for file_path in all_agraw2_data_paths:
    df_x, df_y = accepting.get_clean_df(file_path)
    df_y = pd.DataFrame(LabelEncoder().fit_transform(df_y))

    df_x_ref, df_x_test, df_y_ref, df_y_test = sklearn.model_selection.train_test_split(
        df_x, df_y, test_size=0.7, shuffle=False)
    
    df_x_ref_num, df_x_ref_cat = accepting.divide_numeric_categorical(df_x_ref)
    df_x_test_num, df_x_test_cat = accepting.divide_numeric_categorical(df_x_test)
    
    ref_index = df_x_ref_cat.index
    test_index = df_x_test_cat.index
    encoder = TargetEncoder()
    encoder.fit(df_x_ref_cat, df_y_ref)
    df_x_ref_cat_transformed = pd.DataFrame(encoder.transform(df_x_ref_cat))
    df_x_test_cat_transformed = pd.DataFrame(encoder.transform(df_x_test_cat))
    df_x_ref_cat_transformed.set_index(ref_index, inplace=True)
    df_x_test_cat_transformed.set_index(test_index, inplace=True)
    
    reference_data = df_x_ref_num.join(df_x_ref_cat_transformed, lsuffix='_num').to_numpy()
    testing_data = df_x_test_num.join(df_x_test_cat_transformed, lsuffix='_num').to_numpy()
    scaler = MinMaxScaler()
    scaler.fit(reference_data)
    reference_data = scaler.transform(reference_data)
    testing_data = scaler.transform(testing_data)
    
    num_ref_batches = 3
    num_test_batches = 7
    ref_batches = np.array_split(reference_data, num_ref_batches)
    test_batches = np.array_split(testing_data, num_test_batches)
    
    agraw2_target_reference_batches[file_path] = ref_batches
    agraw2_target_testing_batches[file_path] = test_batches
    
print('agraw2 target')
print(agraw2_target_reference_batches)
print(agraw2_target_testing_batches)
# Out:
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\jpohl\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\accepting.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].str.decode('utf-8')
# c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# agraw2 exclude
# {'../Datasets_concept_drift/synthetic_data/abrupt_drift/agraw2_1_abrupt_drift_0_noise_balanced.arff': [array([[0.29406669, 0.57232188, 0.95      , 0.40768475, 0.79310345,
#         0.76167558],
#        [0.274077  , 0.29819404, 0.11666667, 0.49264216, 0.27586207,
#         0.54039634],
#        [0.97390317, 0.        , 0.1       , 0.23755869, 0.27586207,
#         0.9498421 ],
#        ...,
#        [0.03719466, 0.95578652, 0.31666667
#         0.60849133]]), array([[0.1048706 , 0.46568062, 0.41666667, ..., 0.        , 0.33962982,
#         0.57418835],
#        [0.36542486, 0.59429207, 0.98333333, ..., 0.46089599, 0.57887399,
#         0.5306947 ],
#        [0.73463034, 0.        , 0.63333333, ..., 1.        , 0.26761302,
#         0.40045072],
#        ...,
#        [0.02320063, 0.26157794, 0.21666667, ..., 0.        , 0.        ,
#         0.51993415],
#        [0.08005606, 0.60276029, 0.61666667, ..., 0.49459267, 0.36443839,
#         0.89628827],
#        [0.99465221, 0.        , 0.        , ..., 1.        , 0.09419731,
#         0.89628827]]), array([[0.49267422, 0.        , 0.36666667, ..., 1.        , 0.98045444,
#         0.51993415],
#        [0.56440349, 0.        , 0.31666667, ..., 0.46089599, 0.63503839,
#         0.89628827],
#        [0.15517483, 0.63549706, 0.45      , ..., 0.49459267, 0.36443839,
#         0.60849133],
#        ...,
#        [0.83050799, 0.        , 0.65      , ..., 0.49459267, 0.26761302,
#         0.51993415],
#        [0.29347676, 0.73035018, 0.76666667, ..., 0.        , 0.33962982,
#         0.60849133],
#        [0.77402671, 0.        , 0.65      , ..., 0.49459267, 0.24513319,
#         1.        ]])]}

# %% [markdown]
# ## Helper function

# %%
from eval_helpers import kmeans_verbose_helpers


def write_kmeans_results_ucdd_helper(output_filename_no_extension, ref_batches, n_init, max_iter, tol, random_state):
    # dummy = [np.asarray(1), np.asarray(2), np.asarray(3)]
    combinations = []
    for i in range(3):
    #     combinations.append(np.vstack((dummy[i], dummy[(i + 1) % 3])))
        combinations.append(np.vstack((ref_batches[i], ref_batches[(i + 1) % 3])))
        
    all_results_from_combinations = []
    for i, combination in enumerate(combinations):
        filename = output_filename_no_extension + str(i) + '.txt'
        print('filename', filename)
        kmeans_verbose_helpers.write_verbose_kmeans_to_file(result_filename=output_filename_no_extension + str(i) + '.txt',
                                     data_to_cluster=combination,
                                     n_clusters=2, n_init=n_init, max_iter=max_iter, tol=tol, random_state=random_state)
        output_dicts = kmeans_verbose_helpers.convert_kmeans_output_file_to_dicts(filename, n_init=n_init)
        all_results_from_combinations.append(output_dicts)
        kmeans_verbose_helpers.print_stats_from_kmeans_output_dicts(output_dicts)
        
    kmeans_verbose_helpers.print_stats_from_all_combinations(all_results_from_combinations)
# Out:
# something

# %% [markdown]
# ## AGRAW2 with categories excluded

# %% [markdown]
# ### Find the best tol and max_iter (the drift type is irrelevant)

# %%
write_kmeans_results_ucdd_helper('agraw2_exclude_new_output', agraw2_exclude_reference_batches[abrupt_agraw2_path],
                                 n_init=100, max_iter=500, tol=0,
                                 random_state=1053)
# Out:
# filename agraw2_exclude_new_output0.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 18
# minimum initial inertia: 9083.316503699725
# maximum initial inertia: 17483.991310771078
# number of unique final inertia values: 2
# minimum final inertia: 7136.6496570932595
# maximum final inertia: 7136.64965709326
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_exclude_new_output1.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 26
# minimum initial inertia: 9259.811965492709
# maximum initial inertia: 17336.6024958001
# number of unique final inertia values: 4
# minimum final inertia: 7151.44522595734
# maximum final inertia: 7151.445344936363
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_exclude_new_output2.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 43
# minimum initial inertia: 9921.162773453152
# maximum initial inertia: 15649.896005753346
# number of unique final inertia values: 5
# minimum final inertia: 7134.465735805579
# maximum final inertia: 7134.465872583175
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# {'total_max_iterations': 43, 'total_min_init_inertia': 9083.316503699725, 'total_max_init_inertia': 17483.991310771078, 'total_min_final_inertia': 7134.465735805579, 'total_max_final_inertia': 7151.445344936363, 'total_num_convergences': 300, 'total_num_strict_convergences': 300, 'total_num_tol_based_convergences': 0}

# %% [markdown]
# ### Use them for the analysis

# %%
from core import ucdd_eval


agraw2_exclude_stats = {}
    
for agraw2_path in all_agraw2_data_paths:
    runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
        ucdd_eval.all_drifting_batches_randomness_robust(
        agraw2_exclude_reference_batches[agraw2_path],
        agraw2_exclude_testing_batches[agraw2_path],
        min_ref_batches_drift=0.3,
        additional_check=True,
        n_init=100,
        max_iter=43000,
        tol=0,
        true_drift_idx=2,
        min_runs=2
    )
    agraw2_exclude_stats[agraw2_path] = {
        'runs_results_bool': runs_results_bool,
        'final_fpr_mean': final_fpr_mean,
        'fpr_std_err': fpr_std_err,
        'final_latency_mean': final_latency_mean,
        'latency_std_err': latency_std_err
    }

print('agraw2 STATS')
print(agraw2_exclude_stats)
# Out:
# train_batch_strategy TrainBatchStrategies.SUBMAJORITY
# random_state
# 0
# n_init 100 max_iter 43000 tol 0
# n_init 100 max_iter 43000 tol 0
# n_init 100 max_iter 43000 tol 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       6 agraw2_exclude_stats = {}
#       8 for agraw2_path in all_agraw2_data_paths:
#       9     runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
# ---> 10         ucdd_eval.all_drifting_batches_randomness_robust(
#      11         agraw2_exclude_reference_batches[agraw2_path],
#      12         agraw2_exclude_testing_batches[agraw2_path],
#      13         train_batch_strategy=spms.TrainBatchStrategies.SUBMAJORITY,
#      14         additional_check=True,
#      15         n_init=100,
#      16         max_iter=43000,
#      17         tol=0,
#      18         true_drift_idx=2,
#      19         min_runs=2
#      20     )
#      21     agraw2_exclude_stats[agraw2_path] = {
#      22         'runs_results_bool': runs_results_bool,
#      23         'final_fpr_mean': final_fpr_mean,
#    (...)
#      26         'latency_std_err': latency_std_err
#      27     }
#      29 print('agraw2 STATS')
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd_eval.py:57, in all_drifting_batches_randomness_robust(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, true_drift_idx, first_random_state, min_runs, std_err_threshold)
#      55 while num_runs < min_runs or max(fpr_std_err, latency_std_err) > std_err_threshold:
#      56     print('train_batch_strategy', train_batch_strategy)
# ---> 57     drifting_batches_bool = ucdd.all_drifting_batches(
#      58         reference_data_batches,
#      59         testing_data_batches,
#      60         train_batch_strategy=train_batch_strategy,
#      61         additional_check=additional_check,
#      62         n_init=n_init,
#      63         max_iter=max_iter,
#      64         tol=tol,
#      65         random_state=random_state
#      66     )
#      67     # print('drifting_batches_bool')
#      68     # print(drifting_batches_bool)
#      69     drift_locations = np.arange(len(drifting_batches_bool))[drifting_batches_bool]
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:189, in all_drifting_batches(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, random_state)
#     187 num_ref_drifts = 0 # how many training batches signal drift against this testing batch
#     188 for j, ref_window in enumerate(reference_data_batches):
# --> 189     drift_here = concept_drift_detected(
#     190         ref_window, test_window, additional_check, n_init, max_iter, tol, random_state)
#     191     if drift_here:
#     192         num_ref_drifts += 1
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:145, in concept_drift_detected(ref_window, test_window, additional_check, n_init, max_iter, tol, random_state, threshold, debug)
#     142 beta_minus, beta_minus_additional = compute_beta(
#     143     ref_plus, ref_minus, test_minus)
#     144 if debug: print('BETA PLUS (ref-, ref+, test+)')
# --> 145 beta_plus, beta_plus_additional = compute_beta(
#     146     ref_minus, ref_plus, test_plus)
#     148 drift = (beta_plus < threshold or beta_minus < threshold)
#     149 if additional_check:
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:102, in compute_beta(u, v0, v1, beta_x, debug)
#      90 def compute_beta(u, v0, v1, beta_x=0.5, debug=False):
#      91     """
#      92     Find neighbors and compute beta based on u, v0, v1
#      93
#    (...)
#     100         beta_additional - the beta cdf value for exchanged numbers of neighbours as parameters)
#     101     """
# --> 102     w0 = compute_neighbors(u, v0, 'v0')
#     103     w1 = compute_neighbors(u, v1, 'v1')
#     104     if debug: print('neighbors in W0', len(w0))
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:82, in compute_neighbors(u, v, debug_string)
#      79 neigh = NearestNeighbors(n_neighbors=1, n_jobs=-1)
#      80 neigh.fit(v)
# ---> 82 neigh_ind_v = neigh.kneighbors(u, return_distance=False)
#      83 # print('neigh_ind_' + debug_string, neigh_ind_v)
#      84 unique_v_neighbor_indices = np.unique(neigh_ind_v)
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\neighbors\_base.py:814, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     808     if issparse(X):
#     809         raise ValueError(
#     810             "%s does not work with sparse matrices. Densify the data, "
#     811             "or set algorithm='brute'"
#     812             % self._fit_method
#     813         )
# --> 814     chunked_results = Parallel(n_jobs, prefer="threads")(
#     815         delayed(_tree_query_parallel_helper)(
#     816             self._tree, X[s], n_neighbors, return_distance
#     817         )
#     818         for s in gen_even_slices(X.shape[0], n_jobs)
#     819     )
#     820 else:
#     821     raise ValueError("internal: _fit_method not recognized")
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~\AppData\Local\Programs\Python\Python39\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the obtained results to csv

# %%
from eval_helpers import helpers


final_result_dict = {
    'type_of_data': [], 'dataset': [], 'drift': [], 'width': [], 'encoding': [],
    'min_ref_batches_drift': [], 'additional_check': [],
    'n_init': [], 'max_iter': [], 'tol': [],
    'FPR_mean': [], 'latency_mean': []
}

for data_path, stats_dict in agraw2_exclude_stats.items():
    synthetic_filename_info = helpers.synthetic_data_information(data_path)
    encoding = 'exclude'
    fpr_mean = float(stats_dict['final_fpr_mean'])
    latency_mean = float(stats_dict['final_latency_mean'])
    
    final_result_dict['type_of_data'].append(synthetic_filename_info['type_of_data'])
    final_result_dict['dataset'].append(synthetic_filename_info['dataset_name'])
    final_result_dict['drift'].append(synthetic_filename_info['drift_type'])
    final_result_dict['width'].append(synthetic_filename_info['drift_width'])
    final_result_dict['encoding'].append(encoding)
    final_result_dict['min_ref_batches_drift'].append(0.3)
    final_result_dict['additional_check'].append('yes')
    final_result_dict['n_init'].append(100)
    final_result_dict['max_iter'].append(43000)
    final_result_dict['tol'].append(0)
    final_result_dict['FPR_mean'].append(fpr_mean)
    final_result_dict['latency_mean'].append(latency_mean)
    
final_result_df = pd.DataFrame.from_dict(final_result_dict)
sorted_final_result_df = final_result_df.sort_values(['drift', 'dataset', 'encoding', 'width'])
final_result_df.to_csv('agraw2_exclude_jupyter_results.csv', index=False)

# %% [markdown]
# ### Inspect clusters to obtain meaning

# %%
from core import ucdd
import importlib
importlib.reload(ucdd)

ucdd.all_drifting_batches(
    agraw2_exclude_reference_batches[abrupt_agraw2_path],
    agraw2_exclude_testing_batches[abrupt_agraw2_path],
    min_ref_batches_drift=0.3,
    additional_check=True,
    n_init=100,
    max_iter=77000,
    tol=0,
    parallel=False,
    reference_label_batches=agraw2_reference_label_batches[abrupt_agraw2_path],
    testing_label_batches=agraw2_testing_label_batches[abrupt_agraw2_path],
    debug=True
)
# Out:
# random_state
# None
#
#
# #### TEST BATCH 0 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5761
# actual class 1 percentage in the ref plus cluster: 57.2643638257247
# actual class 0 percentage in the ref plus cluster: 42.7356361742753
# number of points in the ref minus cluster: 4239
# actual class 1 percentage in the ref minus cluster: 40.12738853503185
# actual class 0 percentage in the ref minus cluster: 59.87261146496815
# number of points in the test plus cluster: 5826
# actual class 1 percentage in the test plus cluster: 56.96876072777206
# actual class 0 percentage in the test plus cluster: 43.03123927222794
# number of points in the test minus cluster: 4174
# actual class 1 percentage in the test minus cluster: 40.27311931001437
# actual class 0 percentage in the test minus cluster: 59.72688068998563
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 342
# neighbors in W1 339
# beta 0.4542103519415852
# beta additional 0.5457896480584148
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 169
# neighbors in W1 177
# beta 0.6666277779659813
# beta additional 0.3333722220340187
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4363
# actual class 1 percentage in the ref plus cluster: 41.18725647490259
# actual class 0 percentage in the ref plus cluster: 58.81274352509741
# number of points in the ref minus cluster: 5637
# actual class 1 percentage in the ref minus cluster: 56.821004080184494
# actual class 0 percentage in the ref minus cluster: 43.178995919815506
# number of points in the test plus cluster: 4169
# actual class 1 percentage in the test plus cluster: 40.24946030223075
# actual class 0 percentage in the test plus cluster: 59.75053969776925
# number of points in the test minus cluster: 5831
# actual class 1 percentage in the test minus cluster: 56.97135997256045
# actual class 0 percentage in the test minus cluster: 43.02864002743955
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 165
# neighbors in W1 181
# beta 0.8054791427045094
# beta additional 0.19452085729549068
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 319
# neighbors in W1 329
# beta 0.6528763176870302
# beta additional 0.34712368231296975
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5797
# actual class 1 percentage in the ref plus cluster: 56.184233224081424
# actual class 0 percentage in the ref plus cluster: 43.815766775918576
# number of points in the ref minus cluster: 4203
# actual class 1 percentage in the ref minus cluster: 41.47037830121342
# actual class 0 percentage in the ref minus cluster: 58.52962169878658
# number of points in the test plus cluster: 5832
# actual class 1 percentage in the test plus cluster: 56.96159122085048
# actual class 0 percentage in the test plus cluster: 43.03840877914952
# number of points in the test minus cluster: 4168
# actual class 1 percentage in the test minus cluster: 40.25911708253359
# actual class 0 percentage in the test minus cluster: 59.74088291746641
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 351
# neighbors in W1 325
# beta 0.15847616232891457
# beta additional 0.8415238376710854
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 184
# neighbors in W1 168
# beta 0.19656326320741518
# beta additional 0.8034367367925848
# drift: False
#
#
# #### TEST BATCH 1 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5758
# actual class 1 percentage in the ref plus cluster: 57.27683223341438
# actual class 0 percentage in the ref plus cluster: 42.72316776658562
# number of points in the ref minus cluster: 4242
# actual class 1 percentage in the ref minus cluster: 40.122583686940125
# actual class 0 percentage in the ref minus cluster: 59.877416313059875
# number of points in the test plus cluster: 5645
# actual class 1 percentage in the test plus cluster: 57.04162976085031
# actual class 0 percentage in the test plus cluster: 42.95837023914969
# number of points in the test minus cluster: 4355
# actual class 1 percentage in the test minus cluster: 40.872560275545354
# actual class 0 percentage in the test minus cluster: 59.127439724454646
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 336
# neighbors in W1 346
# beta 0.6491997021687657
# beta additional 0.3508002978312344
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 166
# neighbors in W1 180
# beta 0.7744718770134267
# beta additional 0.22552812298657338
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5641
# actual class 1 percentage in the ref plus cluster: 56.81616734621521
# actual class 0 percentage in the ref plus cluster: 43.18383265378479
# number of points in the ref minus cluster: 4359
# actual class 1 percentage in the ref minus cluster: 41.179169534296854
# actual class 0 percentage in the ref minus cluster: 58.820830465703146
# number of points in the test plus cluster: 5653
# actual class 1 percentage in the test plus cluster: 57.049354325137095
# actual class 0 percentage in the test plus cluster: 42.950645674862905
# number of points in the test minus cluster: 4347
# actual class 1 percentage in the test minus cluster: 40.83275822406257
# actual class 0 percentage in the test minus cluster: 59.16724177593743
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 320
# neighbors in W1 354
# beta 0.9050238050255134
# beta additional 0.09497619497448662
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 165
# neighbors in W1 186
# beta 0.8691890313464418
# beta additional 0.13081096865355826
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4201
# actual class 1 percentage in the ref plus cluster: 41.49012139966675
# actual class 0 percentage in the ref plus cluster: 58.50987860033325
# number of points in the ref minus cluster: 5799
# actual class 1 percentage in the ref minus cluster: 56.16485600965684
# actual class 0 percentage in the ref minus cluster: 43.83514399034316
# number of points in the test plus cluster: 4348
# actual class 1 percentage in the test plus cluster: 40.84636614535419
# actual class 0 percentage in the test plus cluster: 59.15363385464581
# number of points in the test minus cluster: 5652
# actual class 1 percentage in the test minus cluster: 57.04175513092711
# actual class 0 percentage in the test minus cluster: 42.95824486907289
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 181
# neighbors in W1 179
# beta 0.45797698404728643
# beta additional 0.5420230159527135
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 346
# neighbors in W1 358
# beta 0.6745620828601198
# beta additional 0.3254379171398803
# drift: False
#
#
# #### TEST BATCH 2 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.01
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 4246
# actual class 1 percentage in the ref plus cluster: 40.0847856806406
# actual class 0 percentage in the ref plus cluster: 59.9152143193594
# number of points in the ref minus cluster: 5754
# actual class 1 percentage in the ref minus cluster: 57.31664928745221
# actual class 0 percentage in the ref minus cluster: 42.68335071254779
# number of points in the test plus cluster: 4169
# actual class 1 percentage in the test plus cluster: 45.142720076757016
# actual class 0 percentage in the test plus cluster: 54.857279923242984
# number of points in the test minus cluster: 5831
# actual class 1 percentage in the test minus cluster: 53.48996741553764
# actual class 0 percentage in the test minus cluster: 46.51003258446236
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 165
# neighbors in W1 168
# beta 0.5653729479998191
# beta additional 0.4346270520001809
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 335
# neighbors in W1 308
# beta 0.14329694028149254
# beta additional 0.8567030597185075
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 5633
# actual class 1 percentage in the ref plus cluster: 56.861352742765845
# actual class 0 percentage in the ref plus cluster: 43.138647257234155
# number of points in the ref minus cluster: 4367
# actual class 1 percentage in the ref minus cluster: 41.14953057018548
# actual class 0 percentage in the ref minus cluster: 58.85046942981452
# number of points in the test plus cluster: 5839
# actual class 1 percentage in the test plus cluster: 53.48518581948964
# actual class 0 percentage in the test plus cluster: 46.51481418051036
# number of points in the test minus cluster: 4161
# actual class 1 percentage in the test minus cluster: 45.133381398702234
# actual class 0 percentage in the test minus cluster: 54.866618601297766
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 322
# neighbors in W1 324
# beta 0.5313802017863423
# beta additional 0.4686197982136578
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 160
# neighbors in W1 165
# beta 0.6093830948469059
# beta additional 0.3906169051530941
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 4206
# actual class 1 percentage in the ref plus cluster: 41.41702330004755
# actual class 0 percentage in the ref plus cluster: 58.58297669995245
# number of points in the ref minus cluster: 5794
# actual class 1 percentage in the ref minus cluster: 56.23058336209872
# actual class 0 percentage in the ref minus cluster: 43.76941663790128
# number of points in the test plus cluster: 4163
# actual class 1 percentage in the test plus cluster: 45.111698294499156
# actual class 0 percentage in the test plus cluster: 54.888301705500844
# number of points in the test minus cluster: 5837
# actual class 1 percentage in the test minus cluster: 53.50351207812232
# actual class 0 percentage in the test minus cluster: 46.49648792187768
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 172
# neighbors in W1 174
# beta 0.5428635578026657
# beta additional 0.4571364421973343
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 349
# neighbors in W1 315
# beta 0.09332175510842614
# beta additional 0.9066782448915739
# drift: False
#
#
# #### TEST BATCH 3 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4255
# actual class 1 percentage in the ref plus cluster: 40.09400705052879
# actual class 0 percentage in the ref plus cluster: 59.90599294947121
# number of points in the ref minus cluster: 5745
# actual class 1 percentage in the ref minus cluster: 57.33681462140992
# actual class 0 percentage in the ref minus cluster: 42.66318537859008
# number of points in the test plus cluster: 4197
# actual class 1 percentage in the test plus cluster: 50.08339289969025
# actual class 0 percentage in the test plus cluster: 49.91660710030975
# number of points in the test minus cluster: 5803
# actual class 1 percentage in the test minus cluster: 49.93968636911942
# actual class 0 percentage in the test minus cluster: 50.06031363088058
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 162
# neighbors in W1 173
# beta 0.7263452953593112
# beta additional 0.2736547046406887
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 327
# neighbors in W1 354
# beta 0.8497616445389933
# beta additional 0.15023835546100672
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5637
# actual class 1 percentage in the ref plus cluster: 56.83874401277275
# actual class 0 percentage in the ref plus cluster: 43.16125598722725
# number of points in the ref minus cluster: 4363
# actual class 1 percentage in the ref minus cluster: 41.164336465734586
# actual class 0 percentage in the ref minus cluster: 58.835663534265414
# number of points in the test plus cluster: 5818
# actual class 1 percentage in the test plus cluster: 49.96562392574768
# actual class 0 percentage in the test plus cluster: 50.03437607425232
# number of points in the test minus cluster: 4182
# actual class 1 percentage in the test minus cluster: 50.04782400765184
# actual class 0 percentage in the test minus cluster: 49.95217599234816
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 321
# neighbors in W1 348
# beta 0.851912940719114
# beta additional 0.14808705928088592
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 161
# neighbors in W1 161
# beta 0.49999999999999967
# beta additional 0.49999999999999967
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4207
# actual class 1 percentage in the ref plus cluster: 41.4071785120038
# actual class 0 percentage in the ref plus cluster: 58.5928214879962
# number of points in the ref minus cluster: 5793
# actual class 1 percentage in the ref minus cluster: 56.240290005178665
# actual class 0 percentage in the ref minus cluster: 43.759709994821335
# number of points in the test plus cluster: 4183
# actual class 1 percentage in the test plus cluster: 50.059765718383936
# actual class 0 percentage in the test plus cluster: 49.940234281616064
# number of points in the test minus cluster: 5817
# actual class 1 percentage in the test minus cluster: 49.957022520199416
# actual class 0 percentage in the test minus cluster: 50.042977479800584
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 172
# neighbors in W1 157
# beta 0.20378726921028567
# beta additional 0.7962127307897143
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 350
# neighbors in W1 345
# beta 0.42474257139657223
# beta additional 0.5752574286034278
# drift: False
#
#
# #### TEST BATCH 4 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4250
# actual class 1 percentage in the ref plus cluster: 40.09411764705882
# actual class 0 percentage in the ref plus cluster: 59.90588235294118
# number of points in the ref minus cluster: 5750
# actual class 1 percentage in the ref minus cluster: 57.321739130434786
# actual class 0 percentage in the ref minus cluster: 42.678260869565214
# number of points in the test plus cluster: 4235
# actual class 1 percentage in the test plus cluster: 50.01180637544274
# actual class 0 percentage in the test plus cluster: 49.98819362455726
# number of points in the test minus cluster: 5765
# actual class 1 percentage in the test minus cluster: 49.991326973113615
# actual class 0 percentage in the test minus cluster: 50.008673026886385
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 163
# neighbors in W1 170
# beta 0.649544977635748
# beta additional 0.35045502236425197
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 334
# neighbors in W1 330
# beta 0.43828135920025085
# beta additional 0.5617186407997492
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5638
# actual class 1 percentage in the ref plus cluster: 56.79318907413977
# actual class 0 percentage in the ref plus cluster: 43.20681092586023
# number of points in the ref minus cluster: 4362
# actual class 1 percentage in the ref minus cluster: 41.219624025676296
# actual class 0 percentage in the ref minus cluster: 58.780375974323704
# number of points in the test plus cluster: 5779
# actual class 1 percentage in the test plus cluster: 49.99134798408029
# actual class 0 percentage in the test plus cluster: 50.00865201591971
# number of points in the test minus cluster: 4221
# actual class 1 percentage in the test minus cluster: 50.01184553423359
# actual class 0 percentage in the test minus cluster: 49.98815446576641
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 318
# neighbors in W1 324
# beta 0.5936547715719809
# beta additional 0.4063452284280192
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 163
# neighbors in W1 180
# beta 0.8210095117037601
# beta additional 0.1789904882962398
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4202
# actual class 1 percentage in the ref plus cluster: 41.45644930985245
# actual class 0 percentage in the ref plus cluster: 58.54355069014755
# number of points in the ref minus cluster: 5798
# actual class 1 percentage in the ref minus cluster: 56.19179027250776
# actual class 0 percentage in the ref minus cluster: 43.80820972749224
# number of points in the test plus cluster: 4224
# actual class 1 percentage in the test plus cluster: 50.02367424242424
# actual class 0 percentage in the test plus cluster: 49.97632575757576
# number of points in the test minus cluster: 5776
# actual class 1 percentage in the test minus cluster: 49.982686980609415
# actual class 0 percentage in the test minus cluster: 50.017313019390585
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 175
# neighbors in W1 172
# beta 0.43595100558222405
# beta additional 0.564048994417776
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 347
# neighbors in W1 335
# beta 0.32283114535089
# beta additional 0.6771688546491099
# drift: False
#
#
# #### TEST BATCH 5 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4250
# actual class 1 percentage in the ref plus cluster: 40.07058823529412
# actual class 0 percentage in the ref plus cluster: 59.92941176470588
# number of points in the ref minus cluster: 5750
# actual class 1 percentage in the ref minus cluster: 57.33913043478261
# actual class 0 percentage in the ref minus cluster: 42.66086956521739
# number of points in the test plus cluster: 4095
# actual class 1 percentage in the test plus cluster: 50.476190476190474
# actual class 0 percentage in the test plus cluster: 49.523809523809526
# number of points in the test minus cluster: 5905
# actual class 1 percentage in the test minus cluster: 49.66977138018628
# actual class 0 percentage in the test minus cluster: 50.33022861981372
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 163
# neighbors in W1 182
# beta 0.8471821647089208
# beta additional 0.1528178352910792
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 336
# neighbors in W1 319
# beta 0.25311955223972216
# beta additional 0.7468804477602778
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5632
# actual class 1 percentage in the ref plus cluster: 56.88920454545455
# actual class 0 percentage in the ref plus cluster: 43.11079545454545
# number of points in the ref minus cluster: 4368
# actual class 1 percentage in the ref minus cluster: 41.11721611721612
# actual class 0 percentage in the ref minus cluster: 58.88278388278388
# number of points in the test plus cluster: 5914
# actual class 1 percentage in the test plus cluster: 49.71254649983091
# actual class 0 percentage in the test plus cluster: 50.28745350016909
# number of points in the test minus cluster: 4086
# actual class 1 percentage in the test minus cluster: 50.41605482134116
# actual class 0 percentage in the test minus cluster: 49.58394517865884
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 321
# neighbors in W1 316
# beta 0.42142947531774405
# beta additional 0.5785705246822559
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 163
# neighbors in W1 166
# beta 0.5657665564040657
# beta additional 0.43423344359593424
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4218
# actual class 1 percentage in the ref plus cluster: 41.39402560455192
# actual class 0 percentage in the ref plus cluster: 58.60597439544808
# number of points in the ref minus cluster: 5782
# actual class 1 percentage in the ref minus cluster: 56.278104462123835
# actual class 0 percentage in the ref minus cluster: 43.721895537876165
# number of points in the test plus cluster: 4087
# actual class 1 percentage in the test plus cluster: 50.452654758991926
# actual class 0 percentage in the test plus cluster: 49.547345241008074
# number of points in the test minus cluster: 5913
# actual class 1 percentage in the test minus cluster: 49.68713005242686
# actual class 0 percentage in the test minus cluster: 50.31286994757314
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 172
# neighbors in W1 169
# beta 0.43539352243821977
# beta additional 0.5646064775617803
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 345
# neighbors in W1 328
# beta 0.25599484124510025
# beta additional 0.7440051587548997
# drift: False
#
#
# #### TEST BATCH 6 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4251
# actual class 1 percentage in the ref plus cluster: 40.03763820277582
# actual class 0 percentage in the ref plus cluster: 59.96236179722418
# number of points in the ref minus cluster: 5749
# actual class 1 percentage in the ref minus cluster: 57.366498521481994
# actual class 0 percentage in the ref minus cluster: 42.633501478518006
# number of points in the test plus cluster: 4174
# actual class 1 percentage in the test plus cluster: 50.81456636320077
# actual class 0 percentage in the test plus cluster: 49.18543363679923
# number of points in the test minus cluster: 5826
# actual class 1 percentage in the test minus cluster: 49.416409200137316
# actual class 0 percentage in the test minus cluster: 50.583590799862684
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 164
# neighbors in W1 174
# beta 0.7069992228267689
# beta additional 0.29300077717323114
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 332
# neighbors in W1 313
# beta 0.22703044779869247
# beta additional 0.7729695522013076
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5632
# actual class 1 percentage in the ref plus cluster: 56.90696022727273
# actual class 0 percentage in the ref plus cluster: 43.09303977272727
# number of points in the ref minus cluster: 4368
# actual class 1 percentage in the ref minus cluster: 41.09432234432234
# actual class 0 percentage in the ref minus cluster: 58.90567765567766
# number of points in the test plus cluster: 5835
# actual class 1 percentage in the test plus cluster: 49.40874035989717
# actual class 0 percentage in the test plus cluster: 50.59125964010283
# number of points in the test minus cluster: 4165
# actual class 1 percentage in the test minus cluster: 50.82833133253301
# actual class 0 percentage in the test minus cluster: 49.17166866746699
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 322
# neighbors in W1 322
# beta 0.5000000000000003
# beta additional 0.5000000000000003
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 158
# neighbors in W1 166
# beta 0.6718543238938954
# beta additional 0.32814567610610457
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4211
# actual class 1 percentage in the ref plus cluster: 41.3203514604607
# actual class 0 percentage in the ref plus cluster: 58.6796485395393
# number of points in the ref minus cluster: 5789
# actual class 1 percentage in the ref minus cluster: 56.31369839350492
# actual class 0 percentage in the ref minus cluster: 43.68630160649508
# number of points in the test plus cluster: 4163
# actual class 1 percentage in the test plus cluster: 50.85275042036992
# actual class 0 percentage in the test plus cluster: 49.14724957963008
# number of points in the test minus cluster: 5837
# actual class 1 percentage in the test minus cluster: 49.39181086174405
# actual class 0 percentage in the test minus cluster: 50.60818913825595
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 165
# neighbors in W1 173
# beta 0.6684727995825253
# beta additional 0.3315272004174748
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 352
# neighbors in W1 338
# beta 0.29690907839405234
# beta additional 0.7030909216059477
# drift: False
# [False, False, False, False, False, False, False]

# %% [markdown]
# ## AGRAW2 with categories onehot encoded

# %% [markdown]
# ### Find the best tol and max_iter (the drift type is irrelevant)

# %%
write_kmeans_results_ucdd_helper('agraw2_onehot_new_output', agraw2_onehot_reference_batches[abrupt_agraw2_path],
                                 n_init=100, max_iter=500, tol=0,
                                 random_state=1053)
# Out:
# filename agraw2_onehot_new_output0.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 37
# minimum initial inertia: 105224.89101843184
# maximum initial inertia: 115951.42105576495
# number of unique final inertia values: 26
# minimum final inertia: 58603.13327212382
# maximum final inertia: 59998.38063075493
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_onehot_new_output1.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 23
# minimum initial inertia: 105204.7574983774
# maximum initial inertia: 117037.30512573832
# number of unique final inertia values: 18
# minimum final inertia: 58610.34054204606
# maximum final inertia: 60027.82838831125
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_onehot_new_output2.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 29
# minimum initial inertia: 105750.1773853434
# maximum initial inertia: 119165.58192970211
# number of unique final inertia values: 22
# minimum final inertia: 58525.073742665925
# maximum final inertia: 60276.19958720603
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# {'total_max_iterations': 37, 'total_min_init_inertia': 105204.7574983774, 'total_max_init_inertia': 119165.58192970211, 'total_min_final_inertia': 58525.073742665925, 'total_max_final_inertia': 60276.19958720603, 'total_num_convergences': 300, 'total_num_strict_convergences': 300, 'total_num_tol_based_convergences': 0}

# %% [markdown]
# ### Use them for the analysis

# %%
from core import ucdd_eval


agraw2_onehot_stats1 = {}

for agraw2_path in all_agraw2_data_paths:
    runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
        ucdd_eval.all_drifting_batches_randomness_robust(
        agraw2_onehot_reference_batches[agraw2_path],
        agraw2_onehot_testing_batches[agraw2_path],
        min_ref_batches_drift=0.3,
        additional_check=True,
        n_init=100,
        max_iter=37000,
        tol=0,
        true_drift_idx=2,
        min_runs=2
    )
    agraw2_onehot_stats1[agraw2_path] = {
        'runs_results_bool': runs_results_bool,
        'final_fpr_mean': final_fpr_mean,
        'fpr_std_err': fpr_std_err,
        'final_latency_mean': final_latency_mean,
        'latency_std_err': latency_std_err
    }

print('agraw2 STATS')
print(agraw2_onehot_stats1)
# Out:
# train_batch_strategy TrainBatchStrategies.SUBMAJORITY
# random_state
# 0
# n_init 100 max_iter 37000 tol 0
# n_init 100 max_iter 37000 tol 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       6 agraw2_onehot_stats1 = {}
#       8 for agraw2_path in all_agraw2_data_paths:
#       9     runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
# ---> 10         ucdd_eval.all_drifting_batches_randomness_robust(
#      11         agraw2_onehot_reference_batches[agraw2_path],
#      12         agraw2_onehot_testing_batches[agraw2_path],
#      13         train_batch_strategy=spms.TrainBatchStrategies.SUBMAJORITY,
#      14         additional_check=True,
#      15         n_init=100,
#      16         max_iter=37000,
#      17         tol=0,
#      18         true_drift_idx=2,
#      19         min_runs=2
#      20     )
#      21     agraw2_onehot_stats1[agraw2_path] = {
#      22         'runs_results_bool': runs_results_bool,
#      23         'final_fpr_mean': final_fpr_mean,
#    (...)
#      26         'latency_std_err': latency_std_err
#      27     }
#      29 print('agraw2 STATS')
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd_eval.py:57, in all_drifting_batches_randomness_robust(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, true_drift_idx, first_random_state, min_runs, std_err_threshold)
#      55 while num_runs < min_runs or max(fpr_std_err, latency_std_err) > std_err_threshold:
#      56     print('train_batch_strategy', train_batch_strategy)
# ---> 57     drifting_batches_bool = ucdd.all_drifting_batches(
#      58         reference_data_batches,
#      59         testing_data_batches,
#      60         train_batch_strategy=train_batch_strategy,
#      61         additional_check=additional_check,
#      62         n_init=n_init,
#      63         max_iter=max_iter,
#      64         tol=tol,
#      65         random_state=random_state
#      66     )
#      67     # print('drifting_batches_bool')
#      68     # print(drifting_batches_bool)
#      69     drift_locations = np.arange(len(drifting_batches_bool))[drifting_batches_bool]
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:189, in all_drifting_batches(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, random_state)
#     187 num_ref_drifts = 0 # how many training batches signal drift against this testing batch
#     188 for j, ref_window in enumerate(reference_data_batches):
# --> 189     drift_here = concept_drift_detected(
#     190         ref_window, test_window, additional_check, n_init, max_iter, tol, random_state)
#     191     if drift_here:
#     192         num_ref_drifts += 1
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:145, in concept_drift_detected(ref_window, test_window, additional_check, n_init, max_iter, tol, random_state, threshold, debug)
#     142 beta_minus, beta_minus_additional = compute_beta(
#     143     ref_plus, ref_minus, test_minus)
#     144 if debug: print('BETA PLUS (ref-, ref+, test+)')
# --> 145 beta_plus, beta_plus_additional = compute_beta(
#     146     ref_minus, ref_plus, test_plus)
#     148 drift = (beta_plus < threshold or beta_minus < threshold)
#     149 if additional_check:
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:103, in compute_beta(u, v0, v1, beta_x, debug)
#      91 """
#      92 Find neighbors and compute beta based on u, v0, v1
#      93
#    (...)
#     100     beta_additional - the beta cdf value for exchanged numbers of neighbours as parameters)
#     101 """
#     102 w0 = compute_neighbors(u, v0, 'v0')
# --> 103 w1 = compute_neighbors(u, v1, 'v1')
#     104 if debug: print('neighbors in W0', len(w0))
#     105 if debug: print('neighbors in W1', len(w1))
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:82, in compute_neighbors(u, v, debug_string)
#      79 neigh = NearestNeighbors(n_neighbors=1, n_jobs=-1)
#      80 neigh.fit(v)
# ---> 82 neigh_ind_v = neigh.kneighbors(u, return_distance=False)
#      83 # print('neigh_ind_' + debug_string, neigh_ind_v)
#      84 unique_v_neighbor_indices = np.unique(neigh_ind_v)
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\neighbors\_base.py:763, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     756 use_pairwise_distances_reductions = (
#     757     self._fit_method == "brute"
#     758     and PairwiseDistancesArgKmin.is_usable_for(
#     759         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     760     )
#     761 )
#     762 if use_pairwise_distances_reductions:
# --> 763     results = PairwiseDistancesArgKmin.compute(
#     764         X=X,
#     765         Y=self._fit_X,
#     766         k=n_neighbors,
#     767         metric=self.effective_metric_,
#     768         metric_kwargs=self.effective_metric_params_,
#     769         strategy="auto",
#     770         return_distance=return_distance,
#     771     )
#     773 elif (
#     774     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     775 ):
#     776     results = _kneighbors_from_graph(
#     777         X, n_neighbors=n_neighbors, return_distance=return_distance
#     778     )
#
# File sklearn\metrics\_pairwise_distances_reduction.pyx:698, in sklearn.metrics._pairwise_distances_reduction.PairwiseDistancesArgKmin.compute()
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\threadpoolctl.py:171, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     168 def __enter__(self):
#     169     return self
# --> 171 def __exit__(self, type, value, traceback):
#     172     self.restore_original_limits()
#     174 @classmethod
#     175 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the obtained results to csv

# %%
from eval_helpers import helpers


final_result_dict = {
    'type_of_data': [], 'dataset': [], 'drift': [], 'width': [], 'encoding': [],
    'min_ref_batches_drift': [], 'additional_check': [],
    'n_init': [], 'max_iter': [], 'tol': [],
    'FPR_mean': [], 'latency_mean': []
}

for data_path, stats_dict in agraw2_onehot_stats1.items():
    synthetic_filename_info = helpers.synthetic_data_information(data_path)
    encoding = 'onehot'
    fpr_mean = float(stats_dict['final_fpr_mean'])
    latency_mean = float(stats_dict['final_latency_mean'])
    
    final_result_dict['type_of_data'].append(synthetic_filename_info['type_of_data'])
    final_result_dict['dataset'].append(synthetic_filename_info['dataset_name'])
    final_result_dict['drift'].append(synthetic_filename_info['drift_type'])
    final_result_dict['width'].append(synthetic_filename_info['drift_width'])
    final_result_dict['encoding'].append(encoding)
    final_result_dict['min_ref_batches_drift'].append(0.3)
    final_result_dict['additional_check'].append('yes')
    final_result_dict['n_init'].append(100)
    final_result_dict['max_iter'].append(37000)
    final_result_dict['tol'].append(0)
    final_result_dict['FPR_mean'].append(fpr_mean)
    final_result_dict['latency_mean'].append(latency_mean)
    
final_result_df = pd.DataFrame.from_dict(final_result_dict)
sorted_final_result_df = final_result_df.sort_values(['drift', 'dataset', 'encoding', 'width'])
final_result_df.to_csv('agraw2_onehot_jupyter_results.csv', index=False)

# %% [markdown]
# ### Use them for the analysis (majority vote)

# %%
from core import ucdd_eval


agraw2_onehot_stats2 = {}

for agraw2_path in all_agraw2_data_paths:
    runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
        ucdd_eval.all_drifting_batches_randomness_robust(
        agraw2_onehot_reference_batches[agraw2_path],
        agraw2_onehot_testing_batches[agraw2_path],
        min_ref_batches_drift=0.3,
        additional_check=True,
        n_init=100,
        max_iter=37000,
        tol=0,
        true_drift_idx=2,
        min_runs=2
    )
    agraw2_onehot_stats2[agraw2_path] = {
        'runs_results_bool': runs_results_bool,
        'final_fpr_mean': final_fpr_mean,
        'fpr_std_err': fpr_std_err,
        'final_latency_mean': final_latency_mean,
        'latency_std_err': latency_std_err
    }

print('agraw2 STATS')
print(agraw2_onehot_stats2)
# Out:
# train_batch_strategy TrainBatchStrategies.MAJORITY
# random_state
# 0
# n_init 100 max_iter 37000 tol 0
# n_init 100 max_iter 37000 tol 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 10
#       6 agraw2_onehot_stats2 = {}
#       8 for agraw2_path in all_agraw2_data_paths:
#       9     runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
# ---> 10         ucdd_eval.all_drifting_batches_randomness_robust(
#      11         agraw2_onehot_reference_batches[agraw2_path],
#      12         agraw2_onehot_testing_batches[agraw2_path],
#      13         train_batch_strategy=spms.TrainBatchStrategies.MAJORITY,
#      14         additional_check=True,
#      15         n_init=100,
#      16         max_iter=37000,
#      17         tol=0,
#      18         true_drift_idx=2,
#      19         min_runs=2
#      20     )
#      21     agraw2_onehot_stats2[agraw2_path] = {
#      22         'runs_results_bool': runs_results_bool,
#      23         'final_fpr_mean': final_fpr_mean,
#    (...)
#      26         'latency_std_err': latency_std_err
#      27     }
#      29 print('agraw2 STATS')
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd_eval.py:57, in all_drifting_batches_randomness_robust(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, true_drift_idx, first_random_state, min_runs, std_err_threshold)
#      55 while num_runs < min_runs or max(fpr_std_err, latency_std_err) > std_err_threshold:
#      56     print('train_batch_strategy', train_batch_strategy)
# ---> 57     drifting_batches_bool = ucdd.all_drifting_batches(
#      58         reference_data_batches,
#      59         testing_data_batches,
#      60         train_batch_strategy=train_batch_strategy,
#      61         additional_check=additional_check,
#      62         n_init=n_init,
#      63         max_iter=max_iter,
#      64         tol=tol,
#      65         random_state=random_state
#      66     )
#      67     # print('drifting_batches_bool')
#      68     # print(drifting_batches_bool)
#      69     drift_locations = np.arange(len(drifting_batches_bool))[drifting_batches_bool]
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:189, in all_drifting_batches(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, random_state)
#     187 num_ref_drifts = 0 # how many training batches signal drift against this testing batch
#     188 for j, ref_window in enumerate(reference_data_batches):
# --> 189     drift_here = concept_drift_detected(
#     190         ref_window, test_window, additional_check, n_init, max_iter, tol, random_state)
#     191     if drift_here:
#     192         num_ref_drifts += 1
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:145, in concept_drift_detected(ref_window, test_window, additional_check, n_init, max_iter, tol, random_state, threshold, debug)
#     142 beta_minus, beta_minus_additional = compute_beta(
#     143     ref_plus, ref_minus, test_minus)
#     144 if debug: print('BETA PLUS (ref-, ref+, test+)')
# --> 145 beta_plus, beta_plus_additional = compute_beta(
#     146     ref_minus, ref_plus, test_plus)
#     148 drift = (beta_plus < threshold or beta_minus < threshold)
#     149 if additional_check:
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:103, in compute_beta(u, v0, v1, beta_x, debug)
#      91 """
#      92 Find neighbors and compute beta based on u, v0, v1
#      93
#    (...)
#     100     beta_additional - the beta cdf value for exchanged numbers of neighbours as parameters)
#     101 """
#     102 w0 = compute_neighbors(u, v0, 'v0')
# --> 103 w1 = compute_neighbors(u, v1, 'v1')
#     104 if debug: print('neighbors in W0', len(w0))
#     105 if debug: print('neighbors in W1', len(w1))
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:82, in compute_neighbors(u, v, debug_string)
#      79 neigh = NearestNeighbors(n_neighbors=1, n_jobs=-1)
#      80 neigh.fit(v)
# ---> 82 neigh_ind_v = neigh.kneighbors(u, return_distance=False)
#      83 # print('neigh_ind_' + debug_string, neigh_ind_v)
#      84 unique_v_neighbor_indices = np.unique(neigh_ind_v)
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\neighbors\_base.py:763, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     756 use_pairwise_distances_reductions = (
#     757     self._fit_method == "brute"
#     758     and PairwiseDistancesArgKmin.is_usable_for(
#     759         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     760     )
#     761 )
#     762 if use_pairwise_distances_reductions:
# --> 763     results = PairwiseDistancesArgKmin.compute(
#     764         X=X,
#     765         Y=self._fit_X,
#     766         k=n_neighbors,
#     767         metric=self.effective_metric_,
#     768         metric_kwargs=self.effective_metric_params_,
#     769         strategy="auto",
#     770         return_distance=return_distance,
#     771     )
#     773 elif (
#     774     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     775 ):
#     776     results = _kneighbors_from_graph(
#     777         X, n_neighbors=n_neighbors, return_distance=return_distance
#     778     )
#
# File sklearn\metrics\_pairwise_distances_reduction.pyx:698, in sklearn.metrics._pairwise_distances_reduction.PairwiseDistancesArgKmin.compute()
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\threadpoolctl.py:171, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     168 def __enter__(self):
#     169     return self
# --> 171 def __exit__(self, type, value, traceback):
#     172     self.restore_original_limits()
#     174 @classmethod
#     175 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save the obtained results to csv

# %%
from eval_helpers import helpers


final_result_dict = {
    'type_of_data': [], 'dataset': [], 'drift': [], 'width': [], 'encoding': [],
    'min_ref_batches_drift': [], 'additional_check': [],
    'n_init': [], 'max_iter': [], 'tol': [],
    'FPR_mean': [], 'latency_mean': []
}

for data_path, stats_dict in agraw2_onehot_stats2.items():
    synthetic_filename_info = helpers.synthetic_data_information(data_path)
    encoding = 'onehot'
    fpr_mean = float(stats_dict['final_fpr_mean'])
    latency_mean = float(stats_dict['final_latency_mean'])
    
    final_result_dict['type_of_data'].append(synthetic_filename_info['type_of_data'])
    final_result_dict['dataset'].append(synthetic_filename_info['dataset_name'])
    final_result_dict['drift'].append(synthetic_filename_info['drift_type'])
    final_result_dict['width'].append(synthetic_filename_info['drift_width'])
    final_result_dict['encoding'].append(encoding)
    final_result_dict['min_ref_batches_drift'].append(0.6)
    final_result_dict['additional_check'].append('yes')
    final_result_dict['n_init'].append(100)
    final_result_dict['max_iter'].append(37000)
    final_result_dict['tol'].append(0)
    final_result_dict['FPR_mean'].append(fpr_mean)
    final_result_dict['latency_mean'].append(latency_mean)
    
final_result_df = pd.DataFrame.from_dict(final_result_dict)
sorted_final_result_df = final_result_df.sort_values(['drift', 'dataset', 'encoding', 'width'])
final_result_df.to_csv('agraw2_onehot_jupyter_results_majority.csv', index=False)

# %% [markdown]
# ### Use them for the analysis (no check)

# %%
from core import ucdd_eval


agraw2_onehot_stats3 = {}

for agraw2_path in all_agraw2_data_paths:
    runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
        ucdd_eval.all_drifting_batches_randomness_robust(
        agraw2_onehot_reference_batches[agraw2_path],
        agraw2_onehot_testing_batches[agraw2_path],
        min_ref_batches_drift=0.3,
        additional_check=False,
        n_init=100,
        max_iter=37000,
        tol=0,
        true_drift_idx=2,
        min_runs=2
    )
    agraw2_onehot_stats3[agraw2_path] = {
        'runs_results_bool': runs_results_bool,
        'final_fpr_mean': final_fpr_mean,
        'fpr_std_err': fpr_std_err,
        'final_latency_mean': final_latency_mean,
        'latency_std_err': latency_std_err
    }

print('agraw2 STATS')
print(agraw2_onehot_stats3)
# Out:
# train_batch_strategy TrainBatchStrategies.SUBMAJORITY
# random_state
# 0
# n_init 100 max_iter 37000 tol 0

# %% [markdown]
# ### Save the obtained results to csv

# %%
from eval_helpers import helpers


final_result_dict = {
    'type_of_data': [], 'dataset': [], 'drift': [], 'width': [], 'encoding': [],
    'min_ref_batches_drift': [], 'additional_check': [],
    'n_init': [], 'max_iter': [], 'tol': [],
    'FPR_mean': [], 'latency_mean': []
}

for data_path, stats_dict in agraw2_onehot_stats3.items():
    synthetic_filename_info = helpers.synthetic_data_information(data_path)
    encoding = 'onehot'
    fpr_mean = float(stats_dict['final_fpr_mean'])
    latency_mean = float(stats_dict['final_latency_mean'])
    
    final_result_dict['type_of_data'].append(synthetic_filename_info['type_of_data'])
    final_result_dict['dataset'].append(synthetic_filename_info['dataset_name'])
    final_result_dict['drift'].append(synthetic_filename_info['drift_type'])
    final_result_dict['width'].append(synthetic_filename_info['drift_width'])
    final_result_dict['encoding'].append(encoding)
    final_result_dict['min_ref_batches_drift'].append(0.3)
    final_result_dict['additional_check'].append('no')
    final_result_dict['n_init'].append(100)
    final_result_dict['max_iter'].append(37000)
    final_result_dict['tol'].append(0)
    final_result_dict['FPR_mean'].append(fpr_mean)
    final_result_dict['latency_mean'].append(latency_mean)
    
final_result_df = pd.DataFrame.from_dict(final_result_dict)
sorted_final_result_df = final_result_df.sort_values(['drift', 'dataset', 'encoding', 'width'])
final_result_df.to_csv('agraw2_onehot_jupyter_results_no_check.csv', index=False)

# %% [markdown]
# ### Inspect clusters to obtain meaning

# %%
from core import ucdd
import importlib
importlib.reload(ucdd)

ucdd.all_drifting_batches(
    agraw2_onehot_reference_batches[abrupt_agraw2_path],
    agraw2_onehot_testing_batches[abrupt_agraw2_path],
    min_ref_batches_drift=0.3,
    additional_check=True,
    n_init=100,
    max_iter=77000,
    tol=0,
    parallel=False,
    reference_label_batches=agraw2_reference_label_batches[abrupt_agraw2_path],
    testing_label_batches=agraw2_testing_label_batches[abrupt_agraw2_path],
    debug=True
)
# Out:
# random_state
# None
#
#
# #### TEST BATCH 0 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 8007
# actual class 1 percentage in the ref plus cluster: 49.881353815411515
# actual class 0 percentage in the ref plus cluster: 50.118646184588485
# number of points in the ref minus cluster: 1993
# actual class 1 percentage in the ref minus cluster: 50.47666833918716
# actual class 0 percentage in the ref minus cluster: 49.52333166081284
# number of points in the test plus cluster: 7929
# actual class 1 percentage in the test plus cluster: 50.05675368898979
# actual class 0 percentage in the test plus cluster: 49.94324631101021
# number of points in the test minus cluster: 2071
# actual class 1 percentage in the test minus cluster: 49.782713664896185
# actual class 0 percentage in the test minus cluster: 50.217286335103815
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1846
# neighbors in W1 1879
# beta 0.7056624891398426
# beta additional 0.2943375108601574
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1690
# neighbors in W1 1680
# beta 0.4316080480925759
# beta additional 0.5683919519074241
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 8013
# actual class 1 percentage in the ref plus cluster: 50.24335454885811
# actual class 0 percentage in the ref plus cluster: 49.75664545114189
# number of points in the ref minus cluster: 1987
# actual class 1 percentage in the ref minus cluster: 49.0186210367388
# actual class 0 percentage in the ref minus cluster: 50.9813789632612
# number of points in the test plus cluster: 7929
# actual class 1 percentage in the test plus cluster: 50.05675368898979
# actual class 0 percentage in the test plus cluster: 49.94324631101021
# number of points in the test minus cluster: 2071
# actual class 1 percentage in the test minus cluster: 49.782713664896185
# actual class 0 percentage in the test minus cluster: 50.217286335103815
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1828
# neighbors in W1 1887
# beta 0.8335084772558734
# beta additional 0.16649152274412662
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1708
# neighbors in W1 1691
# beta 0.38528597773414747
# beta additional 0.6147140222658525
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7951
# actual class 1 percentage in the ref plus cluster: 50.144635894855995
# actual class 0 percentage in the ref plus cluster: 49.855364105144005
# number of points in the ref minus cluster: 2049
# actual class 1 percentage in the ref minus cluster: 49.43875061005369
# actual class 0 percentage in the ref minus cluster: 50.56124938994631
# number of points in the test plus cluster: 7929
# actual class 1 percentage in the test plus cluster: 50.05675368898979
# actual class 0 percentage in the test plus cluster: 49.94324631101021
# number of points in the test minus cluster: 2071
# actual class 1 percentage in the test minus cluster: 49.782713664896185
# actual class 0 percentage in the test minus cluster: 50.217286335103815
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1881
# neighbors in W1 1888
# beta 0.5453944494264347
# beta additional 0.4546055505735654
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1754
# neighbors in W1 1728
# beta 0.32972615427799545
# beta additional 0.6702738457220045
# drift: False
#
#
# #### TEST BATCH 1 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 2097
# actual class 1 percentage in the ref plus cluster: 50.16690510252742
# actual class 0 percentage in the ref plus cluster: 49.83309489747258
# number of points in the ref minus cluster: 7903
# actual class 1 percentage in the ref minus cluster: 49.95571302037201
# actual class 0 percentage in the ref minus cluster: 50.04428697962799
# number of points in the test plus cluster: 1981
# actual class 1 percentage in the test plus cluster: 48.91468955073196
# actual class 0 percentage in the test plus cluster: 51.08531044926804
# number of points in the test minus cluster: 8019
# actual class 1 percentage in the test minus cluster: 50.26811323107619
# actual class 0 percentage in the test minus cluster: 49.73188676892381
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1776
# neighbors in W1 1744
# beta 0.29479596969812494
# beta additional 0.7052040303018751
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1896
# neighbors in W1 1816
# beta 0.09454723917123531
# beta additional 0.9054527608287647
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 2027
# actual class 1 percentage in the ref plus cluster: 49.62999506660089
# actual class 0 percentage in the ref plus cluster: 50.37000493339911
# number of points in the ref minus cluster: 7973
# actual class 1 percentage in the ref minus cluster: 50.09406747773736
# actual class 0 percentage in the ref minus cluster: 49.90593252226264
# number of points in the test plus cluster: 2026
# actual class 1 percentage in the test plus cluster: 49.407699901283316
# actual class 0 percentage in the test plus cluster: 50.592300098716684
# number of points in the test minus cluster: 7974
# actual class 1 percentage in the test minus cluster: 50.15048908954101
# actual class 0 percentage in the test minus cluster: 49.84951091045899
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1715
# neighbors in W1 1716
# beta 0.5068113210586399
# beta additional 0.4931886789413601
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1845
# neighbors in W1 1845
# beta 0.4999999999999995
# beta additional 0.4999999999999995
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7951
# actual class 1 percentage in the ref plus cluster: 50.144635894855995
# actual class 0 percentage in the ref plus cluster: 49.855364105144005
# number of points in the ref minus cluster: 2049
# actual class 1 percentage in the ref minus cluster: 49.43875061005369
# actual class 0 percentage in the ref minus cluster: 50.56124938994631
# number of points in the test plus cluster: 7986
# actual class 1 percentage in the test plus cluster: 49.82469321312296
# actual class 0 percentage in the test plus cluster: 50.17530678687704
# number of points in the test minus cluster: 2014
# actual class 1 percentage in the test minus cluster: 50.695134061569014
# actual class 0 percentage in the test minus cluster: 49.304865938430986
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1881
# neighbors in W1 1835
# beta 0.2252145680506338
# beta additional 0.7747854319493662
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1754
# neighbors in W1 1760
# beta 0.540315386910321
# beta additional 0.45968461308967906
# drift: False
#
#
# #### TEST BATCH 2 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.01
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 7903
# actual class 1 percentage in the ref plus cluster: 49.95571302037201
# actual class 0 percentage in the ref plus cluster: 50.04428697962799
# number of points in the ref minus cluster: 2097
# actual class 1 percentage in the ref minus cluster: 50.16690510252742
# actual class 0 percentage in the ref minus cluster: 49.83309489747258
# number of points in the test plus cluster: 8003
# actual class 1 percentage in the test plus cluster: 50.218667999500184
# actual class 0 percentage in the test plus cluster: 49.781332000499816
# number of points in the test minus cluster: 1997
# actual class 1 percentage in the test minus cluster: 49.17376064096144
# actual class 0 percentage in the test minus cluster: 50.82623935903856
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1896
# neighbors in W1 1828
# beta 0.13254080542156574
# beta additional 0.8674591945784342
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1776
# neighbors in W1 1777
# beta 0.5066933420660237
# beta additional 0.4933066579339763
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 2027
# actual class 1 percentage in the ref plus cluster: 49.62999506660089
# actual class 0 percentage in the ref plus cluster: 50.37000493339911
# number of points in the ref minus cluster: 7973
# actual class 1 percentage in the ref minus cluster: 50.09406747773736
# actual class 0 percentage in the ref minus cluster: 49.90593252226264
# number of points in the test plus cluster: 2048
# actual class 1 percentage in the test plus cluster: 50.634765625
# actual class 0 percentage in the test plus cluster: 49.365234375
# number of points in the test minus cluster: 7952
# actual class 1 percentage in the test minus cluster: 49.84909456740443
# actual class 0 percentage in the test minus cluster: 50.15090543259557
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1715
# neighbors in W1 1740
# beta 0.6647177270167475
# beta additional 0.33528227298325247
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1845
# neighbors in W1 1881
# beta 0.7223504931410203
# beta additional 0.27764950685897966
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 7979
# actual class 1 percentage in the ref plus cluster: 50.04386514600827
# actual class 0 percentage in the ref plus cluster: 49.95613485399173
# number of points in the ref minus cluster: 2021
# actual class 1 percentage in the ref minus cluster: 49.826818406729345
# actual class 0 percentage in the ref minus cluster: 50.173181593270655
# number of points in the test plus cluster: 7952
# actual class 1 percentage in the test plus cluster: 49.84909456740443
# actual class 0 percentage in the test plus cluster: 50.15090543259557
# number of points in the test minus cluster: 2048
# actual class 1 percentage in the test minus cluster: 50.634765625
# actual class 0 percentage in the test minus cluster: 49.365234375
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1850
# neighbors in W1 1887
# beta 0.7275201013882857
# beta additional 0.27247989861171423
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1739
# neighbors in W1 1759
# beta 0.6323935879193467
# beta additional 0.3676064120806532
# drift: False
#
#
# #### TEST BATCH 3 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7903
# actual class 1 percentage in the ref plus cluster: 49.95571302037201
# actual class 0 percentage in the ref plus cluster: 50.04428697962799
# number of points in the ref minus cluster: 2097
# actual class 1 percentage in the ref minus cluster: 50.16690510252742
# actual class 0 percentage in the ref minus cluster: 49.83309489747258
# number of points in the test plus cluster: 7983
# actual class 1 percentage in the test plus cluster: 50.056369785794814
# actual class 0 percentage in the test plus cluster: 49.943630214205186
# number of points in the test minus cluster: 2017
# actual class 1 percentage in the test minus cluster: 49.77689638076351
# actual class 0 percentage in the test minus cluster: 50.22310361923649
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1896
# neighbors in W1 1836
# beta 0.16297930241107592
# beta additional 0.8370206975889241
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1776
# neighbors in W1 1770
# beta 0.45986635874218645
# beta additional 0.5401336412578135
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 1987
# actual class 1 percentage in the ref plus cluster: 49.0186210367388
# actual class 0 percentage in the ref plus cluster: 50.9813789632612
# number of points in the ref minus cluster: 8013
# actual class 1 percentage in the ref minus cluster: 50.24335454885811
# actual class 0 percentage in the ref minus cluster: 49.75664545114189
# number of points in the test plus cluster: 2084
# actual class 1 percentage in the test plus cluster: 49.424184261036466
# actual class 0 percentage in the test plus cluster: 50.575815738963534
# number of points in the test minus cluster: 7916
# actual class 1 percentage in the test minus cluster: 50.15159171298636
# actual class 0 percentage in the test minus cluster: 49.84840828701364
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1708
# neighbors in W1 1698
# beta 0.4319669914313908
# beta additional 0.5680330085686092
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1828
# neighbors in W1 1889
# beta 0.8415074318032377
# beta additional 0.15849256819676225
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 2049
# actual class 1 percentage in the ref plus cluster: 49.43875061005369
# actual class 0 percentage in the ref plus cluster: 50.56124938994631
# number of points in the ref minus cluster: 7951
# actual class 1 percentage in the ref minus cluster: 50.144635894855995
# actual class 0 percentage in the ref minus cluster: 49.855364105144005
# number of points in the test plus cluster: 2084
# actual class 1 percentage in the test plus cluster: 49.424184261036466
# actual class 0 percentage in the test plus cluster: 50.575815738963534
# number of points in the test minus cluster: 7916
# actual class 1 percentage in the test minus cluster: 50.15159171298636
# actual class 0 percentage in the test minus cluster: 49.84840828701364
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1754
# neighbors in W1 1746
# beta 0.44621072929837147
# beta additional 0.5537892707016285
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1881
# neighbors in W1 1890
# beta 0.5582665937527211
# beta additional 0.44173340624727886
# drift: False
#
#
# #### TEST BATCH 4 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7903
# actual class 1 percentage in the ref plus cluster: 49.95571302037201
# actual class 0 percentage in the ref plus cluster: 50.04428697962799
# number of points in the ref minus cluster: 2097
# actual class 1 percentage in the ref minus cluster: 50.16690510252742
# actual class 0 percentage in the ref minus cluster: 49.83309489747258
# number of points in the test plus cluster: 8023
# actual class 1 percentage in the test plus cluster: 49.85666209647264
# actual class 0 percentage in the test plus cluster: 50.14333790352736
# number of points in the test minus cluster: 1977
# actual class 1 percentage in the test minus cluster: 50.58168942842691
# actual class 0 percentage in the test minus cluster: 49.41831057157309
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1896
# neighbors in W1 1788
# beta 0.03756340993053914
# beta additional 0.9624365900694609
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1776
# neighbors in W1 1785
# beta 0.5599478077032615
# beta additional 0.44005219229673853
# drift: True
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 1995
# actual class 1 percentage in the ref plus cluster: 49.17293233082707
# actual class 0 percentage in the ref plus cluster: 50.82706766917293
# number of points in the ref minus cluster: 8005
# actual class 1 percentage in the ref minus cluster: 50.20612117426608
# actual class 0 percentage in the ref minus cluster: 49.79387882573392
# number of points in the test plus cluster: 2042
# actual class 1 percentage in the test plus cluster: 48.13907933398629
# actual class 0 percentage in the test plus cluster: 51.86092066601371
# number of points in the test minus cluster: 7958
# actual class 1 percentage in the test minus cluster: 50.477506911284244
# actual class 0 percentage in the test minus cluster: 49.522493088715756
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1720
# neighbors in W1 1672
# beta 0.20489069581970001
# beta additional 0.7951093041803
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1834
# neighbors in W1 1867
# beta 0.7062657116643996
# beta additional 0.2937342883356005
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7951
# actual class 1 percentage in the ref plus cluster: 50.144635894855995
# actual class 0 percentage in the ref plus cluster: 49.855364105144005
# number of points in the ref minus cluster: 2049
# actual class 1 percentage in the ref minus cluster: 49.43875061005369
# actual class 0 percentage in the ref minus cluster: 50.56124938994631
# number of points in the test plus cluster: 7978
# actual class 1 percentage in the test plus cluster: 49.9122587114565
# actual class 0 percentage in the test plus cluster: 50.0877412885435
# number of points in the test minus cluster: 2022
# actual class 1 percentage in the test minus cluster: 50.346191889218595
# actual class 0 percentage in the test minus cluster: 49.653808110781405
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1881
# neighbors in W1 1867
# beta 0.4095488232712614
# beta additional 0.5904511767287386
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1754
# neighbors in W1 1751
# beta 0.47979061523960237
# beta additional 0.5202093847603977
# drift: False
#
#
# #### TEST BATCH 5 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7992
# actual class 1 percentage in the ref plus cluster: 49.8998998998999
# actual class 0 percentage in the ref plus cluster: 50.1001001001001
# number of points in the ref minus cluster: 2008
# actual class 1 percentage in the ref minus cluster: 50.398406374501995
# actual class 0 percentage in the ref minus cluster: 49.601593625498005
# number of points in the test plus cluster: 7943
# actual class 1 percentage in the test plus cluster: 50.018884552436106
# actual class 0 percentage in the test plus cluster: 49.981115447563894
# number of points in the test minus cluster: 2057
# actual class 1 percentage in the test minus cluster: 49.927078269324255
# actual class 0 percentage in the test minus cluster: 50.072921730675745
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1838
# neighbors in W1 1863
# beta 0.6594599825757447
# beta additional 0.3405400174242553
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1729
# neighbors in W1 1714
# beta 0.3991036895299844
# beta additional 0.6008963104700156
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7952
# actual class 1 percentage in the ref plus cluster: 49.572434607645874
# actual class 0 percentage in the ref plus cluster: 50.427565392354126
# number of points in the ref minus cluster: 2048
# actual class 1 percentage in the ref minus cluster: 51.66015625
# actual class 0 percentage in the ref minus cluster: 48.33984375
# number of points in the test plus cluster: 7985
# actual class 1 percentage in the test plus cluster: 50.28177833437696
# actual class 0 percentage in the test plus cluster: 49.71822166562304
# number of points in the test minus cluster: 2015
# actual class 1 percentage in the test minus cluster: 48.883374689826304
# actual class 0 percentage in the test minus cluster: 51.116625310173696
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1840
# neighbors in W1 1839
# beta 0.49342229058524706
# beta additional 0.506577709414753
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1749
# neighbors in W1 1784
# beta 0.7220401173379082
# beta additional 0.2779598826620918
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7983
# actual class 1 percentage in the ref plus cluster: 49.8684704998121
# actual class 0 percentage in the ref plus cluster: 50.1315295001879
# number of points in the ref minus cluster: 2017
# actual class 1 percentage in the ref minus cluster: 50.52057511155181
# actual class 0 percentage in the ref minus cluster: 49.47942488844819
# number of points in the test plus cluster: 7943
# actual class 1 percentage in the test plus cluster: 50.018884552436106
# actual class 0 percentage in the test plus cluster: 49.981115447563894
# number of points in the test minus cluster: 2057
# actual class 1 percentage in the test minus cluster: 49.927078269324255
# actual class 0 percentage in the test minus cluster: 50.072921730675745
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1839
# neighbors in W1 1871
# beta 0.7003576922102852
# beta additional 0.29964230778971473
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1713
# neighbors in W1 1700
# beta 0.411942646735171
# beta additional 0.588057353264829
# drift: False
#
#
# #### TEST BATCH 6 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 2008
# actual class 1 percentage in the ref plus cluster: 50.398406374501995
# actual class 0 percentage in the ref plus cluster: 49.601593625498005
# number of points in the ref minus cluster: 7992
# actual class 1 percentage in the ref minus cluster: 49.8998998998999
# actual class 0 percentage in the ref minus cluster: 50.1001001001001
# number of points in the test plus cluster: 2028
# actual class 1 percentage in the test plus cluster: 50.09861932938856
# actual class 0 percentage in the test plus cluster: 49.90138067061144
# number of points in the test minus cluster: 7972
# actual class 1 percentage in the test minus cluster: 49.97491219267436
# actual class 0 percentage in the test minus cluster: 50.02508780732564
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1729
# neighbors in W1 1749
# beta 0.6327594612081877
# beta additional 0.36724053879181223
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1838
# neighbors in W1 1867
# beta 0.683137789067872
# beta additional 0.3168622109321279
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7973
# actual class 1 percentage in the ref plus cluster: 50.09406747773736
# actual class 0 percentage in the ref plus cluster: 49.90593252226264
# number of points in the ref minus cluster: 2027
# actual class 1 percentage in the ref minus cluster: 49.62999506660089
# actual class 0 percentage in the ref minus cluster: 50.37000493339911
# number of points in the test plus cluster: 7931
# actual class 1 percentage in the test plus cluster: 49.89282562098096
# actual class 0 percentage in the test plus cluster: 50.10717437901904
# number of points in the test minus cluster: 2069
# actual class 1 percentage in the test minus cluster: 50.41082648622523
# actual class 0 percentage in the test minus cluster: 49.58917351377477
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1845
# neighbors in W1 1884
# beta 0.7385024209916231
# beta additional 0.2614975790083769
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1715
# neighbors in W1 1739
# beta 0.6585163622158728
# beta additional 0.34148363778412716
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 7979
# actual class 1 percentage in the ref plus cluster: 50.04386514600827
# actual class 0 percentage in the ref plus cluster: 49.95613485399173
# number of points in the ref minus cluster: 2021
# actual class 1 percentage in the ref minus cluster: 49.826818406729345
# actual class 0 percentage in the ref minus cluster: 50.173181593270655
# number of points in the test plus cluster: 7931
# actual class 1 percentage in the test plus cluster: 49.89282562098096
# actual class 0 percentage in the test plus cluster: 50.10717437901904
# number of points in the test minus cluster: 2069
# actual class 1 percentage in the test minus cluster: 50.41082648622523
# actual class 0 percentage in the test minus cluster: 49.58917351377477
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 1850
# neighbors in W1 1891
# beta 0.748702871359177
# beta additional 0.25129712864082293
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 1739
# neighbors in W1 1729
# beta 0.4325721429578132
# beta additional 0.5674278570421868
# drift: False
# [False, False, False, False, True, False, False]

# %% [markdown]
# ## AGRAW2 with categories target encoded

# %% [markdown]
# ### Find the best tol and max_iter (the drift type is irrelevant)

# %%
write_kmeans_results_ucdd_helper('agraw2_target_new_output', agraw2_target_reference_batches[abrupt_agraw2_path],
                                 n_init=100, max_iter=500, tol=0,
                                 random_state=1053)
# Out:
# filename agraw2_target_new_output0.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 20
# minimum initial inertia: 16176.827800853413
# maximum initial inertia: 29031.88560718201
# number of unique final inertia values: 7
# minimum final inertia: 12389.53001076715
# maximum final inertia: 13803.573549796298
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_target_new_output1.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 19
# minimum initial inertia: 16778.152451216705
# maximum initial inertia: 29186.33702861551
# number of unique final inertia values: 9
# minimum final inertia: 12405.60465181937
# maximum final inertia: 12405.605096531615
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename agraw2_target_new_output2.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 25
# minimum initial inertia: 16687.10769088688
# maximum initial inertia: 27537.924214124047
# number of unique final inertia values: 3
# minimum final inertia: 12355.565422772539
# maximum final inertia: 13755.808634925628
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# {'total_max_iterations': 25, 'total_min_init_inertia': 16176.827800853413, 'total_max_init_inertia': 29186.33702861551, 'total_min_final_inertia': 12355.565422772539, 'total_max_final_inertia': 13803.573549796298, 'total_num_convergences': 300, 'total_num_strict_convergences': 300, 'total_num_tol_based_convergences': 0}

# %% [markdown]
# ### Use them for the analysis

# %%
from core import ucdd_eval


agraw2_target_stats = {}
    
for agraw2_path in all_agraw2_data_paths:
    runs_results_bool, final_fpr_mean, fpr_std_err, final_latency_mean, latency_std_err = \
        ucdd_eval.all_drifting_batches_randomness_robust(
        agraw2_target_reference_batches[agraw2_path],
        agraw2_target_testing_batches[agraw2_path],
        min_ref_batches_drift=0.3,
        additional_check=True,
        n_init=100,
        max_iter=25000,
        tol=0,
        true_drift_idx=2,
        min_runs=2
    )
    agraw2_target_stats[agraw2_path] = {
        'runs_results_bool': runs_results_bool,
        'final_fpr_mean': final_fpr_mean,
        'fpr_std_err': fpr_std_err,
        'final_latency_mean': final_latency_mean,
        'latency_std_err': latency_std_err
    }

print('agraw2 STATS')
print(agraw2_target_stats)
# Out:
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.0
# final latency mean 1.0
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.0
# final latency mean 1.0
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.0
# final latency mean 1.0
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.5
# final latency mean 1.0
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.0
# final latency mean 1.0
# random_state
# 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# random_state
# 100
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# n_init 100 max_iter 25000 tol 0
# fpr s.e. 0.0
# latency s.e. 0.0
# final fpr mean 0.0
# final latency mean 1.0
# agraw2 STATS
# {'../Datasets_concept_drift/synthetic_data/abrupt_drift/agraw2_1_abrupt_drift_0_noise_balanced.arff': {'runs_results_bool': [[False, False, False, False, False, False, True], [False, False, False, False, False, False, True]], 'final_fpr_mean': 0.0, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}, '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_05.arff': {'runs_results_bool': [[False, False, False, False, False, False, True], [False, False, False, False, False, False, True]], 'final_fpr_mean': 0.0, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}, '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_1.arff': {'runs_results_bool': [[False, False, False, False, False, False, True], [False, False, False, False, False, False, True]], 'final_fpr_mean': 0.0, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}, '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_5.arff': {'runs_results_bool': [[False, True, False, False, False, False, True], [False, True, False, False, False, False, True]], 'final_fpr_mean': 0.5, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}, '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_10.arff': {'runs_results_bool': [[False, False, False, False, False, False, False], [False, False, False, False, False, False, False]], 'final_fpr_mean': 0.0, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}, '../Datasets_concept_drift/synthetic_data/gradual_drift/agraw2_1_gradual_drift_0_noise_balanced_20.arff': {'runs_results_bool': [[False, False, False, False, False, False, False], [False, False, False, False, False, False, False]], 'final_fpr_mean': 0.0, 'fpr_std_err': 0.0, 'final_latency_mean': 1.0, 'latency_std_err': 0.0}}

# %% [markdown]
# ### Save the obtained results to csv

# %%
from eval_helpers import helpers


final_result_dict = {
    'type_of_data': [], 'dataset': [], 'drift': [], 'width': [], 'encoding': [],
    'min_ref_batches_drift': [], 'additional_check': [],
    'n_init': [], 'max_iter': [], 'tol': [],
    'FPR_mean': [], 'latency_mean': []
}

for data_path, stats_dict in agraw2_target_stats.items():
    synthetic_filename_info = helpers.synthetic_data_information(data_path)
    encoding = 'target'
    fpr_mean = float(stats_dict['final_fpr_mean'])
    latency_mean = float(stats_dict['final_latency_mean'])
    
    final_result_dict['type_of_data'].append(synthetic_filename_info['type_of_data'])
    final_result_dict['dataset'].append(synthetic_filename_info['dataset_name'])
    final_result_dict['drift'].append(synthetic_filename_info['drift_type'])
    final_result_dict['width'].append(synthetic_filename_info['drift_width'])
    final_result_dict['encoding'].append(encoding)
    final_result_dict['min_ref_batches_drift'].append(0.3)
    final_result_dict['additional_check'].append('yes')
    final_result_dict['n_init'].append(100)
    final_result_dict['max_iter'].append(25000)
    final_result_dict['tol'].append(0)
    final_result_dict['FPR_mean'].append(fpr_mean)
    final_result_dict['latency_mean'].append(latency_mean)
    
final_result_df = pd.DataFrame.from_dict(final_result_dict)
sorted_final_result_df = final_result_df.sort_values(['drift', 'dataset', 'encoding', 'width'])
final_result_df.to_csv('agraw2_target_jupyter_results.csv', index=False)

# %% [markdown]
# ### Inspect clusters to obtain meaning

# %%
from core import ucdd
import importlib
importlib.reload(ucdd)

ucdd.all_drifting_batches(
    agraw2_target_reference_batches[abrupt_agraw2_path],
    agraw2_target_testing_batches[abrupt_agraw2_path],
    min_ref_batches_drift=0.3,
    additional_check=True,
    n_init=100,
    max_iter=77000,
    tol=0,
    parallel=False,
    reference_label_batches=agraw2_reference_label_batches[abrupt_agraw2_path],
    testing_label_batches=agraw2_testing_label_batches[abrupt_agraw2_path],
    debug=True
)
# Out:
# random_state
# None
#
#
# #### TEST BATCH 0 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5758
# actual class 1 percentage in the ref plus cluster: 57.25946509204585
# actual class 0 percentage in the ref plus cluster: 42.74053490795415
# number of points in the ref minus cluster: 4242
# actual class 1 percentage in the ref minus cluster: 40.146157472890145
# actual class 0 percentage in the ref minus cluster: 59.853842527109855
# number of points in the test plus cluster: 5824
# actual class 1 percentage in the test plus cluster: 57.005494505494504
# actual class 0 percentage in the test plus cluster: 42.994505494505496
# number of points in the test minus cluster: 4176
# actual class 1 percentage in the test minus cluster: 40.229885057471265
# actual class 0 percentage in the test minus cluster: 59.770114942528735
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 697
# neighbors in W1 726
# beta 0.7790593549521747
# beta additional 0.22094064504782523
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 710
# neighbors in W1 699
# beta 0.38470944128623574
# beta additional 0.6152905587137643
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4357
# actual class 1 percentage in the ref plus cluster: 41.22102364011935
# actual class 0 percentage in the ref plus cluster: 58.77897635988065
# number of points in the ref minus cluster: 5643
# actual class 1 percentage in the ref minus cluster: 56.77830940988836
# actual class 0 percentage in the ref minus cluster: 43.22169059011164
# number of points in the test plus cluster: 4174
# actual class 1 percentage in the test plus cluster: 40.2252036415908
# actual class 0 percentage in the test plus cluster: 59.7747963584092
# number of points in the test minus cluster: 5826
# actual class 1 percentage in the test minus cluster: 57.00308959835221
# actual class 0 percentage in the test minus cluster: 42.99691040164779
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 640
# neighbors in W1 683
# beta 0.8815300418232298
# beta additional 0.11846995817677021
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 709
# neighbors in W1 744
# beta 0.8208223365353154
# beta additional 0.17917766346468453
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4204
# actual class 1 percentage in the ref plus cluster: 41.48430066603235
# actual class 0 percentage in the ref plus cluster: 58.51569933396765
# number of points in the ref minus cluster: 5796
# actual class 1 percentage in the ref minus cluster: 56.176673567977915
# actual class 0 percentage in the ref minus cluster: 43.823326432022085
# number of points in the test plus cluster: 4169
# actual class 1 percentage in the test plus cluster: 40.27344686975294
# actual class 0 percentage in the test plus cluster: 59.72655313024706
# number of points in the test minus cluster: 5831
# actual class 1 percentage in the test minus cluster: 56.95421025553078
# actual class 0 percentage in the test minus cluster: 43.04578974446922
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 650
# neighbors in W1 675
# beta 0.7539710055262306
# beta additional 0.24602899447376939
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 714
# neighbors in W1 769
# beta 0.9234656206123629
# beta additional 0.07653437938763707
# drift: False
#
#
# #### TEST BATCH 1 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5753
# actual class 1 percentage in the ref plus cluster: 57.30922996697375
# actual class 0 percentage in the ref plus cluster: 42.69077003302625
# number of points in the ref minus cluster: 4247
# actual class 1 percentage in the ref minus cluster: 40.098893336472806
# actual class 0 percentage in the ref minus cluster: 59.901106663527194
# number of points in the test plus cluster: 5645
# actual class 1 percentage in the test plus cluster: 57.0770593445527
# actual class 0 percentage in the test plus cluster: 42.9229406554473
# number of points in the test minus cluster: 4355
# actual class 1 percentage in the test minus cluster: 40.82663605051665
# actual class 0 percentage in the test minus cluster: 59.17336394948335
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 697
# neighbors in W1 757
# beta 0.9422774391239777
# beta additional 0.05772256087602239
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 718
# neighbors in W1 665
# beta 0.07696765257049487
# beta additional 0.9230323474295051
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4355
# actual class 1 percentage in the ref plus cluster: 41.239954075774975
# actual class 0 percentage in the ref plus cluster: 58.760045924225025
# number of points in the ref minus cluster: 5645
# actual class 1 percentage in the ref minus cluster: 56.75819309123118
# actual class 0 percentage in the ref minus cluster: 43.24180690876882
# number of points in the test plus cluster: 4345
# actual class 1 percentage in the test plus cluster: 40.82853855005754
# actual class 0 percentage in the test plus cluster: 59.17146144994246
# number of points in the test minus cluster: 5655
# actual class 1 percentage in the test minus cluster: 57.04686118479222
# actual class 0 percentage in the test minus cluster: 42.95313881520778
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 641
# neighbors in W1 658
# beta 0.6814776065777168
# beta additional 0.3185223934222832
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 713
# neighbors in W1 767
# beta 0.9198725005606312
# beta additional 0.08012749943936877
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5797
# actual class 1 percentage in the ref plus cluster: 56.184233224081424
# actual class 0 percentage in the ref plus cluster: 43.815766775918576
# number of points in the ref minus cluster: 4203
# actual class 1 percentage in the ref minus cluster: 41.47037830121342
# actual class 0 percentage in the ref minus cluster: 58.52962169878658
# number of points in the test plus cluster: 5651
# actual class 1 percentage in the test plus cluster: 57.05184923022474
# actual class 0 percentage in the test plus cluster: 42.94815076977526
# number of points in the test minus cluster: 4349
# actual class 1 percentage in the test minus cluster: 40.83697401701541
# actual class 0 percentage in the test minus cluster: 59.16302598298459
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 716
# neighbors in W1 778
# beta 0.9457225636616781
# beta additional 0.054277436338321924
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 649
# neighbors in W1 636
# beta 0.3583868023242743
# beta additional 0.6416131976757258
# drift: False
#
#
# #### TEST BATCH 2 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.01
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 4248
# actual class 1 percentage in the ref plus cluster: 40.112994350282484
# actual class 0 percentage in the ref plus cluster: 59.887005649717516
# number of points in the ref minus cluster: 5752
# actual class 1 percentage in the ref minus cluster: 57.301808066759385
# actual class 0 percentage in the ref minus cluster: 42.698191933240615
# number of points in the test plus cluster: 4170
# actual class 1 percentage in the test plus cluster: 45.10791366906475
# actual class 0 percentage in the test plus cluster: 54.89208633093525
# number of points in the test minus cluster: 5830
# actual class 1 percentage in the test minus cluster: 53.516295025728986
# actual class 0 percentage in the test minus cluster: 46.483704974271014
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 722
# neighbors in W1 708
# beta 0.3555679473196266
# beta additional 0.6444320526803734
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 701
# neighbors in W1 713
# beta 0.6252193298228935
# beta additional 0.3747806701771065
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 5642
# actual class 1 percentage in the ref plus cluster: 56.78837291740518
# actual class 0 percentage in the ref plus cluster: 43.21162708259482
# number of points in the ref minus cluster: 4358
# actual class 1 percentage in the ref minus cluster: 41.21156493804497
# actual class 0 percentage in the ref minus cluster: 58.78843506195503
# number of points in the test plus cluster: 5841
# actual class 1 percentage in the test plus cluster: 53.50111282314672
# actual class 0 percentage in the test plus cluster: 46.49888717685328
# number of points in the test minus cluster: 4159
# actual class 1 percentage in the test minus cluster: 45.106996874248615
# actual class 0 percentage in the test minus cluster: 54.893003125751385
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 708
# neighbors in W1 719
# beta 0.6145811534713088
# beta additional 0.38541884652869113
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 643
# neighbors in W1 674
# beta 0.8035937509261638
# beta additional 0.19640624907383622
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.01
# number of points in the ref plus cluster: 5789
# actual class 1 percentage in the ref plus cluster: 56.261875971670406
# actual class 0 percentage in the ref plus cluster: 43.738124028329594
# number of points in the ref minus cluster: 4211
# actual class 1 percentage in the ref minus cluster: 41.39159344573736
# actual class 0 percentage in the ref minus cluster: 58.60840655426264
# number of points in the test plus cluster: 5837
# actual class 1 percentage in the test plus cluster: 53.50351207812232
# actual class 0 percentage in the test plus cluster: 46.49648792187768
# number of points in the test minus cluster: 4163
# actual class 1 percentage in the test minus cluster: 45.111698294499156
# actual class 0 percentage in the test minus cluster: 54.888301705500844
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 712
# neighbors in W1 730
# beta 0.6823055768394601
# beta additional 0.3176944231605399
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 660
# neighbors in W1 690
# beta 0.7929735777357714
# beta additional 0.20702642226422868
# drift: False
#
#
# #### TEST BATCH 3 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5743
# actual class 1 percentage in the ref plus cluster: 57.33936966742121
# actual class 0 percentage in the ref plus cluster: 42.66063033257879
# number of points in the ref minus cluster: 4257
# actual class 1 percentage in the ref minus cluster: 40.09866102889359
# actual class 0 percentage in the ref minus cluster: 59.90133897110641
# number of points in the test plus cluster: 5800
# actual class 1 percentage in the test plus cluster: 49.94827586206897
# actual class 0 percentage in the test plus cluster: 50.05172413793103
# number of points in the test minus cluster: 4200
# actual class 1 percentage in the test minus cluster: 50.07142857142857
# actual class 0 percentage in the test minus cluster: 49.92857142857143
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 693
# neighbors in W1 698
# beta 0.5533392549533807
# beta additional 0.4466607450466193
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 742
# neighbors in W1 736
# beta 0.4379722586784578
# beta additional 0.5620277413215422
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5638
# actual class 1 percentage in the ref plus cluster: 56.82866264632848
# actual class 0 percentage in the ref plus cluster: 43.17133735367152
# number of points in the ref minus cluster: 4362
# actual class 1 percentage in the ref minus cluster: 41.173773498395235
# actual class 0 percentage in the ref minus cluster: 58.826226501604765
# number of points in the test plus cluster: 5816
# actual class 1 percentage in the test plus cluster: 49.965612104539204
# actual class 0 percentage in the test plus cluster: 50.034387895460796
# number of points in the test minus cluster: 4184
# actual class 1 percentage in the test minus cluster: 50.04780114722753
# actual class 0 percentage in the test minus cluster: 49.95219885277247
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 710
# neighbors in W1 696
# beta 0.35439550812277343
# beta additional 0.6456044918772266
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 666
# neighbors in W1 687
# beta 0.7160343925957027
# beta additional 0.2839656074042973
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5796
# actual class 1 percentage in the ref plus cluster: 56.22843340234645
# actual class 0 percentage in the ref plus cluster: 43.77156659765355
# number of points in the ref minus cluster: 4204
# actual class 1 percentage in the ref minus cluster: 41.412940057088484
# actual class 0 percentage in the ref minus cluster: 58.587059942911516
# number of points in the test plus cluster: 5816
# actual class 1 percentage in the test plus cluster: 49.965612104539204
# actual class 0 percentage in the test plus cluster: 50.034387895460796
# number of points in the test minus cluster: 4184
# actual class 1 percentage in the test minus cluster: 50.04780114722753
# actual class 0 percentage in the test minus cluster: 49.95219885277247
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 716
# neighbors in W1 712
# beta 0.457837913835905
# beta additional 0.542162086164095
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 646
# neighbors in W1 656
# beta 0.6091971238008163
# beta additional 0.3908028761991838
# drift: False
#
#
# #### TEST BATCH 4 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4244
# actual class 1 percentage in the ref plus cluster: 40.12723845428841
# actual class 0 percentage in the ref plus cluster: 59.87276154571159
# number of points in the ref minus cluster: 5756
# actual class 1 percentage in the ref minus cluster: 57.27936066712995
# actual class 0 percentage in the ref minus cluster: 42.72063933287005
# number of points in the test plus cluster: 4234
# actual class 1 percentage in the test plus cluster: 49.97638167217761
# actual class 0 percentage in the test plus cluster: 50.02361832782239
# number of points in the test minus cluster: 5766
# actual class 1 percentage in the test minus cluster: 50.01734304543878
# actual class 0 percentage in the test minus cluster: 49.98265695456122
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 697
# neighbors in W1 681
# beta 0.3331784995077009
# beta additional 0.666821500492299
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 699
# neighbors in W1 715
# beta 0.6648097158340864
# beta additional 0.3351902841659136
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4358
# actual class 1 percentage in the ref plus cluster: 41.21156493804497
# actual class 0 percentage in the ref plus cluster: 58.78843506195503
# number of points in the ref minus cluster: 5642
# actual class 1 percentage in the ref minus cluster: 56.78837291740518
# actual class 0 percentage in the ref minus cluster: 43.21162708259482
# number of points in the test plus cluster: 4222
# actual class 1 percentage in the test plus cluster: 49.976314542870675
# actual class 0 percentage in the test plus cluster: 50.023685457129325
# number of points in the test minus cluster: 5778
# actual class 1 percentage in the test minus cluster: 50.01730702665282
# actual class 0 percentage in the test minus cluster: 49.98269297334718
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 654
# neighbors in W1 641
# beta 0.3589115070190178
# beta additional 0.6410884929809821
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 707
# neighbors in W1 710
# beta 0.5317697986276986
# beta additional 0.46823020137230137
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5796
# actual class 1 percentage in the ref plus cluster: 56.176673567977915
# actual class 0 percentage in the ref plus cluster: 43.823326432022085
# number of points in the ref minus cluster: 4204
# actual class 1 percentage in the ref minus cluster: 41.48430066603235
# actual class 0 percentage in the ref minus cluster: 58.51569933396765
# number of points in the test plus cluster: 5778
# actual class 1 percentage in the test plus cluster: 50.01730702665282
# actual class 0 percentage in the test plus cluster: 49.98269297334718
# number of points in the test minus cluster: 4222
# actual class 1 percentage in the test minus cluster: 49.976314542870675
# actual class 0 percentage in the test minus cluster: 50.023685457129325
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 710
# neighbors in W1 728
# beta 0.6825406412424774
# beta additional 0.3174593587575226
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 662
# neighbors in W1 667
# beta 0.5545624067753607
# beta additional 0.4454375932246393
# drift: False
#
#
# #### TEST BATCH 5 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5753
# actual class 1 percentage in the ref plus cluster: 57.29184773161828
# actual class 0 percentage in the ref plus cluster: 42.70815226838172
# number of points in the ref minus cluster: 4247
# actual class 1 percentage in the ref minus cluster: 40.122439368966326
# actual class 0 percentage in the ref minus cluster: 59.877560631033674
# number of points in the test plus cluster: 5906
# actual class 1 percentage in the test plus cluster: 49.69522519471724
# actual class 0 percentage in the test plus cluster: 50.30477480528276
# number of points in the test minus cluster: 4094
# actual class 1 percentage in the test minus cluster: 50.43966780654617
# actual class 0 percentage in the test minus cluster: 49.56033219345383
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 698
# neighbors in W1 709
# beta 0.6153701972300709
# beta additional 0.3846298027699291
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 722
# neighbors in W1 771
# beta 0.8977090170764058
# beta additional 0.1022909829235942
# drift: False
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5631
# actual class 1 percentage in the ref plus cluster: 56.86378973539336
# actual class 0 percentage in the ref plus cluster: 43.13621026460664
# number of points in the ref minus cluster: 4369
# actual class 1 percentage in the ref minus cluster: 41.15358205539025
# actual class 0 percentage in the ref minus cluster: 58.84641794460975
# number of points in the test plus cluster: 5915
# actual class 1 percentage in the test plus cluster: 49.68723584108199
# actual class 0 percentage in the test plus cluster: 50.31276415891801
# number of points in the test minus cluster: 4085
# actual class 1 percentage in the test minus cluster: 50.45287637698898
# actual class 0 percentage in the test minus cluster: 49.54712362301102
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 707
# neighbors in W1 709
# beta 0.521199799743095
# beta additional 0.4788002002569049
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 672
# neighbors in W1 724
# beta 0.9180879746083257
# beta additional 0.0819120253916743
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4218
# actual class 1 percentage in the ref plus cluster: 41.37031768610716
# actual class 0 percentage in the ref plus cluster: 58.62968231389284
# number of points in the ref minus cluster: 5782
# actual class 1 percentage in the ref minus cluster: 56.2953995157385
# actual class 0 percentage in the ref minus cluster: 43.7046004842615
# number of points in the test plus cluster: 4087
# actual class 1 percentage in the test plus cluster: 50.428186934181554
# actual class 0 percentage in the test plus cluster: 49.571813065818446
# number of points in the test minus cluster: 5913
# actual class 1 percentage in the test minus cluster: 49.70404194148487
# actual class 0 percentage in the test minus cluster: 50.29595805851513
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 678
# neighbors in W1 692
# beta 0.6474178977497724
# beta additional 0.3525821022502276
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 711
# neighbors in W1 714
# beta 0.5316806306273054
# beta additional 0.4683193693726946
# drift: False
#
#
# #### TEST BATCH 6 of 7 ####
# number of points in this test window: 10000
# percentage of class 1 points in this test window: 50.0
#
#  REFERENCE BATCH # 0 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 5748
# actual class 1 percentage in the ref plus cluster: 57.37647877522617
# actual class 0 percentage in the ref plus cluster: 42.62352122477383
# number of points in the ref minus cluster: 4252
# actual class 1 percentage in the ref minus cluster: 40.02822201317027
# actual class 0 percentage in the ref minus cluster: 59.97177798682973
# number of points in the test plus cluster: 5829
# actual class 1 percentage in the test plus cluster: 49.42528735632184
# actual class 0 percentage in the test plus cluster: 50.57471264367816
# number of points in the test minus cluster: 4171
# actual class 1 percentage in the test minus cluster: 50.80316470870295
# actual class 0 percentage in the test minus cluster: 49.19683529129705
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 697
# neighbors in W1 686
# beta 0.38366108873746313
# beta additional 0.6163389112625368
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 735
# neighbors in W1 657
# beta 0.018228478149871812
# beta additional 0.9817715218501282
# drift: True
#
#  REFERENCE BATCH # 1 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4365
# actual class 1 percentage in the ref plus cluster: 41.16838487972509
# actual class 0 percentage in the ref plus cluster: 58.83161512027491
# number of points in the ref minus cluster: 5635
# actual class 1 percentage in the ref minus cluster: 56.84117125110914
# actual class 0 percentage in the ref minus cluster: 43.15882874889086
# number of points in the test plus cluster: 4165
# actual class 1 percentage in the test plus cluster: 50.82833133253301
# actual class 0 percentage in the test plus cluster: 49.17166866746699
# number of points in the test minus cluster: 5835
# actual class 1 percentage in the test minus cluster: 49.40874035989717
# actual class 0 percentage in the test minus cluster: 50.59125964010283
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 665
# neighbors in W1 667
# beta 0.5218577994726259
# beta additional 0.47814220052737405
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 709
# neighbors in W1 683
# beta 0.24286945469056426
# beta additional 0.7571305453094357
# drift: False
#
#  REFERENCE BATCH # 2 of 3
# number of points in this ref window: 10000
# percentage of class 1 points in this ref window: 50.0
# number of points in the ref plus cluster: 4214
# actual class 1 percentage in the ref plus cluster: 41.31466540104414
# actual class 0 percentage in the ref plus cluster: 58.68533459895586
# number of points in the ref minus cluster: 5786
# actual class 1 percentage in the ref minus cluster: 56.32561354994815
# actual class 0 percentage in the ref minus cluster: 43.67438645005185
# number of points in the test plus cluster: 4168
# actual class 1 percentage in the test plus cluster: 50.79174664107486
# actual class 0 percentage in the test plus cluster: 49.20825335892514
# number of points in the test minus cluster: 5832
# actual class 1 percentage in the test minus cluster: 49.434156378600825
# actual class 0 percentage in the test minus cluster: 50.565843621399175
# BETA MINUS (ref+, ref-, test-)
# neighbors in W0 669
# neighbors in W1 659
# beta 0.3918509444516849
# beta additional 0.6081490555483151
# BETA PLUS (ref-, ref+, test+)
# neighbors in W0 713
# neighbors in W1 695
# beta 0.315666976808747
# beta additional 0.684333023191253
# drift: False
# [False, False, False, False, False, False, True]
