# %% [markdown]
# # UCDD on weather evaluation

# %% [markdown]
# ## Accept and preprocess the weather dataset

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler


df = pd.read_csv("../Datasets_concept_drift/real_world_data/weather_dataset.csv")

X = df.drop(columns=['Unnamed: 0', 'Label_Rain'])
y = df["Label_Rain"]

X_ref = X[:6053]
X_test = X[6053:]
y_ref = y[:6053]
y_test = y[6053:]

X_ref = X_ref.to_numpy()
X_test = X_test.to_numpy()
y_ref = y_ref.to_numpy()
y_test = y_test.to_numpy()

scaler = MinMaxScaler()
scaler.fit(X_ref)
X_ref = scaler.transform(X_ref)
X_test = scaler.transform(X_test)

print('\nreference data')
print(X_ref.shape)
print(X_ref)
print('\nreference labels')
print(y_ref.shape)
print('\ntesting data')
print(X_test.shape)
print(X_test)
print('\ntesting labels')
print(y_test.shape)
# Out:
# reference data
# (6053, 8)
# [[0.32335329 0.45853659 0.50909091 ... 0.21443737 0.00335913 0.36567926]
#  [0.34231537 0.44682927 0.53787879 ... 0.34394904 0.00326915 0.35648621]
#  [0.31636727 0.41170732 0.58181818 ... 0.25690021 0.00315918 0.35648621]
#  ...
#  [0.83532934 0.9395122  0.56363636 ... 0.16985138 0.00897767 0.89785495]
#  [0.81936128 0.88       0.58787879 ... 0.12951168 0.0084678  0.84576098]
#  [0.81437126 0.88780488 0.56363636 ... 0.10828025 0.00836782 0.84576098]]
#
# reference labels
# (6053,)
#
# testing data
# (12106, 8)
# [[0.80538922 0.84       0.57272727 ... 0.16985138 0.00855777 0.7854954 ]
#  [0.82035928 0.85853659 0.56060606 ... 0.14861996 0.00936756 0.7854954 ]
#  [0.88922156 0.87804878 0.49242424 ... 0.1910828  0.00965749 0.86823289]
#  ...
#  [0.21556886 0.28195122 0.44545455 ... 0.33970276 0.00278927 0.21552605]
#  [0.1497006  0.17756098 0.51363636 ... 0.48832272 0.00258933 0.13483146]
#  [0.05588822 0.0995122  0.68484848 ... 0.21019108 0.00137964 0.05209397]]
#
# testing labels
# (12106,)

# %% [markdown]
# ## Split the dataset to batches

# %% [markdown]
# ### Yearly batches (size=365)

# %%
(12106 - (12106 % 365)) // 365
# Out:
# 33

# %%
from eval_helpers import helpers

X_test_batches_year, y_test_batches_year = helpers.split_to_fixed_size_batches(X_test, y_test, batch_size=365)
X_ref_batches_year, y_ref_batches_year = helpers.split_to_fixed_size_batches(X_ref, y_ref, batch_size=365)

print('# yearly test batches:')
print(len(X_test_batches_year))
print(len(y_test_batches_year))
print('# yearly ref batches:')
print(len(X_ref_batches_year))
print(len(y_ref_batches_year))
# Out:
# chunk size 365
# number of chunks 33
# number of data 12106
# shape of X that can be split perfectly (12045, 8)
# number of resulting batches 33
# [[0.80538922 0.84       0.57272727 ... 0.16985138 0.00855777 0.7854954 ]
#  [0.82035928 0.85853659 0.56060606 ... 0.14861996 0.00936756 0.7854954 ]
#  [0.88922156 0.87804878 0.49242424 ... 0.1910828  0.00965749 0.86823289]
#  ...
#  [0.78043912 0.83804878 0.61969697 ... 0.14861996 0.00814788 0.80183861]
#  [0.77844311 0.87219512 0.61363636 ... 0.19532909 0.00850779 0.80183861]
#  [0.81736527 0.88780488 0.58333333 ... 0.492569   0.00868774 0.82022472]]
# (365, 8)
# chunk size 365
# number of chunks 16
# number of data 6053
# shape of X that can be split perfectly (5840, 8)
# number of resulting batches 16
# [[0.32335329 0.45853659 0.50909091 ... 0.21443737 0.00335913 0.36567926]
#  [0.34231537 0.44682927 0.53787879 ... 0.34394904 0.00326915 0.35648621]
#  [0.31636727 0.41170732 0.58181818 ... 0.25690021 0.00315918 0.35648621]
#  ...
#  [0.38123752 0.45463415 0.41212121 ... 0.34394904 0.00396897 0.37691522]
#  [0.25149701 0.31707317 0.66666667 ... 0.29723992 0.00436886 0.21348315]
#  [0.41217565 0.4702439  0.56818182 ... 0.17409766 0.00585848 0.35648621]]
# (365, 8)
# # yearly test batches:
# 33
# 33
# # yearly ref batches:
# 16
# 16

# %% [markdown]
# ### Monthly batches (size=30)

# %%
X_test_batches_month, y_test_batches_month = helpers.split_to_fixed_size_batches(X_test, y_test, batch_size=30)
X_ref_batches_month, y_ref_batches_month = helpers.split_to_fixed_size_batches(X_ref, y_ref, batch_size=30)

print('# monthly test batches:')
print(len(X_test_batches_month))
print(len(y_test_batches_month))
print('# monthly ref batches:')
print(len(X_ref_batches_month))
print(len(y_ref_batches_month))
# Out:
# chunk size 30
# number of chunks 403
# number of data 12106
# shape of X that can be split perfectly (12090, 8)
# number of resulting batches 403
# [[0.80538922 0.84       0.57272727 0.63404255 0.14285714 0.16985138
#   0.00855777 0.7854954 ]
#  [0.82035928 0.85853659 0.56060606 0.65106383 0.11278195 0.14861996
#   0.00936756 0.7854954 ]
#  [0.88922156 0.87804878 0.49242424 0.62978723 0.16165414 0.1910828
#   0.00965749 0.86823289]
#  [0.8992016  0.92682927 0.4530303  0.6212766  0.21052632 0.23142251
#   0.00987743 0.87742594]
#  [0.94111776 0.94829268 0.42272727 0.62978723 0.2556391  0.21019108
#   0.01026733 0.92849847]
#  [0.93013972 0.95219512 0.44090909 0.62978723 0.22180451 0.16985138
#   0.00987743 0.94892748]
#  [0.85129741 0.96878049 0.53181818 0.65957447 0.15413534 0.25690021
#   0.00926759 0.8886619 ]
#  [0.84431138 0.96585366 0.57878788 0.50638298 0.16541353 0.10828025
#   0.0084678  0.8886619 ]
#  [0.84231537 0.95317073 0.57575758 0.22978723 0.12030075 0.08280255
#   0.00866775 0.89785495]
#  [0.84231537 0.89170732 0.56515152 0.4893617  0.13909774 0.23142251
#   0.00866775 0.85699694]
#  [0.73752495 0.82926829 0.58636364 0.68085106 0.07894737 0.14861996
#   0.00836782 0.77630235]
#  [0.66067864 0.78731707 0.63030303 0.48510638 0.14661654 0.12951168
#   0.00695819 0.72420838]
#  [0.70159681 0.78536585 0.64242424 0.72765957 0.11654135 0.16985138
#   0.00746806 0.70480082]
#  [0.71257485 0.83121951 0.58181818 0.57446809 0.2481203  0.25690021
#   0.00737808 0.77630235]
#  [0.76047904 0.90243902 0.52424242 0.34893617 0.18796992 0.40552017
#   0.00796793 0.81613892]
#  [0.76846307 0.90926829 0.51969697 0.2893617  0.18796992 0.25690021
#   0.00776798 0.84576098]
#  [0.78243513 0.93073171 0.49848485 0.22978723 0.12030075 0.10828025
#   0.00776798 0.86414709]
#  [0.80538922 0.93268293 0.57878788 0.17021277 0.13909774 0.10828025
#   0.00836782 0.85699694]
#  [0.81237525 0.94439024 0.62727273 0.18297872 0.04135338 0.06369427
#   0.00836782 0.82533197]
#  [0.83133733 0.93853659 0.59393939 0.12765957 0.10526316 0.14861996
#   0.00855777 0.84576098]
#  [0.86027944 0.95317073 0.54090909 0.1787234  0.18045113 0.14861996
#   0.00936756 0.87742594]
#  [0.85429142 0.94536585 0.59393939 0.35744681 0.12781955 0.1910828
#   0.00906764 0.90806946]
#  [0.78542914 0.85658537 0.65151515 0.66808511 0.06015038 0.08280255
#   0.00836782 0.77630235]
#  [0.83133733 0.90439024 0.50454545 0.75744681 0.18421053 0.21019108
#   0.00906764 0.85699694]
#  [0.81936128 0.91512195 0.4969697  0.69361702 0.06390977 0.08280255
#   0.00855777 0.85699694]
#  [0.7994012  0.89853659 0.49090909 0.64680851 0.23308271 0.29723992
#   0.00827785 0.86823289]
#  [0.76147705 0.81853659 0.58484848 0.81702128 0.13909774 0.16985138
#   0.00816788 0.75383044]
#  [0.75948104 0.86439024 0.4969697  0.74468085 0.17293233 0.16985138
#   0.00785796 0.80592441]
#  [0.75449102 0.84195122 0.53181818 0.64255319 0.21428571 0.1910828
#   0.00756803 0.79673136]
#  [0.71057884 0.80097561 0.62878788 0.57446809 0.15413534 0.12951168
#   0.00776798 0.74463739]]
# (30, 8)
# chunk size 30
# number of chunks 201
# number of data 6053
# shape of X that can be split perfectly (6030, 8)
# number of resulting batches 201
# [[0.32335329 0.45853659 0.50909091 0.07234043 0.33082707 0.21443737
#   0.00335913 0.36567926]
#  [0.34231537 0.44682927 0.53787879 0.22978723 0.44360902 0.34394904
#   0.00326915 0.35648621]
#  [0.31636727 0.41170732 0.58181818 0.39148936 0.29699248 0.25690021
#   0.00315918 0.35648621]
#  [0.3253493  0.41853659 0.51515152 0.44680851 0.2481203  0.42675159
#   0.00425889 0.33707865]
#  [0.29540918 0.37073171 0.56515152 0.41276596 0.39097744 0.57324841
#   0.00366905 0.31664964]
#  [0.25848303 0.35804878 0.54090909 0.28510638 0.41729323 0.38428875
#   0.00236938 0.30541369]
#  [0.22355289 0.31707317 0.5530303  0.41702128 0.22180451 0.17409766
#   0.0026793  0.25434116]
#  [0.2994012  0.41463415 0.51060606 0.19148936 0.18421053 0.17409766
#   0.00315918 0.35648621]
#  [0.32035928 0.43609756 0.64242424 0.13617021 0.2593985  0.21443737
#   0.00296923 0.38610827]
#  [0.33433134 0.46536585 0.56060606 0.12340426 0.15413534 0.17409766
#   0.00425889 0.36567926]
#  [0.36626747 0.46146341 0.66818182 0.41702128 0.41353383 0.38428875
#   0.00405894 0.36567926]
#  [0.43113772 0.51609756 0.47424242 0.46808511 0.34962406 0.29723992
#   0.00495871 0.46884576]
#  [0.43013972 0.53756098 0.44545455 0.29361702 0.21428571 0.25690021
#   0.00456881 0.46884576]
#  [0.38323353 0.51414634 0.4469697  0.12765957 0.28947368 0.32271762
#   0.00405894 0.43820225]
#  [0.23552894 0.35707317 0.5030303  0.03829787 0.72556391 0.59872611
#   0.00357907 0.19305414]
#  [0.07185629 0.15804878 0.82727273 0.35319149 0.43609023 0.55414013
#   0.00126967 0.08069459]
#  [0.24850299 0.34341463 0.58030303 0.44680851 0.35714286 0.34394904
#   0.00335913 0.23391216]
#  [0.33532934 0.43512195 0.4469697  0.46382979 0.32706767 0.29723992
#   0.00335913 0.38610827]
#  [0.33632735 0.44195122 0.46969697 0.36170213 0.2481203  0.34394904
#   0.0034691  0.39734423]
#  [0.33832335 0.46243902 0.55151515 0.12765957 0.31954887 0.34394904
#   0.0034691  0.39734423]
#  [0.38223553 0.49463415 0.47121212 0.16595745 0.43233083 0.38428875
#   0.00467878 0.38610827]
#  [0.40419162 0.51707317 0.4969697  0.22978723 0.59022556 0.38428875
#   0.00436886 0.41777324]
#  [0.33033932 0.45073171 0.5530303  0.22553191 0.45864662 0.38428875
#   0.0030692  0.40858018]
#  [0.32634731 0.44       0.57121212 0.5106383  0.37593985 0.34394904
#   0.00357907 0.36567926]
#  [0.31736527 0.43414634 0.57424242 0.34468085 0.27819549 0.27813163
#   0.00377902 0.3258427 ]
#  [0.41417166 0.49853659 0.48636364 0.3106383  0.34586466 0.32271762
#   0.00456881 0.42900919]
#  [0.4001996  0.50536585 0.56969697 0.44255319 0.32706767 0.38428875
#   0.00416892 0.44841675]
#  [0.35628743 0.45463415 0.6030303  0.39148936 0.26691729 0.21443737
#   0.00425889 0.36567926]
#  [0.41417166 0.5102439  0.53333333 0.45531915 0.30075188 0.42675159
#   0.00447884 0.45760981]
#  [0.46806387 0.57268293 0.46363636 0.36170213 0.11278195 0.17409766
#   0.00546858 0.50051073]]
# (30, 8)
# # monthly test batches:
# 403
# 403
# # monthly ref batches:
# 201
# 201

# %% [markdown]
# ## Helper function

# %%
from eval_helpers import kmeans_verbose_helpers


def write_kmeans_results_ucdd_helper(output_filename_no_extension, ref_batches, n_init, max_iter, tol, random_state):
    # dummy = [np.asarray(1), np.asarray(2), np.asarray(3)]
    combinations = []
    for i in range(len(ref_batches)):
    #     combinations.append(np.vstack((dummy[i], dummy[(i + 1) % 3])))
        combinations.append(np.vstack((ref_batches[i], ref_batches[(i + 1) % 3])))
        
    all_results_from_combinations = []
    for i, combination in enumerate(combinations):
        filename = output_filename_no_extension + str(i) + '.txt'
        print('filename', filename)
        kmeans_verbose_helpers.write_verbose_kmeans_to_file(result_filename=output_filename_no_extension + str(i) + '.txt',
                                     data_to_cluster=combination,
                                     n_clusters=2, n_init=n_init, max_iter=max_iter, tol=tol, random_state=random_state)
        output_dicts = kmeans_verbose_helpers.convert_kmeans_output_file_to_dicts(filename, n_init=n_init)
        all_results_from_combinations.append(output_dicts)
        kmeans_verbose_helpers.print_stats_from_kmeans_output_dicts(output_dicts)
        
    kmeans_verbose_helpers.print_stats_from_all_combinations(all_results_from_combinations)

# %% [markdown]
# ## Imports

# %%
import importlib
from eval_helpers import ucdd_eval_real_world
from core import ucdd_supported_parameters as spms
importlib.reload(ucdd_eval_real_world)
from core import ucdd
importlib.reload(ucdd)
# Out:
# <module 'core.ucdd' from 'C:\\Users\\jpohl\\PycharmProjects\\clustering-drift-detection\\ucdd_improved\\core\\ucdd.py'>

# %% [markdown]
# ## Yearly evaluation

# %% [markdown]
# ### Find suitable KMeans clustering parameters

# %%
write_kmeans_results_ucdd_helper('weather_kmeans_year/weather_output_year', X_ref_batches_year, n_init=100, max_iter=500, tol=0,
                                 random_state=1053)
# Out:
# filename weather_kmeans_year/weather_output_year0.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 78.86974728960048
# maximum initial inertia: 216.1735077714928
# number of unique final inertia values: 1
# minimum final inertia: 67.63399508434559
# maximum final inertia: 67.63399508434559
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year1.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 71.47315728070872
# maximum initial inertia: 246.35881897375126
# number of unique final inertia values: 1
# minimum final inertia: 62.76207179848868
# maximum final inertia: 62.76207179848868
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year2.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 87.47345449347397
# maximum initial inertia: 272.87332076775033
# number of unique final inertia values: 2
# minimum final inertia: 72.98736340009974
# maximum final inertia: 72.98774810523548
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year3.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 71.70689157731748
# maximum initial inertia: 259.83510736086566
# number of unique final inertia values: 3
# minimum final inertia: 61.04014904092399
# maximum final inertia: 61.040848449528994
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year4.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 86.95372087137707
# maximum initial inertia: 245.48312889663913
# number of unique final inertia values: 1
# minimum final inertia: 69.2055902729827
# maximum final inertia: 69.2055902729827
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year5.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 78.32981438824183
# maximum initial inertia: 229.06583128094917
# number of unique final inertia values: 1
# minimum final inertia: 63.90027840592604
# maximum final inertia: 63.90027840592604
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year6.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 79.69158913631986
# maximum initial inertia: 224.64419944696726
# number of unique final inertia values: 1
# minimum final inertia: 73.98329719060358
# maximum final inertia: 73.98329719060358
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year7.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 98.55554143029964
# maximum initial inertia: 329.20042221458465
# number of unique final inertia values: 3
# minimum final inertia: 79.37709963503458
# maximum final inertia: 79.3797105016311
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year8.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 72.96897163310803
# maximum initial inertia: 219.4519663863348
# number of unique final inertia values: 1
# minimum final inertia: 63.52488735343812
# maximum final inertia: 63.52488735343812
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year9.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 72.01868295031363
# maximum initial inertia: 215.5077792795994
# number of unique final inertia values: 4
# minimum final inertia: 59.961144657338814
# maximum final inertia: 59.9625463578963
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year10.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 73.39530704038921
# maximum initial inertia: 256.753739866465
# number of unique final inertia values: 2
# minimum final inertia: 60.974725887767455
# maximum final inertia: 60.974772036287625
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year11.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 82.43557737145177
# maximum initial inertia: 237.516922652304
# number of unique final inertia values: 1
# minimum final inertia: 69.08066438345472
# maximum final inertia: 69.08066438345472
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year12.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 91.19888549283208
# maximum initial inertia: 283.8470941012449
# number of unique final inertia values: 1
# minimum final inertia: 79.84054363153308
# maximum final inertia: 79.84054363153308
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year13.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 93.50205173268876
# maximum initial inertia: 241.1936236361607
# number of unique final inertia values: 1
# minimum final inertia: 79.88356642728908
# maximum final inertia: 79.88356642728908
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year14.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 85.16378513911091
# maximum initial inertia: 241.99616588907122
# number of unique final inertia values: 1
# minimum final inertia: 70.24865446707666
# maximum final inertia: 70.24865446707666
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_year/weather_output_year15.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 76.15532832044285
# maximum initial inertia: 265.69886751692667
# number of unique final inertia values: 5
# minimum final inertia: 63.79221313236531
# maximum final inertia: 63.79475764977205
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# {'total_max_iterations': 13, 'total_min_init_inertia': 71.47315728070872, 'total_max_init_inertia': 329.20042221458465, 'total_min_final_inertia': 59.961144657338814, 'total_max_final_inertia': 79.88356642728908, 'total_num_convergences': 1600, 'total_num_strict_convergences': 1600, 'total_num_tol_based_convergences': 0}

# %% [markdown]
# ### Read the defined yearly drift locations

# %%
import csv

true_drift_bool_year = []
with open('../Datasets_concept_drift/real_world_data_drifts/weather/weather_yearly_drifts.csv') as f:
    rdr = csv.reader(f, delimiter=',')
    for row in rdr:
        true_drift_bool_year.append(row)
    true_drift_bool_year = true_drift_bool_year[0] # only one row of important data
    true_drift_bool_year = [b == 'True' for b in true_drift_bool_year]
print(true_drift_bool_year)
# Out:
# [False, True, True, True, False, True, False, False, False, False, True, True, False, False, True, True, True, True, False, False, False, True, False, True, True, False, True, True, True, False, False, True, True]

# %% [markdown]
# ### Use the drift locations and best clustering parameters for the evaluation

# %%
import time


start_regular = time.time()
_, fpr_mean, _, det_acc_mean, _ = ucdd_eval_real_world.all_drifting_batches_randomness_robust(
    reference_data_batches=X_ref_batches_year,
    testing_data_batches=X_test_batches_year,
    true_drift_bool=true_drift_bool_year,
    train_batch_strategy=spms.TrainBatchStrategies.SUBMAJORITY,
    additional_check=True,
    n_init=100, max_iter=13000, tol=0,
    first_random_state=0,
    min_runs=2, std_err_threshold=0.05,
    parallel=False
)

print('yearly mean FPR:', fpr_mean)
print('yearly mean detection accuracy:', det_acc_mean)
print('time(sec):', time.time() - start_regular)

start_parallel = time.time()
_, fpr_mean, _, det_acc_mean, _ = ucdd_eval_real_world.all_drifting_batches_randomness_robust(
    reference_data_batches=X_ref_batches_year,
    testing_data_batches=X_test_batches_year,
    true_drift_bool=true_drift_bool_year,
    train_batch_strategy=spms.TrainBatchStrategies.SUBMAJORITY,
    additional_check=True,
    n_init=100, max_iter=13000, tol=0,
    first_random_state=0,
    min_runs=2, std_err_threshold=0.05,
    parallel=False
)

print('yearly mean FPR:', fpr_mean)
print('yearly mean detection accuracy:', det_acc_mean)
print('time(sec):', time.time() - start_regular)
# Out:
# min_runs 2
# random_state
# 0
# #### TEST BATCH 0 of 33 ####
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:
# Exception ignored in: 'sklearn.cluster._k_means_common._relocate_empty_clusters_dense'
# Traceback (most recent call last):
#   File "<__array_function__ internals>", line 177, in where
# KeyboardInterrupt:
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# n_init 100 max_iter 13000 tol 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       5 from core import ucdd
#       6 importlib.reload(ucdd)
# ----> 8 _, fpr_mean, _, det_acc_mean, _ = ucdd_eval_real_world.all_drifting_batches_randomness_robust(
#       9     reference_data_batches=X_ref_batches_year,
#      10     testing_data_batches=X_test_batches_year,
#      11     true_drift_bool=true_drift_bool_year,
#      12     train_batch_strategy=spms.TrainBatchStrategies.SUBMAJORITY,
#      13     additional_check=True,
#      14     n_init=100, max_iter=13000, tol=0,
#      15     first_random_state=0,
#      16     min_runs=2, std_err_threshold=0.05
#      17 )
#      19 print('yearly mean FPR:', fpr_mean)
#      20 print('yearly mean detection accuracy:', det_acc_mean)
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\eval_helpers\ucdd_eval_real_world.py:59, in all_drifting_batches_randomness_robust(reference_data_batches, testing_data_batches, true_drift_bool, train_batch_strategy, additional_check, n_init, max_iter, tol, first_random_state, min_runs, std_err_threshold)
#      57 random_state = first_random_state
#      58 while num_runs < min_runs or max(fpr_std_err, detection_accuracy_std_err) > std_err_threshold:
# ---> 59     signaled_batches_bool = all_drifting_batches(
#      60         reference_data_batches,
#      61         testing_data_batches,
#      62         train_batch_strategy=train_batch_strategy,
#      63         additional_check=additional_check,
#      64         n_init=n_init,
#      65         max_iter=max_iter,
#      66         tol=tol,
#      67         random_state=random_state
#      68     )
#      70     # print('drifting_batches_bool')
#      71     # print(drifting_batches_bool)
#      73     fpr, detection_accuracy = real_world_metrics(signaled_batches_bool, true_drift_bool)
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:194, in all_drifting_batches(reference_data_batches, testing_data_batches, train_batch_strategy, additional_check, n_init, max_iter, tol, random_state)
#     192 num_ref_drifts = 0 # how many training batches signal drift against this testing batch
#     193 for j, ref_window in enumerate(reference_data_batches):
# --> 194     drift_here = concept_drift_detected(
#     195         ref_window, test_window, additional_check, n_init, max_iter, tol, random_state)
#     196     if drift_here:
#     197         num_ref_drifts += 1
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:143, in concept_drift_detected(ref_window, test_window, additional_check, n_init, max_iter, tol, random_state, threshold, debug)
#     117 def concept_drift_detected(
#     118         ref_window,
#     119         test_window,
#    (...)
#     126         debug=False,
#     127 ):
#     128     """
#     129     Detect whether a concept drift occurred based on one reference and one testing window
#     130
#    (...)
#     140     :return: true if drift is detected based on the two windows, false otherwise
#     141     """
#     142     ref_plus, ref_minus, test_plus, test_minus = \
# --> 143         join_predict_split(ref_window, test_window,
#     144                            n_init=n_init, max_iter=max_iter, tol=tol, random_state=random_state)
#     146     if debug: print('BETA MINUS (ref+, ref-, test-)')
#     147     beta_minus, beta_minus_additional = compute_beta(
#     148         ref_plus, ref_minus, test_minus)
#
# File ~\PycharmProjects\clustering-drift-detection\ucdd_improved\core\ucdd.py:63, in join_predict_split(ref_window, test_window, n_init, max_iter, tol, random_state)
#      60 print('n_init', n_init, 'max_iter', max_iter, 'tol', tol)
#      62 # predict their label values
# ---> 63 predicted_labels = KMeans(n_clusters=2, n_init=n_init, max_iter=max_iter, tol=tol, random_state=random_state)\
#      64     .fit_predict(window_union)
#      66 # split values by predicted label and window
#      67 return split_back_to_windows(window_union, predicted_labels, ref_window.shape[0], test_window.shape[0])
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\cluster\_kmeans.py:996, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#     973 def fit_predict(self, X, y=None, sample_weight=None):
#     974     """Compute cluster centers and predict cluster index for each sample.
#     975
#     976     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#     994         Index of the cluster each sample belongs to.
#     995     """
# --> 996     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\cluster\_kmeans.py:1417, in KMeans.fit(self, X, y, sample_weight)
#    1414     print("Initialization complete")
#    1416 # run a k-means once
# -> 1417 labels, inertia, centers, n_iter_ = kmeans_single(
#    1418     X,
#    1419     sample_weight,
#    1420     centers_init,
#    1421     max_iter=self.max_iter,
#    1422     verbose=self.verbose,
#    1423     tol=self._tol,
#    1424     x_squared_norms=x_squared_norms,
#    1425     n_threads=self._n_threads,
#    1426 )
#    1428 # determine if these results are the best so far
#    1429 # we chose a new run if it has a better inertia and the clustering is
#    1430 # different from the best so far (it's possible that the inertia is
#    1431 # slightly better even if the clustering is the same with potentially
#    1432 # permuted labels, due to rounding errors)
#    1433 if best_inertia is None or (
#    1434     inertia < best_inertia
#    1435     and not _is_same_clustering(labels, best_labels, self.n_clusters)
#    1436 ):
#
# File c:\users\jpohl\pycharmprojects\clustering-drift-detection\venv\lib\site-packages\sklearn\cluster\_kmeans.py:700, in _kmeans_single_lloyd(X, sample_weight, centers_init, max_iter, verbose, x_squared_norms, tol, n_threads)
#     685     if not strict_convergence:
#     686         # rerun E-step so that predicted labels match cluster centers
#     687         lloyd_iter(
#     688             X,
#     689             sample_weight,
#    (...)
#     697             update_centers=False,
#     698         )
# --> 700 inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#     702 return labels, inertia, centers, i + 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Monthly evaluation

# %% [markdown]
# ### Choose a subset of reference batches

# %%
import random

# taking only 10% of reference batches
X_ref_batches_month_subset = random.sample(X_ref_batches_month, int(len(X_ref_batches_month) * 0.1))

# %% [markdown]
# ### Find suitable KMeans clustering parameters

# %%
write_kmeans_results_ucdd_helper('weather_kmeans_month/weather_output_month', X_ref_batches_month, n_init=100, max_iter=500, tol=0,
                                 random_state=1053)
# Out:
# filename weather_kmeans_month/weather_output_month0.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.4902473372212155
# maximum initial inertia: 9.535698525021576
# number of unique final inertia values: 18
# minimum final inertia: 3.669833449585525
# maximum final inertia: 4.473960561286574
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month1.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.510056415586051
# maximum initial inertia: 10.878363271753855
# number of unique final inertia values: 11
# minimum final inertia: 3.6884691873524544
# maximum final inertia: 4.330712480412381
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month2.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 15
# minimum initial inertia: 4.739876427583074
# maximum initial inertia: 13.335120593838178
# number of unique final inertia values: 5
# minimum final inertia: 3.936933665863453
# maximum final inertia: 4.979036094069366
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month3.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.471718900865436
# maximum initial inertia: 14.291865619742811
# number of unique final inertia values: 27
# minimum final inertia: 4.936312424414737
# maximum final inertia: 5.4624896836851216
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month4.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.89473115041848
# maximum initial inertia: 10.34366627365962
# number of unique final inertia values: 7
# minimum final inertia: 4.438564612897257
# maximum final inertia: 5.822356271453621
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month5.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 4.05939130575654
# maximum initial inertia: 18.653360656031058
# number of unique final inertia values: 1
# minimum final inertia: 3.4005350374055907
# maximum final inertia: 3.4005350374055907
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month6.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.586668701828307
# maximum initial inertia: 18.32770799208286
# number of unique final inertia values: 1
# minimum final inertia: 4.059412496562496
# maximum final inertia: 4.059412496562496
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month7.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 3.9276214293856384
# maximum initial inertia: 17.452027132155038
# number of unique final inertia values: 1
# minimum final inertia: 3.298429252011697
# maximum final inertia: 3.298429252011697
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month8.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.625222021586234
# maximum initial inertia: 16.66281223297056
# number of unique final inertia values: 1
# minimum final inertia: 3.809081363191172
# maximum final inertia: 3.809081363191172
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month9.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.86168582051906
# maximum initial inertia: 14.89023857135215
# number of unique final inertia values: 1
# minimum final inertia: 4.462291649410061
# maximum final inertia: 4.462291649410061
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month10.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 4.107686160448337
# maximum initial inertia: 8.010521614393673
# number of unique final inertia values: 2
# minimum final inertia: 3.495161015543496
# maximum final inertia: 3.5917559048547893
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month11.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 4.865944371898753
# maximum initial inertia: 12.386697649703919
# number of unique final inertia values: 28
# minimum final inertia: 4.122028076816554
# maximum final inertia: 4.660903238163101
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month12.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 4.582613766536836
# maximum initial inertia: 9.539547566970665
# number of unique final inertia values: 10
# minimum final inertia: 3.794039647093515
# maximum final inertia: 3.836674860863313
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month13.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.564155588364659
# maximum initial inertia: 12.069898801126666
# number of unique final inertia values: 4
# minimum final inertia: 3.6334881766920395
# maximum final inertia: 5.5372999102692555
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month14.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 6.0705634037665925
# maximum initial inertia: 16.17550460823346
# number of unique final inertia values: 1
# minimum final inertia: 5.219182870042408
# maximum final inertia: 5.219182870042408
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month15.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 6.1829340272598
# maximum initial inertia: 17.621965533621136
# number of unique final inertia values: 17
# minimum final inertia: 5.131339339525947
# maximum final inertia: 6.226960526451775
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month16.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 5.042278977368087
# maximum initial inertia: 14.015533372536115
# number of unique final inertia values: 3
# minimum final inertia: 3.9470220652423573
# maximum final inertia: 5.072990885348766
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month17.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.032917653805104
# maximum initial inertia: 18.174407515922336
# number of unique final inertia values: 1
# minimum final inertia: 3.3794457519135648
# maximum final inertia: 3.3794457519135648
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month18.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.331837276006214
# maximum initial inertia: 18.48512065662333
# number of unique final inertia values: 1
# minimum final inertia: 3.7749337931255695
# maximum final inertia: 3.7749337931255695
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month19.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 3.815462967954708
# maximum initial inertia: 14.442006837408893
# number of unique final inertia values: 1
# minimum final inertia: 3.2335542772128583
# maximum final inertia: 3.2335542772128583
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month20.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.7664736588174645
# maximum initial inertia: 17.27853084951392
# number of unique final inertia values: 1
# minimum final inertia: 3.385200149402173
# maximum final inertia: 3.385200149402173
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month21.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 4.844984605399529
# maximum initial inertia: 12.571405196169602
# number of unique final inertia values: 3
# minimum final inertia: 4.243640413877567
# maximum final inertia: 4.273219794410175
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month22.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 4.560171090502603
# maximum initial inertia: 8.899665165777341
# number of unique final inertia values: 1
# minimum final inertia: 3.7715101993990903
# maximum final inertia: 3.7715101993990903
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month23.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 4.211112834076254
# maximum initial inertia: 10.572873224308918
# number of unique final inertia values: 1
# minimum final inertia: 3.644882319054309
# maximum final inertia: 3.644882319054309
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month24.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 6.0801663953532765
# maximum initial inertia: 14.403780607661247
# number of unique final inertia values: 8
# minimum final inertia: 5.405305338959004
# maximum final inertia: 5.569347804952093
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month25.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 15
# minimum initial inertia: 6.317763532714007
# maximum initial inertia: 16.558064114696045
# number of unique final inertia values: 4
# minimum final inertia: 5.147918744115269
# maximum final inertia: 6.613974508483107
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month26.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 18
# minimum initial inertia: 4.285009784034924
# maximum initial inertia: 11.742708177854748
# number of unique final inertia values: 31
# minimum final inertia: 3.854390422779642
# maximum final inertia: 4.445330846783494
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month27.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.495679595329389
# maximum initial inertia: 12.443281900935915
# number of unique final inertia values: 18
# minimum final inertia: 4.6176167836052935
# maximum final inertia: 5.718533744476598
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month28.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 5.424819986578244
# maximum initial inertia: 12.84209917457005
# number of unique final inertia values: 11
# minimum final inertia: 4.536111186060989
# maximum final inertia: 5.090375488563646
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month29.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.654668070169742
# maximum initial inertia: 14.793105900335659
# number of unique final inertia values: 1
# minimum final inertia: 3.9351200798159467
# maximum final inertia: 3.9351200798159467
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month30.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.755176037844156
# maximum initial inertia: 15.354149245695366
# number of unique final inertia values: 1
# minimum final inertia: 3.429573802193598
# maximum final inertia: 3.429573802193598
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month31.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.230230115299052
# maximum initial inertia: 18.878249159105845
# number of unique final inertia values: 1
# minimum final inertia: 3.297077643333956
# maximum final inertia: 3.297077643333956
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month32.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.376846457741506
# maximum initial inertia: 16.00792084823358
# number of unique final inertia values: 1
# minimum final inertia: 3.696596626342354
# maximum final inertia: 3.696596626342354
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month33.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.414640906381807
# maximum initial inertia: 12.774569872484761
# number of unique final inertia values: 3
# minimum final inertia: 4.854645927910178
# maximum final inertia: 4.8791217921382755
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month34.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.196331903536507
# maximum initial inertia: 10.332890655366866
# number of unique final inertia values: 4
# minimum final inertia: 3.635623226230713
# maximum final inertia: 3.65032484859333
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month35.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 5.598686534836579
# maximum initial inertia: 13.144846533150494
# number of unique final inertia values: 25
# minimum final inertia: 5.207654185031506
# maximum final inertia: 5.9941692162681735
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month36.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 6.271746680167318
# maximum initial inertia: 13.731846183641016
# number of unique final inertia values: 15
# minimum final inertia: 5.686802269298
# maximum final inertia: 6.818962388053692
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month37.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 5.677134848922102
# maximum initial inertia: 14.699028206485812
# number of unique final inertia values: 1
# minimum final inertia: 4.640866780170519
# maximum final inertia: 4.640866780170519
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month38.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 16
# minimum initial inertia: 4.74931026450202
# maximum initial inertia: 12.40111841999369
# number of unique final inertia values: 2
# minimum final inertia: 4.301243678796328
# maximum final inertia: 5.599103353748201
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month39.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.4356282849715765
# maximum initial inertia: 11.499219301998576
# number of unique final inertia values: 3
# minimum final inertia: 3.5720843417663826
# maximum final inertia: 4.982228994459946
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month40.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.445722330502263
# maximum initial inertia: 16.601299738774024
# number of unique final inertia values: 2
# minimum final inertia: 4.31502156567439
# maximum final inertia: 5.861223578755464
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month41.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.9031146061651896
# maximum initial inertia: 14.57925741014568
# number of unique final inertia values: 1
# minimum final inertia: 3.3180524627555634
# maximum final inertia: 3.3180524627555634
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month42.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.153173485149998
# maximum initial inertia: 15.270236549472461
# number of unique final inertia values: 1
# minimum final inertia: 3.694874638321675
# maximum final inertia: 3.694874638321675
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month43.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.7587725839199413
# maximum initial inertia: 17.82883602378722
# number of unique final inertia values: 1
# minimum final inertia: 3.223484945355541
# maximum final inertia: 3.223484945355541
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month44.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.4428308896722806
# maximum initial inertia: 14.875098034695629
# number of unique final inertia values: 1
# minimum final inertia: 3.0811744758863537
# maximum final inertia: 3.0811744758863537
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month45.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 5.717888281340113
# maximum initial inertia: 12.532174632142931
# number of unique final inertia values: 7
# minimum final inertia: 4.908403164905602
# maximum final inertia: 4.93318057023917
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month46.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.71652225982467
# maximum initial inertia: 13.076960703160687
# number of unique final inertia values: 3
# minimum final inertia: 4.024363987566782
# maximum final inertia: 4.385786421534047
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month47.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.644395514244626
# maximum initial inertia: 10.04799615532374
# number of unique final inertia values: 33
# minimum final inertia: 4.0943379259711215
# maximum final inertia: 4.45140908138318
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month48.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 5.679209882767891
# maximum initial inertia: 12.933744553503896
# number of unique final inertia values: 3
# minimum final inertia: 4.978129344528237
# maximum final inertia: 4.985021386334189
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month49.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 6.693103720818605
# maximum initial inertia: 18.562510182546283
# number of unique final inertia values: 5
# minimum final inertia: 5.053668175222969
# maximum final inertia: 5.135702187333543
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month50.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 17
# minimum initial inertia: 4.770608883902467
# maximum initial inertia: 11.685819197399475
# number of unique final inertia values: 2
# minimum final inertia: 4.173064942625161
# maximum final inertia: 4.176172595678045
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month51.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.76916106933796
# maximum initial inertia: 13.32778973821425
# number of unique final inertia values: 13
# minimum final inertia: 5.102067140821131
# maximum final inertia: 5.302846342206164
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month52.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 4.3783333368474775
# maximum initial inertia: 9.373299134509503
# number of unique final inertia values: 21
# minimum final inertia: 3.7051868528790717
# maximum final inertia: 4.155437643546877
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month53.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.9427648861196714
# maximum initial inertia: 13.989179833909002
# number of unique final inertia values: 1
# minimum final inertia: 3.182346461406628
# maximum final inertia: 3.182346461406628
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month54.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.444262484299017
# maximum initial inertia: 16.439693160330602
# number of unique final inertia values: 1
# minimum final inertia: 3.944291301224187
# maximum final inertia: 3.944291301224187
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month55.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 3.738798722042682
# maximum initial inertia: 20.228330399172
# number of unique final inertia values: 1
# minimum final inertia: 3.214191332364298
# maximum final inertia: 3.214191332364298
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month56.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.6499241910196356
# maximum initial inertia: 14.3738376940046
# number of unique final inertia values: 1
# minimum final inertia: 2.9380938423969525
# maximum final inertia: 2.9380938423969525
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month57.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 4.970953119551094
# maximum initial inertia: 13.418558141943548
# number of unique final inertia values: 1
# minimum final inertia: 4.743026661771602
# maximum final inertia: 4.743026661771602
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month58.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 7.193326434228624
# maximum initial inertia: 16.281293377613903
# number of unique final inertia values: 22
# minimum final inertia: 6.275105286830365
# maximum final inertia: 7.52197373667313
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month59.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.35439415418391
# maximum initial inertia: 13.772687173815845
# number of unique final inertia values: 30
# minimum final inertia: 4.725172493037358
# maximum final inertia: 5.2350666454419175
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month60.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 5.472924970167875
# maximum initial inertia: 14.360844242336295
# number of unique final inertia values: 10
# minimum final inertia: 4.623664696138398
# maximum final inertia: 5.71916517862972
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month61.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 15
# minimum initial inertia: 5.424359439559064
# maximum initial inertia: 11.518741739696798
# number of unique final inertia values: 10
# minimum final inertia: 4.373000805704145
# maximum final inertia: 4.584832316258933
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month62.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 3.817229178955212
# maximum initial inertia: 9.957040727030353
# number of unique final inertia values: 21
# minimum final inertia: 3.4167923774508844
# maximum final inertia: 3.5882773775977372
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month63.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 5.071855432360116
# maximum initial inertia: 10.934926896207708
# number of unique final inertia values: 3
# minimum final inertia: 4.205981617055888
# maximum final inertia: 4.7990954947413265
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month64.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 4.9284516439927195
# maximum initial inertia: 12.775956000881004
# number of unique final inertia values: 10
# minimum final inertia: 4.118246908076254
# maximum final inertia: 4.853381611517008
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month65.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.531800005736819
# maximum initial inertia: 19.06030504860189
# number of unique final inertia values: 1
# minimum final inertia: 3.6660409830753635
# maximum final inertia: 3.6660409830753635
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month66.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 4.627689529846844
# maximum initial inertia: 21.829979512890525
# number of unique final inertia values: 1
# minimum final inertia: 4.322212234364538
# maximum final inertia: 4.322212234364538
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month67.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.66768487225969
# maximum initial inertia: 21.852758582736737
# number of unique final inertia values: 1
# minimum final inertia: 3.6722281860744945
# maximum final inertia: 3.6722281860744945
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month68.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 3.6651578455027516
# maximum initial inertia: 16.731546889881262
# number of unique final inertia values: 1
# minimum final inertia: 2.962884238407852
# maximum final inertia: 2.962884238407852
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month69.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 4.44287875227181
# maximum initial inertia: 12.934010587729006
# number of unique final inertia values: 2
# minimum final inertia: 3.9778501812874603
# maximum final inertia: 7.539200357659796
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month70.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 3.6596072277908993
# maximum initial inertia: 7.694088519688439
# number of unique final inertia values: 13
# minimum final inertia: 3.326799604304157
# maximum final inertia: 3.896209911618114
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month71.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.752807942872233
# maximum initial inertia: 11.96958849310795
# number of unique final inertia values: 22
# minimum final inertia: 4.307008815301673
# maximum final inertia: 4.857967580152012
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month72.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 4.6218509591825825
# maximum initial inertia: 9.031367545585894
# number of unique final inertia values: 9
# minimum final inertia: 3.6414013923483144
# maximum final inertia: 4.528289049124678
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month73.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 7.608691369527551
# maximum initial inertia: 21.12034920838019
# number of unique final inertia values: 6
# minimum final inertia: 6.995620305023262
# maximum final inertia: 7.044911420579926
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month74.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.762656570740559
# maximum initial inertia: 15.459690143412585
# number of unique final inertia values: 3
# minimum final inertia: 4.124323322621204
# maximum final inertia: 6.50758173818177
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month75.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 16
# minimum initial inertia: 6.12104302649241
# maximum initial inertia: 15.029779270007772
# number of unique final inertia values: 7
# minimum final inertia: 5.131514594441821
# maximum final inertia: 6.472104099828877
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month76.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 4.698533460314702
# maximum initial inertia: 13.24536180123677
# number of unique final inertia values: 14
# minimum final inertia: 4.177634479820219
# maximum final inertia: 4.810087737980943
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month77.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 5.925320758982039
# maximum initial inertia: 17.93379192727296
# number of unique final inertia values: 1
# minimum final inertia: 5.128508033687254
# maximum final inertia: 5.128508033687254
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month78.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 5.4453073093116675
# maximum initial inertia: 19.682023020184246
# number of unique final inertia values: 1
# minimum final inertia: 4.917856197896045
# maximum final inertia: 4.917856197896045
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month79.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 4.386404044680696
# maximum initial inertia: 17.097205561985238
# number of unique final inertia values: 1
# minimum final inertia: 3.60127898713114
# maximum final inertia: 3.60127898713114
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month80.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 3
# minimum initial inertia: 4.190999470895229
# maximum initial inertia: 18.15570478874304
# number of unique final inertia values: 1
# minimum final inertia: 3.68788586514441
# maximum final inertia: 3.68788586514441
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month81.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 6.000777705166174
# maximum initial inertia: 18.41229726511301
# number of unique final inertia values: 1
# minimum final inertia: 4.791127032286071
# maximum final inertia: 4.791127032286071
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month82.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.5038565976844005
# maximum initial inertia: 9.84117131888399
# number of unique final inertia values: 3
# minimum final inertia: 3.8333928955659933
# maximum final inertia: 5.62030979692365
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month83.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.312573412335716
# maximum initial inertia: 15.773283974820405
# number of unique final inertia values: 3
# minimum final inertia: 4.493508171857215
# maximum final inertia: 4.541693714707086
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month84.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.868354550363433
# maximum initial inertia: 15.017600475736149
# number of unique final inertia values: 15
# minimum final inertia: 4.740159405631516
# maximum final inertia: 4.788949222690865
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month85.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 6.451618587552645
# maximum initial inertia: 14.676383948918449
# number of unique final inertia values: 23
# minimum final inertia: 5.6919910238541505
# maximum final inertia: 5.856900651215927
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month86.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 5.654229085789306
# maximum initial inertia: 15.620315319550123
# number of unique final inertia values: 13
# minimum final inertia: 4.819423317311205
# maximum final inertia: 5.4752196917233675
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month87.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.5224191888650696
# maximum initial inertia: 13.36389480745033
# number of unique final inertia values: 14
# minimum final inertia: 4.9479042500972135
# maximum final inertia: 5.05998847719519
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month88.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.046646178176821
# maximum initial inertia: 11.776768652808284
# number of unique final inertia values: 16
# minimum final inertia: 4.70080921169605
# maximum final inertia: 4.724255325105812
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month89.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 5.689416801034684
# maximum initial inertia: 22.102803110996145
# number of unique final inertia values: 1
# minimum final inertia: 4.878119514328499
# maximum final inertia: 4.878119514328499
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month90.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 5.461516982379088
# maximum initial inertia: 16.85404562434791
# number of unique final inertia values: 1
# minimum final inertia: 4.707360834451362
# maximum final inertia: 4.707360834451362
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month91.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 5.230147071185403
# maximum initial inertia: 14.274968936059668
# number of unique final inertia values: 1
# minimum final inertia: 4.147089332326217
# maximum final inertia: 4.147089332326217
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month92.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.053544441071404
# maximum initial inertia: 14.969950769860674
# number of unique final inertia values: 1
# minimum final inertia: 3.351029685725628
# maximum final inertia: 3.351029685725628
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month93.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.131258355597347
# maximum initial inertia: 14.743973549645355
# number of unique final inertia values: 1
# minimum final inertia: 3.929664640793118
# maximum final inertia: 3.929664640793118
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month94.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.968864998225284
# maximum initial inertia: 13.869765551211215
# number of unique final inertia values: 16
# minimum final inertia: 4.27302604318408
# maximum final inertia: 4.703872187331788
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month95.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 5.485114041732545
# maximum initial inertia: 14.016759519981703
# number of unique final inertia values: 3
# minimum final inertia: 4.594814911062884
# maximum final inertia: 5.816797556381403
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month96.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.667232760314559
# maximum initial inertia: 12.199737875479359
# number of unique final inertia values: 7
# minimum final inertia: 3.9563987226534056
# maximum final inertia: 3.993170921555145
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month97.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.57785621277157
# maximum initial inertia: 11.29494035375918
# number of unique final inertia values: 5
# minimum final inertia: 3.615856752860898
# maximum final inertia: 3.6272407406164784
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month98.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 4.473888805657405
# maximum initial inertia: 9.96144171853897
# number of unique final inertia values: 24
# minimum final inertia: 3.7799892980785668
# maximum final inertia: 4.628888131551215
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month99.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 4.947913512635639
# maximum initial inertia: 11.927553399529923
# number of unique final inertia values: 1
# minimum final inertia: 3.6928807782215523
# maximum final inertia: 3.6928807782215523
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month100.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 5.276523585143678
# maximum initial inertia: 11.21483408946713
# number of unique final inertia values: 3
# minimum final inertia: 4.192835570288662
# maximum final inertia: 4.31636803070498
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month101.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.338497721728065
# maximum initial inertia: 14.29601810553207
# number of unique final inertia values: 1
# minimum final inertia: 3.5485520910273545
# maximum final inertia: 3.5485520910273545
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month102.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 4.908777009623934
# maximum initial inertia: 17.52868445344458
# number of unique final inertia values: 1
# minimum final inertia: 4.149303487095497
# maximum final inertia: 4.149303487095497
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month103.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 4.295381643279868
# maximum initial inertia: 18.545681467041934
# number of unique final inertia values: 1
# minimum final inertia: 3.6613387113981597
# maximum final inertia: 3.6613387113981597
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month104.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 3
# minimum initial inertia: 3.565907443781886
# maximum initial inertia: 17.98372738179495
# number of unique final inertia values: 1
# minimum final inertia: 2.9721992909872403
# maximum final inertia: 2.9721992909872403
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month105.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.107777830746949
# maximum initial inertia: 18.79856358746592
# number of unique final inertia values: 1
# minimum final inertia: 3.819095410018925
# maximum final inertia: 3.819095410018925
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# ...
# number of unique final inertia values: 1
# minimum final inertia: 3.922658044678863
# maximum final inertia: 3.922658044678863
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month167.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.919991457670371
# maximum initial inertia: 16.160065644170757
# number of unique final inertia values: 2
# minimum final inertia: 4.116288999556053
# maximum final inertia: 4.116298008486566
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month168.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 5.265560388141307
# maximum initial inertia: 12.162187112640789
# number of unique final inertia values: 9
# minimum final inertia: 4.403773834680737
# maximum final inertia: 5.460540273944831
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month169.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.194733258163915
# maximum initial inertia: 14.353351580181307
# number of unique final inertia values: 3
# minimum final inertia: 4.4106696105572585
# maximum final inertia: 4.415682367617272
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month170.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 3.7633865251758625
# maximum initial inertia: 11.35146019768315
# number of unique final inertia values: 17
# minimum final inertia: 3.292167098824007
# maximum final inertia: 3.9195908706568714
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month171.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 9
# minimum initial inertia: 5.625771099055099
# maximum initial inertia: 11.243624932019822
# number of unique final inertia values: 28
# minimum final inertia: 4.77028991260491
# maximum final inertia: 5.017973602840424
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month172.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 4.593541432425794
# maximum initial inertia: 11.687044216995867
# number of unique final inertia values: 1
# minimum final inertia: 3.8109119220347374
# maximum final inertia: 3.8109119220347374
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month173.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.357622282168646
# maximum initial inertia: 14.540515858637828
# number of unique final inertia values: 4
# minimum final inertia: 4.317725642352601
# maximum final inertia: 5.6974146145593645
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month174.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 5.772217176171653
# maximum initial inertia: 15.498633038702351
# number of unique final inertia values: 2
# minimum final inertia: 5.237027398220515
# maximum final inertia: 5.238837842171274
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month175.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 4.656278336220695
# maximum initial inertia: 13.85068519580607
# number of unique final inertia values: 10
# minimum final inertia: 4.033671230809652
# maximum final inertia: 5.41996506536008
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month176.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 3
# minimum initial inertia: 4.433819267485939
# maximum initial inertia: 18.745666788047465
# number of unique final inertia values: 1
# minimum final inertia: 3.7591817598828285
# maximum final inertia: 3.7591817598828285
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month177.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 3.986347733891271
# maximum initial inertia: 17.846457182401195
# number of unique final inertia values: 1
# minimum final inertia: 3.4997769999053165
# maximum final inertia: 3.4997769999053165
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month178.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.687939334684227
# maximum initial inertia: 20.072146452185827
# number of unique final inertia values: 3
# minimum final inertia: 3.9049090755902007
# maximum final inertia: 7.1757943049153
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month179.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 5.805731672027967
# maximum initial inertia: 17.455387010141017
# number of unique final inertia values: 1
# minimum final inertia: 4.714294720011938
# maximum final inertia: 4.714294720011938
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month180.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 4.38591121546146
# maximum initial inertia: 10.949654717695532
# number of unique final inertia values: 5
# minimum final inertia: 3.8859938371942464
# maximum final inertia: 3.9043571633176133
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month181.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 5.207840541534006
# maximum initial inertia: 13.631663049171769
# number of unique final inertia values: 13
# minimum final inertia: 4.708799246062727
# maximum final inertia: 5.018581860894267
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month182.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 4.988433933454068
# maximum initial inertia: 10.424663534439176
# number of unique final inertia values: 6
# minimum final inertia: 3.9742467079737467
# maximum final inertia: 5.622582213023133
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month183.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.316129386305058
# maximum initial inertia: 12.599899677865453
# number of unique final inertia values: 29
# minimum final inertia: 4.7445221712269054
# maximum final inertia: 5.403526554704287
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month184.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 4.903722961963355
# maximum initial inertia: 11.713201929510412
# number of unique final inertia values: 5
# minimum final inertia: 4.28705033665648
# maximum final inertia: 4.607234917388272
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month185.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 15
# minimum initial inertia: 5.334521539106075
# maximum initial inertia: 11.084742902725512
# number of unique final inertia values: 37
# minimum final inertia: 4.528779881374618
# maximum final inertia: 5.246148435375586
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month186.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.841685938989814
# maximum initial inertia: 11.236730333117446
# number of unique final inertia values: 4
# minimum final inertia: 4.113101830871244
# maximum final inertia: 4.2273644465959554
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month187.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 8
# minimum initial inertia: 4.375631537950006
# maximum initial inertia: 13.7732896239555
# number of unique final inertia values: 3
# minimum final inertia: 3.697744081313121
# maximum final inertia: 3.7007668584276754
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month188.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 5.068611948951014
# maximum initial inertia: 19.57430801645818
# number of unique final inertia values: 1
# minimum final inertia: 4.082205082907062
# maximum final inertia: 4.082205082907062
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month189.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.228581399252526
# maximum initial inertia: 17.897498214902345
# number of unique final inertia values: 1
# minimum final inertia: 3.709716572150806
# maximum final inertia: 3.709716572150806
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month190.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 5
# minimum initial inertia: 3.9269140294233695
# maximum initial inertia: 17.97100297237528
# number of unique final inertia values: 1
# minimum final inertia: 3.2486234412974
# maximum final inertia: 3.2486234412974
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month191.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 7
# minimum initial inertia: 4.076734692179894
# maximum initial inertia: 14.40253701418009
# number of unique final inertia values: 1
# minimum final inertia: 3.4003577891201457
# maximum final inertia: 3.4003577891201457
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month192.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 12
# minimum initial inertia: 3.8858112484458913
# maximum initial inertia: 9.126006274938309
# number of unique final inertia values: 1
# minimum final inertia: 3.45462772902735
# maximum final inertia: 3.45462772902735
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month193.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 4.329113466278312
# maximum initial inertia: 10.773359856266216
# number of unique final inertia values: 7
# minimum final inertia: 3.6003012307872155
# maximum final inertia: 3.6142351953844187
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month194.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 3.9326650655549087
# maximum initial inertia: 9.007507217072531
# number of unique final inertia values: 31
# minimum final inertia: 3.4685014306018527
# maximum final inertia: 4.168278548642802
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month195.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 14
# minimum initial inertia: 6.910312854332559
# maximum initial inertia: 18.119388017836705
# number of unique final inertia values: 5
# minimum final inertia: 5.853960769094446
# maximum final inertia: 7.617804479908491
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month196.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 13
# minimum initial inertia: 6.554543240464223
# maximum initial inertia: 14.546690146865636
# number of unique final inertia values: 15
# minimum final inertia: 5.603639251557469
# maximum final inertia: 7.608469427852686
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month197.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 11
# minimum initial inertia: 6.558473565806723
# maximum initial inertia: 21.500763783281606
# number of unique final inertia values: 6
# minimum final inertia: 5.74156011087808
# maximum final inertia: 7.714317621308586
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month198.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 10
# minimum initial inertia: 5.696832020302207
# maximum initial inertia: 12.63004181025977
# number of unique final inertia values: 2
# minimum final inertia: 4.861026164376483
# maximum final inertia: 4.876427762355894
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month199.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 6
# minimum initial inertia: 4.941413448816326
# maximum initial inertia: 13.129553970130035
# number of unique final inertia values: 1
# minimum final inertia: 4.284692530505325
# maximum final inertia: 4.284692530505325
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# filename weather_kmeans_month/weather_output_month200.txt
# random state: 1053
# total number of results: 100
# maximum number of iterations: 4
# minimum initial inertia: 4.565334963613139
# maximum initial inertia: 19.868108230282022
# number of unique final inertia values: 1
# minimum final inertia: 4.144114184858864
# maximum final inertia: 4.144114184858864
# total number of convergences: 100
# number of strict convergences: 100
# number of tol-based convergences: 0
# {'total_max_iterations': 18, 'total_min_init_inertia': 3.364562618463802, 'total_max_init_inertia': 22.102803110996145, 'total_min_final_inertia': 2.8864291362628705, 'total_max_final_inertia': 7.714317621308586, 'total_num_convergences': 20100, 'total_num_strict_convergences': 20100, 'total_num_tol_based_convergences': 0}

# %% [markdown]
# ### Read the defined monthly drift locations

# %%
true_drift_bool_month = []
with open('../Datasets_concept_drift/real_world_data_drifts/weather/weather_monthly_drifts.csv') as f:
    rdr = csv.reader(f, delimiter=',')
    for row in rdr:
        true_drift_bool_month.append(row)
    true_drift_bool_month = true_drift_bool_month[0] # only one row of important data
    true_drift_bool_month = [b == 'True' for b in true_drift_bool_month]
print(true_drift_bool_month)
# Out:
# [False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, True, True, True, True, True, True, False, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, False, False, False, True, True, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, True, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, True, False, False, False, False, False, False, False, True, False, True, True, False, False, False]

# %% [markdown]
# ### Use the drift locations and best clustering parameters for the evaluation

# %%
import time


start_time = time.time()
_, fpr_mean_month, _, det_acc_mean_month, _ = ucdd_eval_real_world.all_drifting_batches_randomness_robust(
    reference_data_batches=X_ref_batches_month,
    testing_data_batches=X_test_batches_month,
    true_drift_bool=true_drift_bool_month,
    train_batch_strategy=spms.TrainBatchStrategies.ANY,
    additional_check=True,
    n_init=100, max_iter=18000, tol=0,
    first_random_state=0,
    min_runs=1, std_err_threshold=0.05
)
end_time = time.time()
print('time taken:', end_time - start_time)
print('monthly mean FPR:', fpr_mean_month)
print('monthly mean detection accuracy:', det_acc_mean_month)
# Out:
# min_runs 1
# random_state
# 0
# #### TEST BATCH 0 of 403 ####
# #### TEST BATCH 1 of 403 ####
# #### TEST BATCH 2 of 403 ####
# #### TEST BATCH 3 of 403 ####
# #### TEST BATCH 4 of 403 ####
# #### TEST BATCH 5 of 403 ####
# #### TEST BATCH 6 of 403 ####
# #### TEST BATCH 7 of 403 ####
# #### TEST BATCH 8 of 403 ####
# #### TEST BATCH 9 of 403 ####
# #### TEST BATCH 10 of 403 ####
# #### TEST BATCH 11 of 403 ####
# #### TEST BATCH 12 of 403 ####
# #### TEST BATCH 13 of 403 ####
# #### TEST BATCH 14 of 403 ####
# #### TEST BATCH 15 of 403 ####
# #### TEST BATCH 16 of 403 ####
# #### TEST BATCH 17 of 403 ####
# #### TEST BATCH 18 of 403 ####
# #### TEST BATCH 19 of 403 ####
# #### TEST BATCH 20 of 403 ####
# #### TEST BATCH 21 of 403 ####
# #### TEST BATCH 22 of 403 ####
# #### TEST BATCH 23 of 403 ####
# #### TEST BATCH 24 of 403 ####
# #### TEST BATCH 25 of 403 ####
# #### TEST BATCH 26 of 403 ####
# #### TEST BATCH 27 of 403 ####
# #### TEST BATCH 28 of 403 ####
# #### TEST BATCH 29 of 403 ####
# #### TEST BATCH 30 of 403 ####
# #### TEST BATCH 31 of 403 ####
# #### TEST BATCH 32 of 403 ####
# #### TEST BATCH 33 of 403 ####
# #### TEST BATCH 34 of 403 ####
# #### TEST BATCH 35 of 403 ####
# #### TEST BATCH 36 of 403 ####
# #### TEST BATCH 37 of 403 ####
# #### TEST BATCH 38 of 403 ####
# #### TEST BATCH 39 of 403 ####
# #### TEST BATCH 40 of 403 ####
# #### TEST BATCH 41 of 403 ####
# #### TEST BATCH 42 of 403 ####
# #### TEST BATCH 43 of 403 ####
# #### TEST BATCH 44 of 403 ####
# #### TEST BATCH 45 of 403 ####
# #### TEST BATCH 46 of 403 ####
# #### TEST BATCH 47 of 403 ####
# #### TEST BATCH 48 of 403 ####
# #### TEST BATCH 49 of 403 ####
# #### TEST BATCH 50 of 403 ####
# #### TEST BATCH 51 of 403 ####
# #### TEST BATCH 52 of 403 ####
# #### TEST BATCH 53 of 403 ####
# #### TEST BATCH 54 of 403 ####
# #### TEST BATCH 55 of 403 ####
# #### TEST BATCH 56 of 403 ####
# #### TEST BATCH 57 of 403 ####
# #### TEST BATCH 58 of 403 ####
# #### TEST BATCH 59 of 403 ####
# #### TEST BATCH 60 of 403 ####
# #### TEST BATCH 61 of 403 ####
# #### TEST BATCH 62 of 403 ####
# #### TEST BATCH 63 of 403 ####
# #### TEST BATCH 64 of 403 ####
# #### TEST BATCH 65 of 403 ####
# #### TEST BATCH 66 of 403 ####
# #### TEST BATCH 67 of 403 ####
# #### TEST BATCH 68 of 403 ####
# #### TEST BATCH 69 of 403 ####
# #### TEST BATCH 70 of 403 ####
# #### TEST BATCH 71 of 403 ####
# #### TEST BATCH 72 of 403 ####
# #### TEST BATCH 73 of 403 ####
# #### TEST BATCH 74 of 403 ####
# #### TEST BATCH 75 of 403 ####
# #### TEST BATCH 76 of 403 ####
# #### TEST BATCH 77 of 403 ####
# #### TEST BATCH 78 of 403 ####
# #### TEST BATCH 79 of 403 ####
# #### TEST BATCH 80 of 403 ####
# #### TEST BATCH 81 of 403 ####
# #### TEST BATCH 82 of 403 ####
# #### TEST BATCH 83 of 403 ####
# #### TEST BATCH 84 of 403 ####
# #### TEST BATCH 85 of 403 ####
# #### TEST BATCH 86 of 403 ####
# #### TEST BATCH 87 of 403 ####
# #### TEST BATCH 88 of 403 ####
# #### TEST BATCH 89 of 403 ####
# #### TEST BATCH 90 of 403 ####
# #### TEST BATCH 91 of 403 ####
# #### TEST BATCH 92 of 403 ####
# #### TEST BATCH 93 of 403 ####
# #### TEST BATCH 94 of 403 ####
# #### TEST BATCH 95 of 403 ####
# #### TEST BATCH 96 of 403 ####
# #### TEST BATCH 97 of 403 ####
# #### TEST BATCH 98 of 403 ####
# #### TEST BATCH 99 of 403 ####
# #### TEST BATCH 100 of 403 ####
# #### TEST BATCH 101 of 403 ####
# #### TEST BATCH 102 of 403 ####
# #### TEST BATCH 103 of 403 ####
# #### TEST BATCH 104 of 403 ####
# #### TEST BATCH 105 of 403 ####
# #### TEST BATCH 106 of 403 ####
# #### TEST BATCH 107 of 403 ####
# #### TEST BATCH 108 of 403 ####
# #### TEST BATCH 109 of 403 ####
# #### TEST BATCH 110 of 403 ####
# #### TEST BATCH 111 of 403 ####
# #### TEST BATCH 112 of 403 ####
# #### TEST BATCH 113 of 403 ####
# #### TEST BATCH 114 of 403 ####
# #### TEST BATCH 115 of 403 ####
# #### TEST BATCH 116 of 403 ####
# #### TEST BATCH 117 of 403 ####
# #### TEST BATCH 118 of 403 ####
# #### TEST BATCH 119 of 403 ####
# #### TEST BATCH 120 of 403 ####
# #### TEST BATCH 121 of 403 ####
# #### TEST BATCH 122 of 403 ####
# #### TEST BATCH 123 of 403 ####
# #### TEST BATCH 124 of 403 ####
# #### TEST BATCH 125 of 403 ####
# #### TEST BATCH 126 of 403 ####
# #### TEST BATCH 127 of 403 ####
# #### TEST BATCH 128 of 403 ####
# #### TEST BATCH 129 of 403 ####
# #### TEST BATCH 130 of 403 ####
# #### TEST BATCH 131 of 403 ####
# #### TEST BATCH 132 of 403 ####
# #### TEST BATCH 133 of 403 ####
# #### TEST BATCH 134 of 403 ####
# #### TEST BATCH 135 of 403 ####
# #### TEST BATCH 136 of 403 ####
# #### TEST BATCH 137 of 403 ####
# #### TEST BATCH 138 of 403 ####
# #### TEST BATCH 139 of 403 ####
# #### TEST BATCH 140 of 403 ####
# #### TEST BATCH 141 of 403 ####
# #### TEST BATCH 142 of 403 ####
# #### TEST BATCH 143 of 403 ####
# #### TEST BATCH 144 of 403 ####
# #### TEST BATCH 145 of 403 ####
# #### TEST BATCH 146 of 403 ####
# #### TEST BATCH 147 of 403 ####
# #### TEST BATCH 148 of 403 ####
# #### TEST BATCH 149 of 403 ####
# #### TEST BATCH 150 of 403 ####
# #### TEST BATCH 151 of 403 ####
# #### TEST BATCH 152 of 403 ####
# #### TEST BATCH 153 of 403 ####
# #### TEST BATCH 154 of 403 ####
# #### TEST BATCH 155 of 403 ####
# #### TEST BATCH 156 of 403 ####
# #### TEST BATCH 157 of 403 ####
# #### TEST BATCH 158 of 403 ####
# #### TEST BATCH 159 of 403 ####
# #### TEST BATCH 160 of 403 ####
# #### TEST BATCH 161 of 403 ####
# #### TEST BATCH 162 of 403 ####
# #### TEST BATCH 163 of 403 ####
# #### TEST BATCH 164 of 403 ####
# #### TEST BATCH 165 of 403 ####
# #### TEST BATCH 166 of 403 ####
# #### TEST BATCH 167 of 403 ####
# #### TEST BATCH 168 of 403 ####
# #### TEST BATCH 169 of 403 ####
# #### TEST BATCH 170 of 403 ####
# #### TEST BATCH 171 of 403 ####
# #### TEST BATCH 172 of 403 ####
# #### TEST BATCH 173 of 403 ####
# #### TEST BATCH 174 of 403 ####
# #### TEST BATCH 175 of 403 ####
# #### TEST BATCH 176 of 403 ####
# #### TEST BATCH 177 of 403 ####
# #### TEST BATCH 178 of 403 ####
# #### TEST BATCH 179 of 403 ####
# #### TEST BATCH 180 of 403 ####
# #### TEST BATCH 181 of 403 ####
# #### TEST BATCH 182 of 403 ####
# #### TEST BATCH 183 of 403 ####
# #### TEST BATCH 184 of 403 ####
# #### TEST BATCH 185 of 403 ####
# #### TEST BATCH 186 of 403 ####
# #### TEST BATCH 187 of 403 ####
# #### TEST BATCH 188 of 403 ####
# #### TEST BATCH 189 of 403 ####
# #### TEST BATCH 190 of 403 ####
# #### TEST BATCH 191 of 403 ####
# #### TEST BATCH 192 of 403 ####
# #### TEST BATCH 193 of 403 ####
# #### TEST BATCH 194 of 403 ####
# #### TEST BATCH 195 of 403 ####
# #### TEST BATCH 196 of 403 ####
# #### TEST BATCH 197 of 403 ####
# #### TEST BATCH 198 of 403 ####
# #### TEST BATCH 199 of 403 ####
# #### TEST BATCH 200 of 403 ####
# #### TEST BATCH 201 of 403 ####
# #### TEST BATCH 202 of 403 ####
# #### TEST BATCH 203 of 403 ####
# #### TEST BATCH 204 of 403 ####
# #### TEST BATCH 205 of 403 ####
# #### TEST BATCH 206 of 403 ####
# #### TEST BATCH 207 of 403 ####
# #### TEST BATCH 208 of 403 ####
# #### TEST BATCH 209 of 403 ####
# #### TEST BATCH 210 of 403 ####
# #### TEST BATCH 211 of 403 ####
# #### TEST BATCH 212 of 403 ####
# #### TEST BATCH 213 of 403 ####
# #### TEST BATCH 214 of 403 ####
# #### TEST BATCH 215 of 403 ####
# #### TEST BATCH 216 of 403 ####
# #### TEST BATCH 217 of 403 ####
# #### TEST BATCH 218 of 403 ####
# #### TEST BATCH 219 of 403 ####
# #### TEST BATCH 220 of 403 ####
# #### TEST BATCH 221 of 403 ####
# #### TEST BATCH 222 of 403 ####
# #### TEST BATCH 223 of 403 ####
# #### TEST BATCH 224 of 403 ####
# #### TEST BATCH 225 of 403 ####
# #### TEST BATCH 226 of 403 ####
# #### TEST BATCH 227 of 403 ####
# #### TEST BATCH 228 of 403 ####
# #### TEST BATCH 229 of 403 ####
# #### TEST BATCH 230 of 403 ####
# #### TEST BATCH 231 of 403 ####
# #### TEST BATCH 232 of 403 ####
# #### TEST BATCH 233 of 403 ####
# #### TEST BATCH 234 of 403 ####
# #### TEST BATCH 235 of 403 ####
# #### TEST BATCH 236 of 403 ####
# #### TEST BATCH 237 of 403 ####
# #### TEST BATCH 238 of 403 ####
# #### TEST BATCH 239 of 403 ####
# #### TEST BATCH 240 of 403 ####
# #### TEST BATCH 241 of 403 ####
# #### TEST BATCH 242 of 403 ####
# #### TEST BATCH 243 of 403 ####
# #### TEST BATCH 244 of 403 ####
# #### TEST BATCH 245 of 403 ####
# #### TEST BATCH 246 of 403 ####
# #### TEST BATCH 247 of 403 ####
# #### TEST BATCH 248 of 403 ####
# #### TEST BATCH 249 of 403 ####
# #### TEST BATCH 250 of 403 ####
# #### TEST BATCH 251 of 403 ####
# #### TEST BATCH 252 of 403 ####
# #### TEST BATCH 253 of 403 ####
# #### TEST BATCH 254 of 403 ####
# #### TEST BATCH 255 of 403 ####
# #### TEST BATCH 256 of 403 ####
# #### TEST BATCH 257 of 403 ####
# #### TEST BATCH 258 of 403 ####
# #### TEST BATCH 259 of 403 ####
# #### TEST BATCH 260 of 403 ####
# #### TEST BATCH 261 of 403 ####
# #### TEST BATCH 262 of 403 ####
# #### TEST BATCH 263 of 403 ####
# #### TEST BATCH 264 of 403 ####
# #### TEST BATCH 265 of 403 ####
# #### TEST BATCH 266 of 403 ####
# #### TEST BATCH 267 of 403 ####
# #### TEST BATCH 268 of 403 ####
# #### TEST BATCH 269 of 403 ####
# #### TEST BATCH 270 of 403 ####
# #### TEST BATCH 271 of 403 ####
# #### TEST BATCH 272 of 403 ####
# #### TEST BATCH 273 of 403 ####
# #### TEST BATCH 274 of 403 ####
# #### TEST BATCH 275 of 403 ####
# #### TEST BATCH 276 of 403 ####
# #### TEST BATCH 277 of 403 ####
# #### TEST BATCH 278 of 403 ####
# #### TEST BATCH 279 of 403 ####
# #### TEST BATCH 280 of 403 ####
# #### TEST BATCH 281 of 403 ####
# #### TEST BATCH 282 of 403 ####
# #### TEST BATCH 283 of 403 ####
# #### TEST BATCH 284 of 403 ####
# #### TEST BATCH 285 of 403 ####
# #### TEST BATCH 286 of 403 ####
# #### TEST BATCH 287 of 403 ####
# #### TEST BATCH 288 of 403 ####
# #### TEST BATCH 289 of 403 ####
# #### TEST BATCH 290 of 403 ####
# #### TEST BATCH 291 of 403 ####
# #### TEST BATCH 292 of 403 ####
# #### TEST BATCH 293 of 403 ####
# #### TEST BATCH 294 of 403 ####
# #### TEST BATCH 295 of 403 ####
# #### TEST BATCH 296 of 403 ####
# #### TEST BATCH 297 of 403 ####
# #### TEST BATCH 298 of 403 ####
# #### TEST BATCH 299 of 403 ####
# #### TEST BATCH 300 of 403 ####
# #### TEST BATCH 301 of 403 ####
# #### TEST BATCH 302 of 403 ####
# #### TEST BATCH 303 of 403 ####
# #### TEST BATCH 304 of 403 ####
# #### TEST BATCH 305 of 403 ####
# #### TEST BATCH 306 of 403 ####
# #### TEST BATCH 307 of 403 ####
# #### TEST BATCH 308 of 403 ####
# #### TEST BATCH 309 of 403 ####
# #### TEST BATCH 310 of 403 ####
# #### TEST BATCH 311 of 403 ####
# #### TEST BATCH 312 of 403 ####
# #### TEST BATCH 313 of 403 ####
# #### TEST BATCH 314 of 403 ####
# #### TEST BATCH 315 of 403 ####
# #### TEST BATCH 316 of 403 ####
# #### TEST BATCH 317 of 403 ####
# #### TEST BATCH 318 of 403 ####
# #### TEST BATCH 319 of 403 ####
# #### TEST BATCH 320 of 403 ####
# #### TEST BATCH 321 of 403 ####
# #### TEST BATCH 322 of 403 ####
# #### TEST BATCH 323 of 403 ####
# #### TEST BATCH 324 of 403 ####
# #### TEST BATCH 325 of 403 ####
# #### TEST BATCH 326 of 403 ####
# #### TEST BATCH 327 of 403 ####
# #### TEST BATCH 328 of 403 ####
# #### TEST BATCH 329 of 403 ####
# #### TEST BATCH 330 of 403 ####
# #### TEST BATCH 331 of 403 ####
# #### TEST BATCH 332 of 403 ####
# #### TEST BATCH 333 of 403 ####
# #### TEST BATCH 334 of 403 ####
# #### TEST BATCH 335 of 403 ####
# #### TEST BATCH 336 of 403 ####
# #### TEST BATCH 337 of 403 ####
# #### TEST BATCH 338 of 403 ####
# #### TEST BATCH 339 of 403 ####
# #### TEST BATCH 340 of 403 ####
# #### TEST BATCH 341 of 403 ####
# #### TEST BATCH 342 of 403 ####
# #### TEST BATCH 343 of 403 ####
# #### TEST BATCH 344 of 403 ####
# #### TEST BATCH 345 of 403 ####
# #### TEST BATCH 346 of 403 ####
# #### TEST BATCH 347 of 403 ####
# #### TEST BATCH 348 of 403 ####
# #### TEST BATCH 349 of 403 ####
# #### TEST BATCH 350 of 403 ####
# #### TEST BATCH 351 of 403 ####
# #### TEST BATCH 352 of 403 ####
# #### TEST BATCH 353 of 403 ####
# #### TEST BATCH 354 of 403 ####
# #### TEST BATCH 355 of 403 ####
# #### TEST BATCH 356 of 403 ####
# #### TEST BATCH 357 of 403 ####
# #### TEST BATCH 358 of 403 ####
# #### TEST BATCH 359 of 403 ####
# #### TEST BATCH 360 of 403 ####
# #### TEST BATCH 361 of 403 ####
# #### TEST BATCH 362 of 403 ####
# #### TEST BATCH 363 of 403 ####
# #### TEST BATCH 364 of 403 ####
# #### TEST BATCH 365 of 403 ####
# #### TEST BATCH 366 of 403 ####
# #### TEST BATCH 367 of 403 ####
# #### TEST BATCH 368 of 403 ####
# #### TEST BATCH 369 of 403 ####
# #### TEST BATCH 370 of 403 ####
# #### TEST BATCH 371 of 403 ####
# #### TEST BATCH 372 of 403 ####
# #### TEST BATCH 373 of 403 ####
# #### TEST BATCH 374 of 403 ####
# #### TEST BATCH 375 of 403 ####
# #### TEST BATCH 376 of 403 ####
# #### TEST BATCH 377 of 403 ####
# #### TEST BATCH 378 of 403 ####
# #### TEST BATCH 379 of 403 ####
# #### TEST BATCH 380 of 403 ####
# #### TEST BATCH 381 of 403 ####
# #### TEST BATCH 382 of 403 ####
# #### TEST BATCH 383 of 403 ####
# #### TEST BATCH 384 of 403 ####
# #### TEST BATCH 385 of 403 ####
# #### TEST BATCH 386 of 403 ####
# #### TEST BATCH 387 of 403 ####
# #### TEST BATCH 388 of 403 ####
# #### TEST BATCH 389 of 403 ####
# #### TEST BATCH 390 of 403 ####
# #### TEST BATCH 391 of 403 ####
# #### TEST BATCH 392 of 403 ####
# #### TEST BATCH 393 of 403 ####
# #### TEST BATCH 394 of 403 ####
# #### TEST BATCH 395 of 403 ####
# #### TEST BATCH 396 of 403 ####
# #### TEST BATCH 397 of 403 ####
# #### TEST BATCH 398 of 403 ####
# #### TEST BATCH 399 of 403 ####
# #### TEST BATCH 400 of 403 ####
# #### TEST BATCH 401 of 403 ####
# #### TEST BATCH 402 of 403 ####
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]
# [False, False, False, False, False, False, False, False, False, False, True, True, False, True, False, False, False, True, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, True, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, False, True, False, False, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, True, True, True, True, True, True, False, False, False, False, True, False, True, True, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, True, False, False, False, True, True, False, False, False, True, True, False, True, False, False, True, False, False, False, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, True, True, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, True, True, False, False, True, False, False, False, False, False, False, False, True, False, False, True, False, False, False, False, False, False, False, False, False, False, False, True, False, False, True, False, False, False, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True, False, True, False, False, False, False, False, False, False, True, False, True, True, False, False, False]
# time taken: 26789.528102636337
# monthly mean FPR: 1.0
# monthly mean detection accuracy: 1.0
